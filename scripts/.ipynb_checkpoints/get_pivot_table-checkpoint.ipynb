# %%
import pandas as pd
import sys
import csv

# %%
results = pd.read_csv("Final_Results.csv")

# %%
results
# Out:
#      Unnamed: 0                   project    algorithm  batch_size  \
# 0           109   cloud_controller_ng.csv       BATCH4           4
# 1           104   cloud_controller_ng.csv  BATCHBISECT           1
# 2           105   cloud_controller_ng.csv  BATCHBISECT           2
# 3           106   cloud_controller_ng.csv  BATCHBISECT           4
# 4           107   cloud_controller_ng.csv  BATCHBISECT           8
# ..          ...                       ...          ...         ...
# 615         127  metasploit-framework.csv  BATCHBISECT          16
# 616         135                gradle.csv  BATCHBISECT          16
# 617         143                puppet.csv  BATCHBISECT          16
# 618         151                  opal.csv  BATCHBISECT          16
# 619         159             sonarqube.csv  BATCHBISECT          16
#
#      builds_reqd  median_delay  testall_size method
# 0      73.091364           2.0          2397     gr
# 1     100.000000           0.0          2397     gr
# 2      80.141844           1.0          2397     gr
# 3      79.098874           2.0          2397     gr
# 4      83.771381           4.0          2397     gr
# ..           ...           ...           ...    ...
# 615    28.828947           8.0          7600   aici
# 616    38.015139           8.0          3567   aici
# 617    28.742004           8.0          2345   aici
# 618    42.460470           8.0          2593   aici
# 619    65.960139           8.0          3161   aici
#
# [620 rows x 8 columns]

# %%
results = results.drop('Unnamed: 0', axis='columns')

# %%
method = ['aici', 'ssr', 'gr', '']
algorithms = ['BATCH4', 'BATCHBISECT', 'BATCHSTOP4']
batchsize = [2, 4, 8, 16]
project_list = list(set(results['project'].tolist()))

# %%
for m in method:
    
    filename = m + '_pivot_median_delay.csv'
    file = open(filename, 'w')
    res_headers = ['project', 'B4_builds', 'B4_delay', 'B4_Batch', 'BB_builds', 'BB_delay', 'BB_Batch', 'BS4_builds', 'BS4_delay', 'BS4_Batch']
    res_writer = csv.writer(file)
    res_writer.writerow(res_headers)
    
    
    for p in project_list:
        
        b4_builds = 0
        b4_delay = 0
        b4_batch = 0
        
        bs4_builds = 0
        bs4_delay = 0
        bs4_batch = 0
        
        bb_builds = 0
        bb_delay = 0
        bb_batch = 0
        
        for alg in algorithms:
            data = results[ (results['method'] == m) & (results['algorithm'] == alg) & (results['project'] == p)]
            data = data.drop(data[data.batch_size < 2].index)
            data = data.drop(data[data.batch_size > 16].index)

            best_batch = 0
            lowest_distance = sys.maxsize
            delays = data['median_delay'].tolist()
            builds_reqd = data['builds_reqd'].tolist()
            batch_size = data['batch_size'].tolist()

            for i in range(len(delays)):
                d = (builds_reqd[i]**2 + delays[i]**2)**0.5
                if d < lowest_distance:
                    
                    best_batch = batch_size[i]
                    lowest_distance = d
                    
                    if alg == 'BATCHBISECT':
                        bb_builds = builds_reqd[i]
                        bb_delay = delays[i]
                        bb_batch = best_batch
                    elif alg == 'BATCHSTOP4':
                        bs4_builds = builds_reqd[i]
                        bs4_delay = delays[i]
                        bs4_batch = best_batch
                    else:
                        b4_builds = builds_reqd[i]
                        b4_delay = delays[i]
                        b4_batch = best_batch
            print('{} - {} - {} - {}'.format(p, m, alg, best_batch))
        res_writer.writerow([p, b4_builds, b4_delay, b4_batch, bb_builds, bb_delay, bb_batch, bs4_builds, bs4_delay, bs4_batch])
# Out:
# loomio.csv - aici - BATCH4 - 4
# loomio.csv - aici - BATCHBISECT - 4
# loomio.csv - aici - BATCHSTOP4 - 8
# concerto.csv - aici - BATCH4 - 4
# concerto.csv - aici - BATCHBISECT - 2
# concerto.csv - aici - BATCHSTOP4 - 8
# sonarqube.csv - aici - BATCH4 - 4
# sonarqube.csv - aici - BATCHBISECT - 4
# sonarqube.csv - aici - BATCHSTOP4 - 8
# vagrant.csv - aici - BATCH4 - 4
# vagrant.csv - aici - BATCHBISECT - 8
# vagrant.csv - aici - BATCHSTOP4 - 8
# geoserver.csv - aici - BATCH4 - 4
# geoserver.csv - aici - BATCHBISECT - 2
# geoserver.csv - aici - BATCHSTOP4 - 8
# puppet.csv - aici - BATCH4 - 4
# puppet.csv - aici - BATCHBISECT - 16
# puppet.csv - aici - BATCHSTOP4 - 16
# sufia.csv - aici - BATCH4 - 4
# sufia.csv - aici - BATCHBISECT - 8
# sufia.csv - aici - BATCHSTOP4 - 8
# open-build-service.csv - aici - BATCH4 - 4
# open-build-service.csv - aici - BATCHBISECT - 2
# open-build-service.csv - aici - BATCHSTOP4 - 8
# heroku.csv - aici - BATCH4 - 4
# heroku.csv - aici - BATCHBISECT - 4
# heroku.csv - aici - BATCHSTOP4 - 8
# jruby.csv - aici - BATCH4 - 4
# jruby.csv - aici - BATCHBISECT - 2
# jruby.csv - aici - BATCHSTOP4 - 8
# orbeon-forms.csv - aici - BATCH4 - 4
# orbeon-forms.csv - aici - BATCHBISECT - 2
# orbeon-forms.csv - aici - BATCHSTOP4 - 8
# rubinius.csv - aici - BATCH4 - 4
# rubinius.csv - aici - BATCHBISECT - 2
# rubinius.csv - aici - BATCHSTOP4 - 8
# gradle.csv - aici - BATCH4 - 4
# gradle.csv - aici - BATCHBISECT - 8
# gradle.csv - aici - BATCHSTOP4 - 8
# rails.csv - aici - BATCH4 - 4
# rails.csv - aici - BATCHBISECT - 2
# rails.csv - aici - BATCHSTOP4 - 8
# metasploit-framework.csv - aici - BATCH4 - 4
# metasploit-framework.csv - aici - BATCHBISECT - 16
# metasploit-framework.csv - aici - BATCHSTOP4 - 16
# fog.csv - aici - BATCH4 - 4
# fog.csv - aici - BATCHBISECT - 2
# fog.csv - aici - BATCHSTOP4 - 8
# cloud_controller_ng.csv - aici - BATCH4 - 4
# cloud_controller_ng.csv - aici - BATCHBISECT - 2
# cloud_controller_ng.csv - aici - BATCHSTOP4 - 8
# opal.csv - aici - BATCH4 - 4
# opal.csv - aici - BATCHBISECT - 4
# opal.csv - aici - BATCHSTOP4 - 8
# cloudify.csv - aici - BATCH4 - 4
# cloudify.csv - aici - BATCHBISECT - 16
# cloudify.csv - aici - BATCHSTOP4 - 8
# graylog2-server.csv - aici - BATCH4 - 4
# graylog2-server.csv - aici - BATCHBISECT - 16
# graylog2-server.csv - aici - BATCHSTOP4 - 16
# loomio.csv - ssr - BATCH4 - 4
# loomio.csv - ssr - BATCHBISECT - 2
# loomio.csv - ssr - BATCHSTOP4 - 8
# concerto.csv - ssr - BATCH4 - 4
# concerto.csv - ssr - BATCHBISECT - 2
# concerto.csv - ssr - BATCHSTOP4 - 8
# sonarqube.csv - ssr - BATCH4 - 4
# sonarqube.csv - ssr - BATCHBISECT - 2
# sonarqube.csv - ssr - BATCHSTOP4 - 8
# vagrant.csv - ssr - BATCH4 - 4
# vagrant.csv - ssr - BATCHBISECT - 2
# vagrant.csv - ssr - BATCHSTOP4 - 8
# geoserver.csv - ssr - BATCH4 - 4
# geoserver.csv - ssr - BATCHBISECT - 2
# geoserver.csv - ssr - BATCHSTOP4 - 8
# puppet.csv - ssr - BATCH4 - 4
# puppet.csv - ssr - BATCHBISECT - 2
# puppet.csv - ssr - BATCHSTOP4 - 8
# sufia.csv - ssr - BATCH4 - 4
# sufia.csv - ssr - BATCHBISECT - 2
# sufia.csv - ssr - BATCHSTOP4 - 8
# open-build-service.csv - ssr - BATCH4 - 4
# open-build-service.csv - ssr - BATCHBISECT - 2
# open-build-service.csv - ssr - BATCHSTOP4 - 8
# heroku.csv - ssr - BATCH4 - 4
# heroku.csv - ssr - BATCHBISECT - 2
# heroku.csv - ssr - BATCHSTOP4 - 8
# jruby.csv - ssr - BATCH4 - 4
# jruby.csv - ssr - BATCHBISECT - 2
# jruby.csv - ssr - BATCHSTOP4 - 8
# orbeon-forms.csv - ssr - BATCH4 - 4
# orbeon-forms.csv - ssr - BATCHBISECT - 2
# orbeon-forms.csv - ssr - BATCHSTOP4 - 8
# rubinius.csv - ssr - BATCH4 - 4
# rubinius.csv - ssr - BATCHBISECT - 2
# rubinius.csv - ssr - BATCHSTOP4 - 8
# gradle.csv - ssr - BATCH4 - 4
# gradle.csv - ssr - BATCHBISECT - 2
# gradle.csv - ssr - BATCHSTOP4 - 8
# rails.csv - ssr - BATCH4 - 4
# rails.csv - ssr - BATCHBISECT - 2
# rails.csv - ssr - BATCHSTOP4 - 8
# metasploit-framework.csv - ssr - BATCH4 - 4
# metasploit-framework.csv - ssr - BATCHBISECT - 2
# metasploit-framework.csv - ssr - BATCHSTOP4 - 8
# fog.csv - ssr - BATCH4 - 4
# fog.csv - ssr - BATCHBISECT - 2
# fog.csv - ssr - BATCHSTOP4 - 8
# cloud_controller_ng.csv - ssr - BATCH4 - 4
# cloud_controller_ng.csv - ssr - BATCHBISECT - 2
# cloud_controller_ng.csv - ssr - BATCHSTOP4 - 8
# opal.csv - ssr - BATCH4 - 4
# opal.csv - ssr - BATCHBISECT - 2
# opal.csv - ssr - BATCHSTOP4 - 8
# cloudify.csv - ssr - BATCH4 - 4
# cloudify.csv - ssr - BATCHBISECT - 2
# cloudify.csv - ssr - BATCHSTOP4 - 8
# graylog2-server.csv - ssr - BATCH4 - 4
# graylog2-server.csv - ssr - BATCHBISECT - 2
# graylog2-server.csv - ssr - BATCHSTOP4 - 8
# loomio.csv - gr - BATCH4 - 4
# loomio.csv - gr - BATCHBISECT - 4
# loomio.csv - gr - BATCHSTOP4 - 8
# concerto.csv - gr - BATCH4 - 4
# concerto.csv - gr - BATCHBISECT - 8
# concerto.csv - gr - BATCHSTOP4 - 8
# sonarqube.csv - gr - BATCH4 - 4
# sonarqube.csv - gr - BATCHBISECT - 4
# sonarqube.csv - gr - BATCHSTOP4 - 8
# vagrant.csv - gr - BATCH4 - 4
# vagrant.csv - gr - BATCHBISECT - 16
# vagrant.csv - gr - BATCHSTOP4 - 16
# geoserver.csv - gr - BATCH4 - 4
# geoserver.csv - gr - BATCHBISECT - 2
# geoserver.csv - gr - BATCHSTOP4 - 8
# puppet.csv - gr - BATCH4 - 4
# puppet.csv - gr - BATCHBISECT - 16
# puppet.csv - gr - BATCHSTOP4 - 16
# sufia.csv - gr - BATCH4 - 4
# sufia.csv - gr - BATCHBISECT - 8
# sufia.csv - gr - BATCHSTOP4 - 8
# open-build-service.csv - gr - BATCH4 - 4
# open-build-service.csv - gr - BATCHBISECT - 4
# open-build-service.csv - gr - BATCHSTOP4 - 8
# heroku.csv - gr - BATCH4 - 4
# heroku.csv - gr - BATCHBISECT - 8
# heroku.csv - gr - BATCHSTOP4 - 8
# jruby.csv - gr - BATCH4 - 4
# jruby.csv - gr - BATCHBISECT - 2
# jruby.csv - gr - BATCHSTOP4 - 8
# orbeon-forms.csv - gr - BATCH4 - 4
# orbeon-forms.csv - gr - BATCHBISECT - 2
# orbeon-forms.csv - gr - BATCHSTOP4 - 8
# rubinius.csv - gr - BATCH4 - 4
# rubinius.csv - gr - BATCHBISECT - 2
# rubinius.csv - gr - BATCHSTOP4 - 8
# gradle.csv - gr - BATCH4 - 4
# gradle.csv - gr - BATCHBISECT - 8
# gradle.csv - gr - BATCHSTOP4 - 8
# rails.csv - gr - BATCH4 - 4
# rails.csv - gr - BATCHBISECT - 4
# rails.csv - gr - BATCHSTOP4 - 8
# metasploit-framework.csv - gr - BATCH4 - 4
# metasploit-framework.csv - gr - BATCHBISECT - 16
# metasploit-framework.csv - gr - BATCHSTOP4 - 16
# fog.csv - gr - BATCH4 - 4
# fog.csv - gr - BATCHBISECT - 2
# fog.csv - gr - BATCHSTOP4 - 8
# cloud_controller_ng.csv - gr - BATCH4 - 4
# cloud_controller_ng.csv - gr - BATCHBISECT - 4
# cloud_controller_ng.csv - gr - BATCHSTOP4 - 8
# opal.csv - gr - BATCH4 - 4
# opal.csv - gr - BATCHBISECT - 8
# opal.csv - gr - BATCHSTOP4 - 8
# cloudify.csv - gr - BATCH4 - 4
# cloudify.csv - gr - BATCHBISECT - 8
# cloudify.csv - gr - BATCHSTOP4 - 8
# graylog2-server.csv - gr - BATCH4 - 4
# graylog2-server.csv - gr - BATCHBISECT - 16
# graylog2-server.csv - gr - BATCHSTOP4 - 16
# loomio.csv -  - BATCH4 - 0
# loomio.csv -  - BATCHBISECT - 0
# loomio.csv -  - BATCHSTOP4 - 0
# concerto.csv -  - BATCH4 - 0
# concerto.csv -  - BATCHBISECT - 0
# concerto.csv -  - BATCHSTOP4 - 0
# sonarqube.csv -  - BATCH4 - 0
# sonarqube.csv -  - BATCHBISECT - 0
# sonarqube.csv -  - BATCHSTOP4 - 0
# vagrant.csv -  - BATCH4 - 0
# vagrant.csv -  - BATCHBISECT - 0
# vagrant.csv -  - BATCHSTOP4 - 0
# geoserver.csv -  - BATCH4 - 0
# geoserver.csv -  - BATCHBISECT - 0
# geoserver.csv -  - BATCHSTOP4 - 0
# puppet.csv -  - BATCH4 - 0
# puppet.csv -  - BATCHBISECT - 0
# puppet.csv -  - BATCHSTOP4 - 0
# sufia.csv -  - BATCH4 - 0
# sufia.csv -  - BATCHBISECT - 0
# sufia.csv -  - BATCHSTOP4 - 0
# open-build-service.csv -  - BATCH4 - 0
# open-build-service.csv -  - BATCHBISECT - 0
# open-build-service.csv -  - BATCHSTOP4 - 0
# heroku.csv -  - BATCH4 - 0
# heroku.csv -  - BATCHBISECT - 0
# heroku.csv -  - BATCHSTOP4 - 0
# jruby.csv -  - BATCH4 - 0
# jruby.csv -  - BATCHBISECT - 0
# jruby.csv -  - BATCHSTOP4 - 0
# orbeon-forms.csv -  - BATCH4 - 0
# orbeon-forms.csv -  - BATCHBISECT - 0
# orbeon-forms.csv -  - BATCHSTOP4 - 0
# rubinius.csv -  - BATCH4 - 0
# rubinius.csv -  - BATCHBISECT - 0
# rubinius.csv -  - BATCHSTOP4 - 0
# gradle.csv -  - BATCH4 - 0
# gradle.csv -  - BATCHBISECT - 0
# gradle.csv -  - BATCHSTOP4 - 0
# rails.csv -  - BATCH4 - 0
# rails.csv -  - BATCHBISECT - 0
# rails.csv -  - BATCHSTOP4 - 0
# metasploit-framework.csv -  - BATCH4 - 0
# metasploit-framework.csv -  - BATCHBISECT - 0
# metasploit-framework.csv -  - BATCHSTOP4 - 0
# fog.csv -  - BATCH4 - 0
# fog.csv -  - BATCHBISECT - 0
# fog.csv -  - BATCHSTOP4 - 0
# cloud_controller_ng.csv -  - BATCH4 - 0
# cloud_controller_ng.csv -  - BATCHBISECT - 0
# cloud_controller_ng.csv -  - BATCHSTOP4 - 0
# opal.csv -  - BATCH4 - 0
# opal.csv -  - BATCHBISECT - 0
# opal.csv -  - BATCHSTOP4 - 0
# cloudify.csv -  - BATCH4 - 0
# cloudify.csv -  - BATCHBISECT - 0
# cloudify.csv -  - BATCHSTOP4 - 0
# graylog2-server.csv -  - BATCH4 - 0
# graylog2-server.csv -  - BATCHBISECT - 0
# graylog2-server.csv -  - BATCHSTOP4 - 0

# %%
batch_reps = {0: 'na', 2: '^*^*', 4: '^\#', 6: '^\%', 8:'^\#^\#', 16:'^\wedge'}

# %%
print(batch_reps[2])
# Out:
# ^*^*

# %%
ssr = pd.read_csv('ssr_pivot_median_delay.csv')

# %%
projects = ssr['project'].tolist()
projects.sort()
col3 = ssr['B4_builds'].tolist()
col4 = ssr['B4_delay'].tolist()
b4_batch = ssr['B4_Batch'].tolist()
col5 = ssr['BB_builds'].tolist()
col6 = ssr['BB_delay'].tolist()
bb_batch = ssr['BB_Batch'].tolist()
col7 = ssr['BS4_builds'].tolist()
col8 = ssr['BS4_delay'].tolist()
bs4_batch = ssr['BS4_Batch'].tolist()

# %%
projects
# Out:
# ['cloud_controller_ng.csv',
#  'cloudify.csv',
#  'concerto.csv',
#  'fog.csv',
#  'geoserver.csv',
#  'gradle.csv',
#  'graylog2-server.csv',
#  'heroku.csv',
#  'jruby.csv',
#  'loomio.csv',
#  'metasploit-framework.csv',
#  'opal.csv',
#  'open-build-service.csv',
#  'orbeon-forms.csv',
#  'puppet.csv',
#  'rails.csv',
#  'rubinius.csv',
#  'sonarqube.csv',
#  'sufia.csv',
#  'vagrant.csv']

# %%
for i in range(len(projects)):
    print("{} & {}{} & {}{} & {}{} & {}{} & {}{} & {}{} \\\\".format(projects[i],  
                                                                round(col3[i], 3), batch_reps[b4_batch[i]], round(col4[i], 3), batch_reps[b4_batch[i]], 
                                                                round(col5[i], 3), batch_reps[bb_batch[i]], round(col6[i], 3), batch_reps[bb_batch[i]], 
                                                                round(col7[i], 3), batch_reps[bs4_batch[i]], round(col8[i], 3), batch_reps[bs4_batch[i]] ))
    print("\hline")
# Out:
# cloud_controller_ng.csv & 38.912^\# & 2.0^\# & 23.032^*^* & 1.0^*^* & 57.084^\#^\# & 4.0^\#^\# \\
# \hline
# cloudify.csv & 11.483^\# & 2.0^\# & 6.655^*^* & 1.0^*^* & 22.097^\#^\# & 4.0^\#^\# \\
# \hline
# concerto.csv & 17.748^\# & 2.0^\# & 15.153^*^* & 1.0^*^* & 32.49^\#^\# & 4.0^\#^\# \\
# \hline
# fog.csv & 10.773^\# & 2.0^\# & 8.451^*^* & 1.0^*^* & 15.295^\#^\# & 4.0^\#^\# \\
# \hline
# geoserver.csv & 72.398^\# & 2.0^\# & 56.167^*^* & 1.0^*^* & 96.424^\#^\# & 4.0^\#^\# \\
# \hline
# gradle.csv & 7.42^\# & 2.0^\# & 5.842^*^* & 1.0^*^* & 13.561^\#^\# & 4.0^\#^\# \\
# \hline
# graylog2-server.csv & 13.735^\# & 2.0^\# & 9.171^*^* & 1.0^*^* & 22.818^\#^\# & 4.0^\#^\# \\
# \hline
# heroku.csv & 25.673^\# & 2.0^\# & 16.604^*^* & 1.0^*^* & 49.569^\#^\# & 4.0^\#^\# \\
# \hline
# jruby.csv & 17.636^\# & 2.0^\# & 15.089^*^* & 1.0^*^* & 24.796^\#^\# & 4.0^\#^\# \\
# \hline
# loomio.csv & 79.79^\# & 2.0^\# & 69.999^*^* & 1.0^*^* & 103.397^\#^\# & 4.0^\#^\# \\
# \hline
# metasploit-framework.csv & 56.793^\# & 2.0^\# & 58.641^*^* & 1.0^*^* & 70.887^\#^\# & 4.0^\#^\# \\
# \hline
# opal.csv & 52.96^\# & 2.0^\# & 30.602^*^* & 1.0^*^* & 76.168^\#^\# & 4.0^\#^\# \\
# \hline
# open-build-service.csv & 10.345^\# & 2.0^\# & 7.205^*^* & 1.0^*^* & 15.475^\#^\# & 4.0^\#^\# \\
# \hline
# orbeon-forms.csv & 35.857^\# & 2.0^\# & 27.656^*^* & 1.0^*^* & 56.203^\#^\# & 4.0^\#^\# \\
# \hline
# puppet.csv & 7.421^\# & 2.0^\# & 6.855^*^* & 1.0^*^* & 12.132^\#^\# & 4.0^\#^\# \\
# \hline
# rails.csv & 45.059^\# & 2.0^\# & 27.56^*^* & 1.0^*^* & 66.691^\#^\# & 4.0^\#^\# \\
# \hline
# rubinius.csv & 28.744^\# & 2.0^\# & 16.479^*^* & 1.0^*^* & 50.688^\#^\# & 4.0^\#^\# \\
# \hline
# sonarqube.csv & 12.495^\# & 2.0^\# & 7.675^*^* & 1.0^*^* & 19.784^\#^\# & 4.0^\#^\# \\
# \hline
# sufia.csv & 23.021^\# & 2.0^\# & 21.089^*^* & 1.0^*^* & 30.314^\#^\# & 4.0^\#^\# \\
# \hline
# vagrant.csv & 5.977^\# & 2.0^\# & 5.645^*^* & 1.0^*^* & 8.112^\#^\# & 4.0^\#^\# \\
# \hline

# %%
ml = pd.read_csv('aici_pivot_median_delay.csv')

# %%
projects = ml['project'].tolist()
col3 = ml['B4_builds'].tolist()
col4 = ml['B4_delay'].tolist()
b4_batch = ml['B4_Batch'].tolist()
col5 = ml['BB_builds'].tolist()
col6 = ml['BB_delay'].tolist()
bb_batch = ml['BB_Batch'].tolist()
col7 = ml['BS4_builds'].tolist()
col8 = ml['BS4_delay'].tolist()
bs4_batch = ml['BS4_Batch'].tolist()

# %%
for i in range(len(projects)):
    print("{} & {}{} & {}{} & {}{} & {}{} & {}{} & {}{} \\\\".format(projects[i], 
                                                                round(col3[i], 3), batch_reps[b4_batch[i]], round(col4[i], 3), batch_reps[b4_batch[i]], 
                                                                round(col5[i], 3), batch_reps[bb_batch[i]], round(col6[i], 3), batch_reps[bb_batch[i]], 
                                                                round(col7[i], 3), batch_reps[bs4_batch[i]], round(col8[i], 3), batch_reps[bs4_batch[i]] ))
    print("\hline")
# Out:
# loomio.csv & 71.971^\# & 1.0^\# & 82.512^\# & 1.0^\# & 75.77^\#^\# & 4.0^\#^\# \\
# \hline
# concerto.csv & 34.58^\# & 2.0^\# & 35.059^*^* & 1.0^*^* & 38.93^\#^\# & 3.0^\#^\# \\
# \hline
# sonarqube.csv & 55.615^\# & 2.0^\# & 60.234^\# & 2.0^\# & 56.849^\#^\# & 3.0^\#^\# \\
# \hline
# vagrant.csv & 35.582^\# & 1.0^\# & 32.468^\#^\# & 3.0^\#^\# & 30.096^\#^\# & 3.0^\#^\# \\
# \hline
# geoserver.csv & 99.45^\# & 1.0^\# & 108.161^*^* & 1.0^*^* & 108.803^\#^\# & 3.5^\#^\# \\
# \hline
# puppet.csv & 36.972^\# & 1.5^\# & 28.742^\wedge & 8.0^\wedge & 27.719^\wedge & 8.0^\wedge \\
# \hline
# sufia.csv & 50.288^\# & 1.0^\# & 51.883^\#^\# & 3.0^\#^\# & 48.25^\#^\# & 3.0^\#^\# \\
# \hline
# open-build-service.csv & 68.407^\# & 1.0^\# & 75.323^*^* & 1.0^*^* & 73.197^\#^\# & 3.0^\#^\# \\
# \hline
# heroku.csv & 48.39^\# & 1.0^\# & 53.484^\# & 1.0^\# & 51.177^\#^\# & 3.0^\#^\# \\
# \hline
# jruby.csv & 101.221^\# & 1.0^\# & 111.338^*^* & 1.0^*^* & 111.725^\#^\# & 3.0^\#^\# \\
# \hline
# orbeon-forms.csv & 80.499^\# & 2.0^\# & 91.543^*^* & 1.0^*^* & 86.969^\#^\# & 3.0^\#^\# \\
# \hline
# rubinius.csv & 80.39^\# & 1.0^\# & 84.512^*^* & 1.0^*^* & 89.058^\#^\# & 3.0^\#^\# \\
# \hline
# gradle.csv & 35.071^\# & 2.0^\# & 35.716^\#^\# & 3.0^\#^\# & 34.258^\#^\# & 3.0^\#^\# \\
# \hline
# rails.csv & 74.121^\# & 1.0^\# & 85.068^*^* & 1.0^*^* & 77.263^\#^\# & 3.0^\#^\# \\
# \hline
# metasploit-framework.csv & 35.961^\# & 1.0^\# & 28.829^\wedge & 8.0^\wedge & 28.066^\wedge & 8.0^\wedge \\
# \hline
# fog.csv & 73.554^\# & 1.0^\# & 79.59^*^* & 1.0^*^* & 82.824^\#^\# & 4.0^\#^\# \\
# \hline
# cloud_controller_ng.csv & 70.129^\# & 2.0^\# & 71.381^*^* & 1.0^*^* & 74.969^\#^\# & 3.0^\#^\# \\
# \hline
# opal.csv & 39.028^\# & 2.0^\# & 40.417^\# & 2.0^\# & 38.912^\#^\# & 3.0^\#^\# \\
# \hline
# cloudify.csv & 51.714^\# & 2.0^\# & 55.496^\wedge & 8.0^\wedge & 48.12^\#^\# & 4.0^\#^\# \\
# \hline
# graylog2-server.csv & 32.448^\# & 2.0^\# & 20.778^\wedge & 8.0^\wedge & 20.209^\wedge & 8.0^\wedge \\
# \hline
