# %%
import pandas as pd
import numpy as np
from numpy import argmax
from numpy import sqrt
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.utils import resample
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from matplotlib import pyplot
from statistics import median
import pickle
import csv
import warnings
import datetime
import multiprocess
warnings.filterwarnings("ignore")

# %%
project_list = ['geoserver', 'gradle', 'cloud_controller_ng', 'opal', 'jruby', 'cloudify', 'chef', 'orbeon-forms', 'vagrant']

# %%
def output_values(Y_data):
    Y_t = []
    for e in Y_data:
        if e == 'passed':
            Y_t.append(1)
        else:
            Y_t.append(0) 
    return Y_t

# %%
def get_pass_streak(y_project):
    p = y_project[0]
    pass_streak = [y_project[0]]
    for i in range(1, len(y_project)):
        pass_streak.append(p)
        if y_project[i] == 1:
            p += 1
        else:
            p = 0
    return pass_streak

# %%
def get_first_failures(df):
    
    results = df['tr_status'].tolist()
    length = len(results)
    verdict = ['keep']
    prev = results[0]
    
    for i in range(1, length):
        if results[i] == 0:
            if prev == 0:
                verdict.append('discard')
                #print(i+1)
            else:
                verdict.append('keep')
        else:
            verdict.append('keep')
        prev = results[i]
    
    df['verdict'] = verdict
    df = df[ df['verdict'] == 'keep' ]
    df.drop('verdict', inplace=True, axis=1)
    return df

# %%
def get_complete_data(p_name):
    
    #open the metrics file
    filename = 'metrics_data/' + p_name + '_metrics.csv'
    project = pd.read_csv(filename)
    
    #clean the data & remove correlated columns
    project = project [ project['developer_experience'] >= 0]
    project.drop('num_commits', inplace=True, axis=1)
    project.drop('reviewer_experience', inplace=True, axis=1)
    project.drop('num_of_reviewers', inplace=True, axis=1)
    
    build_ids = project['tr_build_id'].tolist()
    #get results data
    res_file = '../data/' + p_name + '.csv'
    res_project = pd.read_csv(res_file, usecols = ['tr_build_id', 'gh_build_started_at', 'tr_status'])
    res_project['gh_build_started_at'] =  pd.to_datetime(res_project['gh_build_started_at'], format='%Y-%m-%d %H:%M:%S')
    y_project = res_project[res_project['tr_build_id'].isin(build_ids)]['tr_status'].tolist()
    y_project = output_values(y_project)
    
    #append date of build
    project_dates = res_project[res_project['tr_build_id'].isin(build_ids)]['gh_build_started_at'].tolist()
    project['gh_build_started_at'] = project_dates
    
    #add results column to the dataframe
    project['tr_status'] = y_project
    
    return project

# %%
def get_start_end_date(project):
    dates = project['gh_build_started_at'].tolist()
    
    start_date = dates[0] - datetime.timedelta(days = 1)
    end_date = dates[-1] - datetime.timedelta(days = 1)
    
    return start_date, end_date

# %%
def get_required_data(p_name, build_ids):
    
    res_file = '../data/' + p_name + '.csv'
    res_project = pd.read_csv(res_file, usecols = ['tr_build_id', 'tr_duration'])
    durations = res_project[res_project['tr_build_id'].isin(build_ids)]['tr_duration'].tolist()
    return durations

# %%
def compute_performance(p_name, test_builds, test_result, pred_result):
    
    
    
    durations = get_required_data(p_name, test_builds)
    actual_duration = sum(durations)
    actual_failures = test_result.count(0)
    
    total_builds = len(test_builds)
    num_of_builds = 0
    total_duration = 0
    cbf = 0
    saved_builds = 0
    
    batch = []
    batch_duration = []
    actual_results = []
    max_batch_size = 4
    
    for i in range(len(pred_result)):
        if pred_result[i] == 0:
            
            if test_result[i] == 0:
                cbf += 1
                
            if len(batch) < max_batch_size:
                batch.append(pred_result[i])
                batch_duration.append(durations[i])
                actual_results.append(test_result[i])
            
            if len(batch) == max_batch_size:
                num_of_builds += 1
                total_duration += max(batch_duration)
                
                if 0 in actual_results:
                    num_of_builds += 4
                    total_duration += sum(batch_duration)
        else:
            saved_builds += 1
            
    if len(batch) > 0:
        num_of_builds += 1
        total_duration += max(batch_duration)
        
        if 0 in actual_results:
            num_of_builds += len(batch)
            total_duration += sum(batch_duration)
                    
    #Delay computation
    flag = 0
    count = 0
    delay = []
    for i in range(len(pred_result)):
        if flag == 1:
            if pred_result[i] == 1:
                count += 1
            
            if pred_result[i] == 0:
                delay.append(count)
                count = 0
                flag = 0
                
        if test_result[i] != 1:
            if pred_result[i] == 1:
                flag = 1
    delay.append(count)

    
    try:
        
        time_saved = 100*total_duration/actual_duration
        builds_saved = 100*saved_builds/total_builds
        reqd_builds = 100*num_of_builds/total_builds
        failed = 100*cbf/actual_failures
        median_delays = median(delay)
        total_delays = sum(delay)
    
#         print("===========================================")
#         print('The performance of the model is as follows:')
#         print('\t Time Reqd : {}'.format(total_duration))
#         print('\t % Time Reqd : {}%'.format(time_saved))
#         print('\t Num. Builds saved : {}%'.format(saved_builds))
#         print('\t % Builds saved : {}%'.format(builds_saved))
#         print('\t Num. Builds required : {}'.format(num_of_builds))
#         print('\t % Builds required : {}%'.format(reqd_builds))
#         print('\t Num. Failed Builds Identified : {}'.format(cbf))
#         print('\t % Failed Builds Identified : {}%'.format(failed))
#         print('\t Median Delay Induced : {} builds'.format(median_delays))
#         print('\t Total Delay Induced: {} builds'.format(total_delays))
#         print('\t Total number of builds: {}'.format(total_builds))
#         print('\t Total number of failed builds: {}'.format(actual_failures))
#         print('\t Total Duration: {}'.format(actual_duration))
#         print("===========================================")
        
    except:
        
#         print('exception')
        return (0, 0, 0, 0, 0, 0)
    
    return (time_saved, builds_saved, reqd_builds, failed, median_delays, total_delays)

# %%
def bootstrapping(p_name):
    performances = {'time_saved':[], 'builds_saved':[], 'builds_reqd':[], 'failed_builds':[], 'total_delay':[], 'median_delay':[]}
    print('Processing {}'.format(p_name))
    
    project = get_complete_data(p_name)
    start_date, end_date = get_start_end_date(project)
    
    n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
    max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
    
    param_grid = {'n_estimators': n_estimators, 'max_depth': max_depth}
    forest = RandomForestClassifier()
    grid_search = GridSearchCV(estimator = forest, param_grid = param_grid, cv = 3, n_jobs = -1, verbose = 0)
    
    phase = 1

    while start_date < end_date:
        
        train_period = 100
        test_period = 10
        
        while True:
            train_end = start_date + datetime.timedelta(days = train_period + 1)
            test_start = start_date + datetime.timedelta(days = train_period)
            test_end = test_start + datetime.timedelta(days = test_period)

            #getting data of train & test phase wise
            train_data = project[ (project['gh_build_started_at'] > start_date) & (project['gh_build_started_at'] < train_end)]
            test_data = project[ (project['gh_build_started_at'] > test_start) & (project['gh_build_started_at'] < test_end)]

            #getting 'y' data
            train_result = train_data['tr_status'].tolist()
            test_result = test_data['tr_status'].tolist()
            
            if len(train_result) > 100 and len(test_result) > 10 :
                break
            
            if test_end > end_date:
                break
                
            if len(train_result) <= 100:
                train_period += 20
            
            if len(test_result) <= 10:
                test_period += 20
                
            
        
        #dropping build start time column
        train_data.drop('gh_build_started_at', inplace=True, axis=1)
        test_data.drop('gh_build_started_at', inplace=True, axis=1)
        
        #add pass_streak to training data:
        train_data['num_of_passes'] = get_pass_streak(train_result)
        
        best_n_estimators = []
        best_max_depth = []
        
        best_f1 = 0
        best_f1_sample = 0
        best_f1_sample_result = 0
        best_f1_estimator = 0
        best_thresholds = []
        
#         train_result = train_data['tr_status']
        
#         train_data.drop('tr_status', inplace=True, axis=1)
#         train_data.drop('tr_status', inplace=True, axis=1)
        
#         test_data.drop('tr_build_id', inplace=True, axis=1)
#         test_data.drop('tr_build_id', inplace=True, axis=1)
        
#         grid_search.fit(train_data, train_result)
        
        #bootstrap 10 times
        for i in range(2):
            
            file_name = 'rq2_' + p_name + '_' + str(phase) + '_model_' + str(i+1) + '_model.pkl'
            
            while True:
                sample_train = resample(train_data, replace=True, n_samples=len(train_data))
                sample_train_result = sample_train['tr_status']

                build_ids = sample_train['tr_build_id'].tolist()
                sample_test = train_data [~train_data['tr_build_id'].isin(build_ids)] 
                sample_test_result = sample_test['tr_status']
                
                if len(sample_test_result) != 0:
                    break
            
            #dropping result column and build ids column
            sample_train.drop('tr_status', inplace=True, axis=1)
            sample_train.drop('tr_build_id', inplace=True, axis=1)
            sample_test.drop('tr_status', inplace=True, axis=1)
            sample_test.drop('tr_build_id', inplace=True, axis=1)
            
            #training
            grid_search.fit(sample_train, sample_train_result)
            sample_pred_vals = grid_search.predict_proba(sample_test)
            
#             print(sample_pred_vals)
            pred_vals = sample_pred_vals[:, 1]
            fpr, tpr, t = roc_curve(sample_test_result, pred_vals)
            gmeans = sqrt(tpr * (1-fpr))
            ix = argmax(gmeans)
            bt = t[ix]
            best_thresholds.append(bt)
            
            final_pred_result = []
            #threshold setting
            for j in range(len(pred_vals)):
                if pred_vals[j] > bt:
                    final_pred_result.append(1)
                else:
                    final_pred_result.append(0)
            
            try:
                accuracy = accuracy_score(sample_test_result, final_pred_result)
                precision = precision_score(sample_test_result, final_pred_result)
                recall = recall_score(sample_test_result, final_pred_result)
                confusion = confusion_matrix(sample_test_result, final_pred_result)
                auc_score = roc_auc_score(sample_test_result, final_pred_result)
                f1 = f1_score(sample_test_result, final_pred_result)
            except:
                print('')
    
            if f1 > best_f1:
                best_f1 = f1
                best_f1_sample = sample_train
                best_f1_sample_result = sample_train_result
                best_f1_estimator = grid_search.best_estimator_

            print(precision, recall, accuracy, f1, auc_score)
            best_n_estimators.append(grid_search.best_params_['n_estimators'])
            best_max_depth.append(grid_search.best_params_['max_depth'])
        
        #completed with bootstrapping 
        threshold = median(best_thresholds)
        n_estimator = median(best_n_estimators)
        max_depth = median(best_max_depth)
        #retrain on the best 
        forest = RandomForestClassifier(n_estimators=int(n_estimator), max_depth=int(max_depth))
        forest.fit(best_f1_sample, best_f1_sample_result)
        
        test_builds = test_data['tr_build_id'].tolist()
        test_data.drop('tr_build_id', inplace=True, axis=1)
        test_data.drop('tr_status', inplace=True, axis=1)
        
        final_pred_result = []
        queue = 0
        i = 0
        total = len(test_data)
        while i < total :
            data = test_data.iloc[i]
            data['num_of_passes'] = queue
            predict = forest.predict_proba([data])
            if predict[0][1] > threshold:
                final_pred_result.append(1)
                queue += 1
                i+=1
            else:
                final_pred_result.append(0)
                queue = 0
                i += 1
                
                
        print('Individual testing for {}....'.format(p_name))
        
        try:
            accuracy = accuracy_score(test_result, final_pred_result)
            precision = precision_score(test_result, final_pred_result)
            recall = recall_score(test_result, final_pred_result)
            confusion = confusion_matrix(test_result, final_pred_result)
            auc_score = roc_auc_score(test_result, final_pred_result)
            f1 = f1_score(test_result, final_pred_result)

#             print(precision, recall, accuracy, f1, auc_score)
#             print(confusion)
            
        except:
            print('')
        
        batch_performance = compute_performance(p_name, test_builds, test_result, final_pred_result)
        
        performances['time_saved'].append(batch_performance[0])
        performances['builds_saved'].append(batch_performance[1])
        performances['builds_reqd'].append(batch_performance[2])
        performances['failed_builds'].append(batch_performance[3])
        performances['median_delay'].append(batch_performance[4])
        performances['total_delay'].append(batch_performance[5])
        
        start_date = test_end
        phase += 1
    
    #Project Performance:
    
    print("Average Time Saved in {} = {}".format(p_name, sum(performances['time_saved'])/len(performances['time_saved'])))
    print("Average Builds Saved in {} = {}".format(p_name, sum(performances['builds_saved'])/len(performances['builds_saved'])))
    print("Average Builds Reqd in {} = {}".format(p_name, sum(performances['builds_reqd'])/len(performances['builds_reqd'])))
    print("Average Failed Identified in {} = {}".format(p_name, sum(performances['failed_builds'])/len(performances['failed_builds'])))
    print("Average Median Delay in {} = {}".format(p_name, sum(performances['median_delay'])/len(performances['median_delay'])))
    print("Average Total Delay in {} = {}".format(p_name, sum(performances['total_delay'])/len(performances['total_delay'])))
    
    print('\n\n\n\n\n')

# %%
jobs = []
for p_name in project_list:
    
    q = multiprocess.Process(target=bootstrapping, args=(p_name,))
    jobs.append(q)
    q.start()

for j in jobs:
    j.join()
# Out:
# Processing geoserver
# Processing gradle
# Processing cloud_controller_ng
# Processing opalProcessing jruby
#
# Processing cloudifyProcessing chef
#
# Processing orbeon-forms
# Processing vagrant
# 0.9047619047619048 0.9743589743589743 0.8863636363636364 0.9382716049382716 0.5871794871794871
# 0.9736842105263158 0.9736842105263158 0.95 0.9736842105263158 0.736842105263158
# 0.9310344827586207 0.7941176470588235 0.7567567567567568 0.8571428571428571 0.5637254901960784
# 0.8846153846153846 0.7796610169491526 0.7361111111111112 0.8288288288288288 0.6590612777053455
# 0.9318181818181818 0.7454545454545455 0.7638888888888888 0.8282828282828283 0.7844919786096257
# 0.7777777777777778 0.5526315789473685 0.6805555555555556 0.6461538461538462 0.6880804953560372
# 0.9222222222222223 0.8383838383838383 0.8067226890756303 0.8783068783068783 0.7441919191919192
# 0.9791666666666666 0.30128205128205127 0.3167701863354037 0.46078431372549017 0.5506410256410257
# 0.8636363636363636 0.8636363636363636 0.8392857142857143 0.8636363636363636 0.8339920948616601
#
# 0.0 0.0 0.0 0.9382716049382716 0.5871794871794871
# 0.0 0.0 0.02127659574468085 0.0 0.5
# Individual testing for opal....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 1875
# 	 % Time Reqd : 93.28358208955224%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 25
# 	 % Builds required : 92.5925925925926%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 27
# 	 Total number of failed builds: 1
# 	 Total Duration: 2010
# ===========================================
# 0.92 0.6216216216216216 0.627906976744186 0.7419354838709677 0.6441441441441442
# Individual testing for chef....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 145776
# 	 % Time Reqd : 207.2683842347722%
# 	 Num. Builds saved : 18%
# 	 % Builds saved : 50.0%
# 	 Num. Builds required : 80
# 	 % Builds required : 222.22222222222223%
# 	 Num. Failed Builds Identified : 4
# 	 % Failed Builds Identified : 80.0%
# 	 Median Delay Induced : 1.0 builds
# 	 Total Delay Induced: 2 builds
# 	 Total number of builds: 36
# 	 Total number of failed builds: 5
# 	 Total Duration: 70332
# ===========================================
# 0.9473684210526315 0.5217391304347826 0.5625 0.6728971962616822 0.6699604743083003
# 0.7796610169491526 0.92 0.7875 0.8440366972477064 0.7433333333333333
# Individual testing for orbeon-forms....
#
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 19071
# 	 % Time Reqd : 726.2376237623762%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 45
# 	 % Builds required : 409.09090909090907%
# 	 Num. Failed Builds Identified : 11
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 11
# 	 Total number of failed builds: 11
# 	 Total Duration: 2626
# ===========================================
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 218400
# 	 % Time Reqd : 409.4872035248898%
# 	 Num. Builds saved : 2%
# 	 % Builds saved : 5.555555555555555%
# 	 Num. Builds required : 160
# 	 % Builds required : 444.44444444444446%
# 	 Num. Failed Builds Identified : 6
# 	 % Failed Builds Identified : 85.71428571428571%
# 	 Median Delay Induced : 0.0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 36
# 	 Total number of failed builds: 7
# 	 Total Duration: 53335
# ===========================================
# Individual testing for vagrant....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 22176
# 	 % Time Reqd : 118.19005489527261%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 308
# 	 % Builds required : 99.35483870967742%
# 	 Num. Failed Builds Identified : 4
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 310
# 	 Total number of failed builds: 4
# 	 Total Duration: 18763
# ===========================================
# 0.72 0.46153846153846156 0.6111111111111112 0.5625 0.6247086247086248
# 1.0 0.37037037037037035 0.4 0.5405405405405406 0.6851851851851851
# 0.9380530973451328 0.9724770642201835 0.9230769230769231 0.954954954954955 0.8195718654434251
# Individual testing for jruby....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 0
# 	 % Time Reqd : 0.0%
# 	 Num. Builds saved : 19%
# 	 % Builds saved : 100.0%
# 	 Num. Builds required : 0
# 	 % Builds required : 0.0%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 12 builds
# 	 Total Delay Induced: 12 builds
# 	 Total number of builds: 19
# 	 Total number of failed builds: 6
# 	 Total Duration: 11214
# ===========================================
# Individual testing for gradle....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 706797
# 	 % Time Reqd : 409.3482138720289%
# 	 Num. Builds saved : 17%
# 	 % Builds saved : 12.5%
# 	 Num. Builds required : 585
# 	 % Builds required : 430.1470588235294%
# 	 Num. Failed Builds Identified : 2
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 136
# 	 Total number of failed builds: 2
# 	 Total Duration: 172664
# ===========================================
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 357150
# 	 % Time Reqd : 567.2288927005908%
# 	 Num. Builds saved : 3%
# 	 % Builds saved : 10.0%
# 	 Num. Builds required : 125
# 	 % Builds required : 416.6666666666667%
# 	 Num. Failed Builds Identified : 24
# 	 % Failed Builds Identified : 88.88888888888889%
# 	 Median Delay Induced : 0.0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 30
# 	 Total number of failed builds: 27
# 	 Total Duration: 62964
# ===========================================
# 0.885 0.917098445595855 0.8821752265861027 0.900763358778626 0.8752158894645943
# Individual testing for cloudify....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 0
# 	 % Time Reqd : 0.0%
# 	 Num. Builds saved : 76%
# 	 % Builds saved : 100.0%
# 	 Num. Builds required : 0
# 	 % Builds required : 0.0%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 72 builds
# 	 Total Delay Induced: 72 builds
# 	 Total number of builds: 76
# 	 Total number of failed builds: 19
# 	 Total Duration: 24352
# ===========================================
# 0.0 0.0 0.02857142857142857 0.0 0.5
# 0.927710843373494 0.7129629629629629 0.7063492063492064 0.8062827225130891 0.6898148148148148
# 0.92 0.9583333333333334 0.9411764705882353 0.9387755102040817 0.9421296296296298
# Process Process-18:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_37385/690140083.py", line 102, in bootstrapping
#     pred_vals = sample_pred_vals[:, 1]
# IndexError: index 1 is out of bounds for axis 1 with size 1
# 0.8055555555555556 0.43283582089552236 0.47674418604651164 0.5631067961165048 0.5322073841319717
# 0.7619047619047619 0.6857142857142857 0.6442307692307693 0.7218045112781954 0.6222689075630252
# 0.19230769230769232 0.8333333333333334 0.6666666666666666 0.3125 0.7416666666666668
# 0.9679144385026738 0.9526315789473684 0.9253731343283582 0.9602122015915119 0.7035885167464115
# 0.0 0.0 0.023255813953488372 0.0 0.5
# Process Process-16:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_37385/690140083.py", line 143, in bootstrapping
#     forest.fit(best_f1_sample, best_f1_sample_result)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 327, in fit
#     X, y = self._validate_data(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/base.py", line 576, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/utils/validation.py", line 956, in check_X_y
#     X = check_array(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/utils/validation.py", line 753, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got scalar array instead:
# array=0.0.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# 0.9446808510638298 0.925 0.8938356164383562 0.9347368421052632 0.8375
# 0.8888888888888888 0.9411764705882353 0.9285714285714286 0.9142857142857143 0.9305882352941176
# Individual testing for orbeon-forms....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 0
# 	 % Time Reqd : 0.0%
# 	 Num. Builds saved : 53%
# 	 % Builds saved : 100.0%
# 	 Num. Builds required : 0
# 	 % Builds required : 0.0%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 14 builds
# 	 Total Delay Induced: 14 builds
# 	 Total number of builds: 53
# 	 Total number of failed builds: 3
# 	 Total Duration: 36434
# ===========================================
# 0.96 0.42857142857142855 0.472 0.5925925925925924 0.6373626373626373
# Individual testing for opal....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 5200
# 	 % Time Reqd : 165.4996817313813%
# 	 Num. Builds saved : 2%
# 	 % Builds saved : 8.333333333333334%
# 	 Num. Builds required : 20
# 	 % Builds required : 83.33333333333333%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 24
# 	 Total number of failed builds: 1
# 	 Total Duration: 3142
# ===========================================
# 0.7096774193548387 0.36666666666666664 0.4125 0.48351648351648346 0.45833333333333337
# 0.125 0.25 0.8360655737704918 0.16666666666666666 0.5635964912280702
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 92912
# 	 % Time Reqd : 192.17738432581132%
# 	 Num. Builds saved : 7%
# 	 % Builds saved : 53.84615384615385%
# 	 Num. Builds required : 20
# 	 % Builds required : 153.84615384615384%
# 	 Num. Failed Builds Identified : 3
# 	 % Failed Builds Identified : 50.0%
# 	 Median Delay Induced : 0.5 builds
# 	 Total Delay Induced: 1 builds
# 	 Total number of builds: 13
# 	 Total number of failed builds: 6
# 	 Total Duration: 48347
# ===========================================
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 153576
# 	 % Time Reqd : 117.4739161031729%
# 	 Num. Builds saved : 5%
# 	 % Builds saved : 14.705882352941176%
# 	 Num. Builds required : 27
# 	 % Builds required : 79.41176470588235%
# 	 Num. Failed Builds Identified : 10
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 34
# 	 Total number of failed builds: 10
# 	 Total Duration: 130732
# ===========================================
# 0.75 0.42857142857142855 0.5132743362831859 0.5454545454545454 0.5615079365079365
# 0.9735449735449735 0.9292929292929293 0.9090909090909091 0.9509043927648578 0.7373737373737373
# Individual testing for gradle....
#
# exception
# Average Time Saved in gradle = 204.67410693601445
# Average Builds Saved in gradle = 6.25
# Average Builds Reqd in gradle = 215.0735294117647
# Average Failed Identified in gradle = 50.0
# Average Median Delay in gradle = 0.0
# Average Total Delay in gradle = 0.0
#
#
#
#
#
#
# Individual testing for jruby....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 271600
# 	 % Time Reqd : 594.1807044410414%
# 	 Num. Builds saved : 4%
# 	 % Builds saved : 8.695652173913043%
# 	 Num. Builds required : 200
# 	 % Builds required : 434.7826086956522%
# 	 Num. Failed Builds Identified : 16
# 	 % Failed Builds Identified : 88.88888888888889%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 46
# 	 Total number of failed builds: 18
# 	 Total Duration: 45710
# ===========================================
# 0.96 0.42857142857142855 0.484375 0.5925925925925924 0.6517857142857143
# 0.9666666666666667 0.8877551020408163 0.8627450980392157 0.9255319148936171 0.5688775510204082
# 0.9469387755102041 0.9469387755102041 0.910958904109589 0.9469387755102041 0.8351715154146765
# Individual testing for cloudify....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 1081
# 	 % Time Reqd : 4.391809539286585%
# 	 Num. Builds saved : 31%
# 	 % Builds saved : 91.17647058823529%
# 	 Num. Builds required : 4
# 	 % Builds required : 11.764705882352942%
# 	 Num. Failed Builds Identified : 2
# 	 % Failed Builds Identified : 40.0%
# 	 Median Delay Induced : 29 builds
# 	 Total Delay Induced: 29 builds
# 	 Total number of builds: 34
# 	 Total number of failed builds: 5
# 	 Total Duration: 24614
# ===========================================
# 0.6470588235294118 0.4074074074074074 0.5686274509803921 0.5 0.5787037037037037
# 0.7727272727272727 0.7846153846153846 0.6914893617021277 0.7786259541984732 0.6336870026525199
# 0.47368421052631576 0.8181818181818182 0.7142857142857143 0.6 0.747800586510264
# 0.9736842105263158 0.7551020408163265 0.7592592592592593 0.8505747126436782 0.7775510204081633
# Individual testing for orbeon-forms....
#
# exception
# 0.9482758620689655 0.625 0.6210526315789474 0.7534246575342466 0.5982142857142857
# Individual testing for opal....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 4308
# 	 % Time Reqd : 145.05050505050505%
# 	 Num. Builds saved : 7%
# 	 % Builds saved : 53.84615384615385%
# 	 Num. Builds required : 20
# 	 % Builds required : 153.84615384615384%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 13
# 	 Total number of failed builds: 1
# 	 Total Duration: 2970
# ===========================================
# 0.5675675675675675 0.75 0.603448275862069 0.6461538461538462 0.6083333333333334
# 1.0 0.7808988764044944 0.7914438502673797 0.8769716088328076 0.8904494382022472
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 28860
# 	 % Time Reqd : 60.79116990352614%
# 	 Num. Builds saved : 9%
# 	 % Builds saved : 52.94117647058823%
# 	 Num. Builds required : 6
# 	 % Builds required : 35.294117647058826%
# 	 Num. Failed Builds Identified : 3
# 	 % Failed Builds Identified : 30.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 3 builds
# 	 Total number of builds: 17
# 	 Total number of failed builds: 10
# 	 Total Duration: 47474
# ===========================================
# 0.7910447761194029 0.6625 0.6203703703703703 0.7210884353741497 0.58125
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 23590
# 	 % Time Reqd : 32.48282224639577%
# 	 Num. Builds saved : 13%
# 	 % Builds saved : 59.09090909090909%
# 	 Num. Builds required : 7
# 	 % Builds required : 31.818181818181817%
# 	 Num. Failed Builds Identified : 2
# 	 % Failed Builds Identified : 66.66666666666667%
# 	 Median Delay Induced : 2.5 builds
# 	 Total Delay Induced: 5 builds
# 	 Total number of builds: 22
# 	 Total number of failed builds: 3
# 	 Total Duration: 72623
# ===========================================
# 0.6 0.75 0.7692307692307693 0.6666666666666665 0.763888888888889
# Individual testing for jruby....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 2291562
# 	 % Time Reqd : 184.1718558619958%
# 	 Num. Builds saved : 176%
# 	 % Builds saved : 59.66101694915254%
# 	 Num. Builds required : 585
# 	 % Builds required : 198.3050847457627%
# 	 Num. Failed Builds Identified : 54
# 	 % Failed Builds Identified : 34.177215189873415%
# 	 Median Delay Induced : 2.5 builds
# 	 Total Delay Induced: 144 builds
# 	 Total number of builds: 295
# 	 Total number of failed builds: 158
# 	 Total Duration: 1244252
# ===========================================
# 1.0 0.8780487804878049 0.8863636363636364 0.9350649350649352 0.9390243902439024
# 0.96875 0.6458333333333334 0.6635514018691588 0.775 0.7320075757575758
# 0.9936708860759493 0.8092783505154639 0.8118811881188119 0.8920454545454546 0.842139175257732
# 0.34210526315789475 0.5909090909090909 0.6382978723404256 0.43333333333333335 0.6218434343434344
# 0.8222222222222222 0.5606060606060606 0.5697674418604651 0.6666666666666666 0.5803030303030303
# Individual testing for cloudify....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 99799
# 	 % Time Reqd : 119.69895052473763%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 53
# 	 % Builds required : 96.36363636363636%
# 	 Num. Failed Builds Identified : 46
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 55
# 	 Total number of failed builds: 46
# 	 Total Duration: 83375
# ===========================================
# 0.6527777777777778 0.7121212121212122 0.6271186440677966 0.6811594202898551 0.6156759906759907
# 1.0 0.9787234042553191 0.9791666666666666 0.989247311827957 0.9893617021276595
# Individual testing for orbeon-forms....
#
# exception
# 0.34210526315789475 0.5909090909090909 0.6263736263736264 0.43333333333333335 0.6142951251646903
# 0.9647887323943662 0.6372093023255814 0.6422413793103449 0.7675070028011204 0.6715458276333789
# 0.90625 0.6987951807228916 0.6736842105263158 0.7891156462585034 0.5993975903614458
# Individual testing for opal....
#
# exception
# Individual testing for geoserver....
#
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 289464
# 	 % Time Reqd : 373.18893830980466%
# 	 Num. Builds saved : 1%
# 	 % Builds saved : 6.666666666666667%
# 	 Num. Builds required : 60
# 	 % Builds required : 400.0%
# 	 Num. Failed Builds Identified : 14
# 	 % Failed Builds Identified : 93.33333333333333%
# 	 Median Delay Induced : 0.0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 15
# 	 Total number of failed builds: 15
# 	 Total Duration: 77565
# ===========================================
# 0.9530201342281879 0.9793103448275862 0.954337899543379 0.9659863945578231 0.9423578751164958
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 527816
# 	 % Time Reqd : 280.405667444072%
# 	 Num. Builds saved : 19%
# 	 % Builds saved : 34.54545454545455%
# 	 Num. Builds required : 170
# 	 % Builds required : 309.09090909090907%
# 	 Num. Failed Builds Identified : 6
# 	 % Failed Builds Identified : 75.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 3 builds
# 	 Total number of builds: 55
# 	 Total number of failed builds: 8
#
# 	 Total Duration: 188233===========================================
# 0.704225352112676 0.6944444444444444 0.6446280991735537 0.6993006993006993 0.6329365079365079
# Individual testing for jruby....
# 0.9444444444444444 0.918918918918919 0.8958333333333334 0.9315068493150684 0.8685503685503685
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 36305
# 	 % Time Reqd : 15.882702924989719%
# 	 Num. Builds saved : 29%
# 	 % Builds saved : 80.55555555555556%
# 	 Num. Builds required : 5
# 	 % Builds required : 13.88888888888889%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 22 builds
# 	 Total Delay Induced: 22 builds
# 	 Total number of builds: 36
# 	 Total number of failed builds: 16
# 	 Total Duration: 228582
# ===========================================
# 0.9743589743589743 0.9743589743589743 0.9512195121951219 0.9743589743589743 0.7371794871794872
# 0.29411764705882354 0.6666666666666666 0.6588235294117647 0.40816326530612246 0.6619047619047619
# 0.8636363636363636 0.59375 0.6 0.7037037037037037 0.609375
# 0.9343065693430657 0.9696969696969697 0.9359605911330049 0.9516728624535317 0.921468203158344
# Individual testing for cloudify....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 43260
# 	 % Time Reqd : 37.32141624680792%
# 	 Num. Builds saved : 77%
# 	 % Builds saved : 89.53488372093024%
# 	 Num. Builds required : 35
# 	 % Builds required : 40.69767441860465%
# 	 Num. Failed Builds Identified : 9
# 	 % Failed Builds Identified : 19.565217391304348%
# 	 Median Delay Induced : 76 builds
# 	 Total Delay Induced: 76 builds
# 	 Total number of builds: 86
# 	 Total number of failed builds: 46
# 	 Total Duration: 115912
# ===========================================
# 0.9411764705882353 0.9411764705882353 0.92 0.9411764705882353 0.9080882352941176
# Individual testing for orbeon-forms....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 108562
# 	 % Time Reqd : 710.0660605664203%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 155
# 	 % Builds required : 469.6969696969697%
# 	 Num. Failed Builds Identified : 31
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 33
# 	 Total number of failed builds: 31
# 	 Total Duration: 15289
# ===========================================
# 0.6610169491525424 0.78 0.7960526315789473 0.7155963302752293 0.7919607843137255
# 0.9666666666666667 0.6744186046511628 0.6739130434782609 0.7945205479452055 0.6705426356589147
# Individual testing for opal....
#
# exception
# 0.3181818181818182 0.5384615384615384 0.72 0.39999999999999997 0.6482630272952853
# Individual testing for geoserver....
#
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 295784
# 	 % Time Reqd : 341.6940067464535%
# 	 Num. Builds saved : 4%
# 	 % Builds saved : 28.571428571428573%
# 	 Num. Builds required : 40
# 	 % Builds required : 285.7142857142857%
# 	 Num. Failed Builds Identified : 10
# 	 % Failed Builds Identified : 71.42857142857143%
# 	 Median Delay Induced : 1.0 builds
# 	 Total Delay Induced: 2 builds
# 	 Total number of builds: 14
# 	 Total number of failed builds: 14
# 	 Total Duration: 86564
# ===========================================
# 0.8679245283018868 0.4791666666666667 0.525 0.6174496644295302 0.59375
# Individual testing for cloud_controller_ng....
#
# exception
# 0.0 0.0 0.02880658436213992 0.0 0.5
# 0.7777777777777778 0.8235294117647058 0.851063829787234 0.7999999999999999 0.8450980392156863
# 0.7291666666666666 0.7 0.8133333333333334 0.7142857142857142 0.7849999999999999
# 1.0 0.875 0.8780487804878049 0.9333333333333333 0.9375
# Individual testing for jruby....
#
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 538688
# 	 % Time Reqd : 395.10924973778594%
# 	 Num. Builds saved : 6%
# 	 % Builds saved : 25.0%
# 	 Num. Builds required : 80
# 	 % Builds required : 333.3333333333333%
# 	 Num. Failed Builds Identified : 18
# 	 % Failed Builds Identified : 75.0%
# 	 Median Delay Induced : 2.5 builds
# 	 Total Delay Induced: 5 builds
# 	 Total number of builds: 24
# 	 Total number of failed builds: 24
# 	 Total Duration: 136339
# ===========================================
# 0.7254901960784313 0.6851851851851852 0.6125 0.7047619047619048 0.5733618233618234
# 0.9230769230769231 0.75 0.726027397260274 0.8275862068965517 0.6527777777777778
# 0.994475138121547 0.7377049180327869 0.7410358565737052 0.8470588235294118 0.7974238875878221
# Individual testing for cloudify....
#
# exception
# 1.0 0.8571428571428571 0.9285714285714286 0.923076923076923 0.9285714285714286
# Individual testing for orbeon-forms....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 22168
# 	 % Time Reqd : 99.9684329199549%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 17
# 	 % Builds required : 89.47368421052632%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 19
# 	 Total number of failed builds: 1
# 	 Total Duration: 22175
# ===========================================
# 1.0 0.6904761904761905 0.7111111111111111 0.8169014084507042 0.8452380952380952
# Process Process-14:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_37385/690140083.py", line 102, in bootstrapping
#     pred_vals = sample_pred_vals[:, 1]
# IndexError: index 1 is out of bounds for axis 1 with size 1
# Individual testing for opal....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 22154
# 	 % Time Reqd : 104.48028673835125%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 38
# 	 % Builds required : 95.0%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 40
# 	 Total number of failed builds: 1
# 	 Total Duration: 21204
# ===========================================
# 0.74 0.74 0.6486486486486487 0.74 0.5991666666666667
# 0.9387755102040817 0.6216216216216216 0.6352941176470588 0.7479674796747967 0.6744471744471744
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 0
# 	 % Time Reqd : 0.0%
# 	 Num. Builds saved : 14%
# 	 % Builds saved : 100.0%
# 	 Num. Builds required : 0
# 	 % Builds required : 0.0%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 5 builds
# 	 Total Delay Induced: 5 builds
# 	 Total number of builds: 14
# 	 Total number of failed builds: 1
# 	 Total Duration: 85274
# ===========================================
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 194496
# 	 % Time Reqd : 421.50705415772705%
# 	 Num. Builds saved : 2%
# 	 % Builds saved : 10.0%
# 	 Num. Builds required : 80
# 	 % Builds required : 400.0%
# 	 Num. Failed Builds Identified : 2
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 20
# 	 Total number of failed builds: 2
# 	 Total Duration: 46143
# ===========================================
# 0.9946808510638298 0.9396984924623115 0.9368932038834952 0.9664082687338502 0.8984206748025844
# 0.782608695652174 0.5454545454545454 0.6774193548387096 0.6428571428571429 0.6865203761755486
# 1.0 0.8857142857142857 0.8888888888888888 0.9393939393939393 0.9428571428571428
# 0.8620689655172413 0.704225352112676 0.6627906976744186 0.7751937984496124 0.5854460093896714
# 0.8857142857142857 0.44285714285714284 0.4819277108433735 0.5904761904761905 0.5675824175824176
# 0.7777777777777778 0.7777777777777778 0.7538461538461538 0.7777777777777778 0.7509578544061303
# 0.9952380952380953 0.9812206572769953 0.9769585253456221 0.9881796690307328 0.8656103286384976
# Individual testing for orbeon-forms....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 0
# 	 % Time Reqd : 0.0%
# 	 Num. Builds saved : 16%
# 	 % Builds saved : 100.0%
# 	 Num. Builds required : 0
# 	 % Builds required : 0.0%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 11 builds
# 	 Total Delay Induced: 11 builds
# 	 Total number of builds: 16
# 	 Total number of failed builds: 6
# 	 Total Duration: 31638
# ===========================================
# Individual testing for cloudify....
#
# exception
#
# 0.0 0.0 0.0 0.9393939393939393 0.9428571428571428
# Individual testing for opal....
#
# exception
# 0.868421052631579 0.5 0.525 0.6346153846153846 0.5714285714285714
# 0.8518518518518519 0.696969696969697 0.6455696202531646 0.7666666666666667 0.5407925407925408
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 99960
# 	 % Time Reqd : 127.44960538562559%
# 	 Num. Builds saved : 25%
# 	 % Builds saved : 73.52941176470588%
# 	 Num. Builds required : 35
# 	 % Builds required : 102.94117647058823%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 25.0%
# 	 Median Delay Induced : 3.0 builds
# 	 Total Delay Induced: 6 builds
# 	 Total number of builds: 34
# 	 Total number of failed builds: 4
# 	 Total Duration: 78431
# ===========================================
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 349299
# 	 % Time Reqd : 141.85479842590675%
# 	 Num. Builds saved : 19%
# 	 % Builds saved : 63.333333333333336%
# 	 Num. Builds required : 45
# 	 % Builds required : 150.0%
# 	 Num. Failed Builds Identified : 5
# 	 % Failed Builds Identified : 55.55555555555556%
# 	 Median Delay Induced : 1.0 builds
# 	 Total Delay Induced: 9 builds
# 	 Total number of builds: 30
# 	 Total number of failed builds: 9
# 	 Total Duration: 246237
# ===========================================
# 0.75 0.5454545454545454 0.8157894736842105 0.631578947368421 0.7356902356902357
#
# 0.0 0.0 0.0 0.9881796690307328 0.8656103286384976
# 0.0 0.0 0.04 0.0 0.5
# 0.8823529411764706 0.5 0.5321100917431193 0.6382978723404256 0.5921052631578948
# 0.92 0.36507936507936506 0.4166666666666667 0.5227272727272727 0.5714285714285714
# 0.5 0.8571428571428571 0.8 0.631578947368421 0.8214285714285714
#
# 0.0 0.0 0.0 0.9881796690307328 0.8656103286384976
# Individual testing for cloudify....
#
# exception
# Average Time Saved in cloudify = 23.058882330118877
# Average Builds Saved in cloudify = 40.101622044166504
# Average Builds Reqd in cloudify = 21.260859523513425
# Average Failed Identified in cloudify = 22.79503105590062
# Average Median Delay in cloudify = 25.285714285714285
# Average Total Delay in cloudify = 25.285714285714285
#
#
#
#
#
#
# Individual testing for orbeon-forms....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 174944
# 	 % Time Reqd : 272.45600373773556%
# 	 Num. Builds saved : 0%
# 	 % Builds saved : 0.0%
# 	 Num. Builds required : 160
# 	 % Builds required : 470.5882352941176%
# 	 Num. Failed Builds Identified : 17
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 34
# 	 Total number of failed builds: 17
# 	 Total Duration: 64210
# ===========================================
# 0.0 0.0 0.043478260869565216 0.0 0.5
# Process Process-13:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_37385/690140083.py", line 143, in bootstrapping
#     forest.fit(best_f1_sample, best_f1_sample_result)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 327, in fit
#     X, y = self._validate_data(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/base.py", line 576, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/utils/validation.py", line 956, in check_X_y
#     X = check_array(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/utils/validation.py", line 753, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got scalar array instead:
# array=0.0.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# 0.9545454545454546 0.2916666666666667 0.35 0.4468085106382979 0.5833333333333334
# 0.8627450980392157 0.4835164835164835 0.5 0.6197183098591549 0.5358758888170653
#
# 0.0 0.0 1.0 0.0 0.5
# Individual testing for cloud_controller_ng....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 12680
# 	 % Time Reqd : 21.680402147522486%
# 	 Num. Builds saved : 15%
# 	 % Builds saved : 71.42857142857143%
# 	 Num. Builds required : 4
# 	 % Builds required : 19.047619047619047%
# 	 Num. Failed Builds Identified : 0
# 	 % Failed Builds Identified : 0.0%
# 	 Median Delay Induced : 1.0 builds
# 	 Total Delay Induced: 2 builds
# 	 Total number of builds: 21
# 	 Total number of failed builds: 2
# 	 Total Duration: 58486
# ===========================================
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 135792
# 	 % Time Reqd : 208.76302924084493%
# 	 Num. Builds saved : 4%
# 	 % Builds saved : 9.523809523809524%
# 	 Num. Builds required : 36
# 	 % Builds required : 85.71428571428571%
# 	 Num. Failed Builds Identified : 32
# 	 % Failed Builds Identified : 96.96969696969697%
# 	 Median Delay Induced : 0.0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 42
# 	 Total number of failed builds: 33
# 	 Total Duration: 65046
# ===========================================
# 0.0 0.0 0.9761904761904762 0.0 0.5
# Process Process-17:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_37385/690140083.py", line 143, in bootstrapping
#     forest.fit(best_f1_sample, best_f1_sample_result)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 327, in fit
#     X, y = self._validate_data(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/base.py", line 576, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/utils/validation.py", line 956, in check_X_y
#     X = check_array(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/utils/validation.py", line 753, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got scalar array instead:
# array=0.0.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# 0.8888888888888888 0.7058823529411765 0.675 0.7868852459016393 0.6029411764705883
# 0.9032258064516129 0.8 0.8412698412698413 0.8484848484848486 0.8464285714285714
# 0.9375 0.42857142857142855 0.46153846153846156 0.588235294117647 0.5892857142857143
# Individual testing for cloud_controller_ng....
#
# exception
# Average Time Saved in cloud_controller_ng = 156.72074122326728
# Average Builds Saved in cloud_controller_ng = 29.87286497090419
# Average Builds Reqd in cloud_controller_ng = 154.0837883975139
# Average Failed Identified in cloud_controller_ng = 50.264550264550266
# Average Median Delay in cloud_controller_ng = 0.7222222222222222
# Average Total Delay in cloud_controller_ng = 1.7777777777777777
#
#
#
#
#
#
# 0.8918918918918919 0.8048780487804879 0.8064516129032258 0.8461538461538461 0.8072009291521487
# Individual testing for geoserver....
# ===========================================
# The performance of the model is as follows:
# 	 Time Reqd : 8477
# 	 % Time Reqd : 35.18011288180611%
# 	 Num. Builds saved : 8%
# 	 % Builds saved : 72.72727272727273%
# 	 Num. Builds required : 4
# 	 % Builds required : 36.36363636363637%
# 	 Num. Failed Builds Identified : 1
# 	 % Failed Builds Identified : 100.0%
# 	 Median Delay Induced : 0 builds
# 	 Total Delay Induced: 0 builds
# 	 Total number of builds: 11
# 	 Total number of failed builds: 1
# 	 Total Duration: 24096
# ===========================================
# 0.9375 0.6818181818181818 0.7333333333333333 0.7894736842105263 0.7784090909090908
# 0.8181818181818182 0.72 0.65625 0.7659574468085107 0.5742857142857143
# Individual testing for geoserver....
#
# exception
# Average Time Saved in geoserver = 192.0878332534744
# Average Builds Saved in geoserver = 39.76098411392529
# Average Builds Reqd in geoserver = 156.35991459520872
# Average Failed Identified in geoserver = 58.61760461760461
# Average Median Delay in geoserver = 0.75
# Average Total Delay in geoserver = 2.0

# %% [raw]
# Training days = 100, testing days = 10
# Average Time Saved in gradle = 204.67410693601445
# Average Builds Saved in gradle = 6.25
# Average Builds Reqd in gradle = 215.0735294117647
# Average Failed Identified in gradle = 50.0
# Average Median Delay in gradle = 0.0
# Average Total Delay in gradle = 0.0

# %% [raw]
# Training days = 100, testing days = 10
# Average Time Saved in cloudify = 23.058882330118877
# Average Builds Saved in cloudify = 40.101622044166504
# Average Builds Reqd in cloudify = 21.260859523513425
# Average Failed Identified in cloudify = 22.79503105590062
# Average Median Delay in cloudify = 25.285714285714285
# Average Total Delay in cloudify = 25.285714285714285

# %% [raw]
# Training days = 100, testing days = 10
# Average Time Saved in cloud_controller_ng = 156.72074122326728
# Average Builds Saved in cloud_controller_ng = 29.87286497090419
# Average Builds Reqd in cloud_controller_ng = 154.0837883975139
# Average Failed Identified in cloud_controller_ng = 50.264550264550266
# Average Median Delay in cloud_controller_ng = 0.7222222222222222
# Average Total Delay in cloud_controller_ng = 1.7777777777777777

# %% [raw]
# Training days = 100, testing days = 10
# Average Time Saved in geoserver = 192.0878332534744
# Average Builds Saved in geoserver = 39.76098411392529
# Average Builds Reqd in geoserver = 156.35991459520872
# Average Failed Identified in geoserver = 58.61760461760461
# Average Median Delay in geoserver = 0.75
# Average Total Delay in geoserver = 2.0

# %%
for q in jobs:
    q.terminate()
