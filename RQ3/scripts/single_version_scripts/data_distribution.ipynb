# %%
import pandas as pd

# %%
data_file = open('data/datasets/list', 'r')
projects = data_file.read().split('\n')

# %%
path = 'data/datasets/all_datasets/'

# %%
distributions = {}

# %%
for p in projects:
    print(p)
    file_path = path + p
    p_data = pd.read_csv(file_path)
    outcomes = p_data['tr_status'].tolist()
    total = len(outcomes)
    passes = outcomes.count('passed')
    failures = total - passes
    ratio = passes/total
# Out:
# 0      failed
# 1      failed
# 2      failed
# 3      failed
# 4      failed
#         ...
# 374    failed
# 375    failed
# 376    failed
# 377    failed
# 378    failed
# Name: tr_status, Length: 379, dtype: object
# 0      failed
# 1      failed
# 2      passed
# 3      passed
# 4      passed
#         ...
# 316    passed
# 317    passed
# 318    passed
# 319    passed
# 320    passed
# Name: tr_status, Length: 321, dtype: object
# 0     passed
# 1     failed
# 2     failed
# 3     failed
# 4     failed
#        ...
# 66    failed
# 67    failed
# 68    failed
# 69    passed
# 70    passed
# Name: tr_status, Length: 71, dtype: object
# 0      passed
# 1      passed
# 2      passed
# 3      passed
# 4      passed
#         ...
# 111    passed
# 112    passed
# 113    passed
# 114    passed
# 115    passed
# Name: tr_status, Length: 116, dtype: object
# 0      failed
# 1      passed
# 2      passed
# 3      passed
# 4      passed
#         ...
# 99     passed
# 100    passed
# ...
