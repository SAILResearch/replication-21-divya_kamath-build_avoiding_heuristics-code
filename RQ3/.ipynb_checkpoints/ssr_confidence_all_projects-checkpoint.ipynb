# %%
import pandas as pd
from statistics import mean, median
import sys
import pprint

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
ssr_result_file = '../RQ2/ssr_final_results.csv'

# %%
batch_sizes = [1, 2, 4, 8, 16]
batching_alg = ['BATCH4', 'BATCHBISECT', 'BATCHSTOP4']

# %%
projects = {'sonarqube.csv', 'geoserver.csv', 'jruby.csv', 'vagrant.csv', 'cloud_controller_ng.csv', 'graylog2-server.csv', 'rails.csv', 'puppet.csv', 'fog.csv', 'rubinius.csv', 'sufia.csv', 'orbeon-forms.csv', 'opal.csv', 'gradle.csv', 'heroku.csv', 'cloudify.csv', 'metasploit-framework.csv', 'open-build-service.csv', 'loomio.csv', 'concerto.csv'}

# %%
def str_to_list(s):
    if s == '[]':
        return [0]
    l = s[1:-1].split(', ')
    l = [int(x) for x in l]
    return l

# %%
def get_results(results):
    l = []
    
    for r in results:
        if r == 'passed':
            l.append(1)
        else:
            l.append(0)
            
    return l

# %%
ssr_delay_lib = {}
for p in projects:
    ssr_delay_lib[p] = {'BATCHSTOP4':{4:{}, 8:{}, 16:{}}, 'BATCH4':{4:{}}, 'BATCHBISECT':{1:{}, 2:{}, 4:{}, 8:{}, 16:{}}}

# %%
ssr_results = pd.read_csv(ssr_result_file)
project_test_file = {}

# %%
for p in projects:
    
    test_file = pd.read_csv('../data/test_data/'+p.split('.')[0]+'_test.csv')
    y_test = get_results(test_file['tr_status'].tolist())
    project_test_file[p] = y_test

# %%
for x in range(len(ssr_results)):
    row = ssr_results.iloc[x]
    ci = str_to_list(row['ci'])
    b = row['batch_size'] - 1
    
    y_test = project_test_file[row['project']+'.csv']
    
    i = 0        
    delay_list = []
    missed = []

    while i < len(ci):

        sbs_delay = 0
        batch_delay = 0

        if ci[i] == 0:
            while len(missed) > 0:
                sbs_delay += i - missed.pop()
            batch_delay += b
            b -= 1
            if b == -1:
                b = row['batch_size'] - 1

        if ci[i] == 1:
            if y_test[i] == 0:
                missed.append(i)
                
        delay_list.append(sbs_delay + batch_delay)

        i += 1
    #if row['project'] == 'heroku' and row['batch_size']==4:
        #print('-----------------')
    point = {'builds_reqd':row['project_reqd_builds'], 'median_delay':median(delay_list)}
    ssr_delay_lib[row['project']+'.csv'][row['algorithm']][row['batch_size']][row['confidence']] = point

# %%
ssr_delay_lib
# Out:
# {'geoserver.csv': {'BATCHSTOP4': {4: {2: {'builds_reqd': 95.83333333333331,
#      'median_delay': 1.0},
#     3: {'builds_reqd': 80.95238095238095, 'median_delay': 1.0},
#     4: {'builds_reqd': 75.5952380952381, 'median_delay': 1.0},
#     5: {'builds_reqd': 76.78571428571429, 'median_delay': 1.0},
#     6: {'builds_reqd': 80.95238095238095, 'median_delay': 1.0},
#     7: {'builds_reqd': 71.42857142857143, 'median_delay': 1.0},
#     8: {'builds_reqd': 81.54761904761905, 'median_delay': 1.0},
#     9: {'builds_reqd': 75.5952380952381, 'median_delay': 1.0},
#     10: {'builds_reqd': 74.4047619047619, 'median_delay': 1.0},
#     11: {'builds_reqd': 67.85714285714286, 'median_delay': 1.0},
#     12: {'builds_reqd': 67.26190476190476, 'median_delay': 1.0},
#     13: {'builds_reqd': 66.66666666666667, 'median_delay': 0.5},
#     14: {'builds_reqd': 65.47619047619048, 'median_delay': 0.5},
#     15: {'builds_reqd': 61.90476190476191, 'median_delay': 0.0},
#     16: {'builds_reqd': 61.30952380952381, 'median_delay': 0.0},
#     17: {'builds_reqd': 61.30952380952381, 'median_delay': 0.0},
#     18: {'builds_reqd': 61.30952380952381, 'median_delay': 0.0},
#     19: {'builds_reqd': 75.0, 'median_delay': 1.0},
#     20: {'builds_reqd': 72.02380952380952, 'median_delay': 1.0}},
#    8: {2: {'builds_reqd': 110.71428571428572, 'median_delay': 3.5},
#     3: {'builds_reqd': 99.4047619047619, 'median_delay': 3.0},
#     4: {'builds_reqd': 100.0, 'median_delay': 3.0},
#     5: {'builds_reqd': 103.57142857142856, 'median_delay': 3.0},
#     6: {'builds_reqd': 102.38095238095238, 'median_delay': 3.0},
#     7: {'builds_reqd': 98.8095238095238, 'median_delay': 3.0},
#     8: {'builds_reqd': 98.21428571428572, 'median_delay': 3.0},
#     9: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     10: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     11: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     12: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     13: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     14: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     15: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     16: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     17: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     18: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     19: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0},
#     20: {'builds_reqd': 97.61904761904762, 'median_delay': 3.0}},
#    16: {2: {'builds_reqd': 116.66666666666669, 'median_delay': 8.0},
#     3: {'builds_reqd': 111.3095238095238, 'median_delay': 8.0},
#     4: {'builds_reqd': 104.76190476190476, 'median_delay': 7.5},
#     5: {'builds_reqd': 113.6904761904762, 'median_delay': 7.0},
#     6: {'builds_reqd': 113.0952380952381, 'median_delay': 7.0},
#     7: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     8: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     9: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     10: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     11: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     12: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     13: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     14: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     15: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     16: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     17: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     18: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     19: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0},
#     20: {'builds_reqd': 110.11904761904762, 'median_delay': 7.0}}},
#   'BATCH4': {4: {2: {'builds_reqd': 95.83333333333331, 'median_delay': 1.0},
#     3: {'builds_reqd': 80.95238095238095, 'median_delay': 1.0},
#     4: {'builds_reqd': 75.5952380952381, 'median_delay': 1.0},
#     5: {'builds_reqd': 76.78571428571429, 'median_delay': 1.0},
#     6: {'builds_reqd': 80.95238095238095, 'median_delay': 1.0},
#     7: {'builds_reqd': 71.42857142857143, 'median_delay': 1.0},
#     8: {'builds_reqd': 81.54761904761905, 'median_delay': 1.0},
#     9: {'builds_reqd': 75.5952380952381, 'median_delay': 1.0},
#     10: {'builds_reqd': 74.4047619047619, 'median_delay': 1.0},
#     11: {'builds_reqd': 67.85714285714286, 'median_delay': 1.0},
#     12: {'builds_reqd': 67.26190476190476, 'median_delay': 1.0},
#     13: {'builds_reqd': 66.66666666666667, 'median_delay': 0.5},
#     14: {'builds_reqd': 65.47619047619048, 'median_delay': 0.5},
#     15: {'builds_reqd': 61.90476190476191, 'median_delay': 0.0},
#     16: {'builds_reqd': 61.30952380952381, 'median_delay': 0.0},
#     17: {'builds_reqd': 61.30952380952381, 'median_delay': 0.0},
#     18: {'builds_reqd': 61.30952380952381, 'median_delay': 0.0},
#     19: {'builds_reqd': 75.0, 'median_delay': 1.0},
#     20: {'builds_reqd': 72.02380952380952, 'median_delay': 1.0}}},
#   'BATCHBISECT': {1: {2: {'builds_reqd': 54.76190476190476,
#      'median_delay': 0.0},
#     3: {'builds_reqd': 43.45238095238095, 'median_delay': 0.0},
#     4: {'builds_reqd': 29.761904761904763, 'median_delay': 0.0},
#     5: {'builds_reqd': 29.166666666666668, 'median_delay': 0.0},
#     6: {'builds_reqd': 25.0, 'median_delay': 0.0},
#     7: {'builds_reqd': 20.83333333333333, 'median_delay': 0.0},
#     8: {'builds_reqd': 18.45238095238096, 'median_delay': 0.0},
#     9: {'builds_reqd': 17.857142857142858, 'median_delay': 0.0},
#     10: {'builds_reqd': 16.071428571428573, 'median_delay': 0.0},
#     11: {'builds_reqd': 14.88095238095238, 'median_delay': 0.0},
#     12: {'builds_reqd': 13.69047619047619, 'median_delay': 0.0},
#     13: {'builds_reqd': 14.88095238095238, 'median_delay': 0.0},
#     14: {'builds_reqd': 12.5, 'median_delay': 0.0},
#     15: {'builds_reqd': 13.69047619047619, 'median_delay': 0.0},
#     16: {'builds_reqd': 12.5, 'median_delay': 0.0},
#     17: {'builds_reqd': 14.285714285714286, 'median_delay': 0.0},
#     18: {'builds_reqd': 11.904761904761903, 'median_delay': 0.0},
#     19: {'builds_reqd': 12.5, 'median_delay': 0.0},
#     20: {'builds_reqd': 11.904761904761903, 'median_delay': 0.0}},
#    2: {2: {'builds_reqd': 78.57142857142857, 'median_delay': 0.0},
#     3: {'builds_reqd': 66.07142857142857, 'median_delay': 0.0},
#     4: {'builds_reqd': 60.11904761904762, 'median_delay': 0.0},
#     5: {'builds_reqd': 51.785714285714285, 'median_delay': 0.0},
#     6: {'builds_reqd': 45.833333333333336, 'median_delay': 0.0},
#     7: {'builds_reqd': 46.42857142857143, 'median_delay': 0.0},
#     8: {'builds_reqd': 35.714285714285715, 'median_delay': 0.0},
#     9: {'builds_reqd': 36.30952380952381, 'median_delay': 0.0},
#     10: {'builds_reqd': 34.523809523809526, 'median_delay': 0.0},
#     11: {'builds_reqd': 38.69047619047619, 'median_delay': 0.0},
#     12: {'builds_reqd': 38.69047619047619, 'median_delay': 0.0},
#     13: {'builds_reqd': 34.523809523809526, 'median_delay': 0.0},
#     14: {'builds_reqd': 39.88095238095238, 'median_delay': 0.0},
#     15: {'builds_reqd': 38.095238095238095, 'median_delay': 0.0},
#     16: {'builds_reqd': 36.30952380952381, 'median_delay': 0.0},
#     17: {'builds_reqd': 30.95238095238096, 'median_delay': 0.0},
#     18: {'builds_reqd': 32.142857142857146, 'median_delay': 0.0},
#     19: {'builds_reqd': 31.547619047619047, 'median_delay': 0.0},
#     20: {'builds_reqd': 31.547619047619047, 'median_delay': 0.0}},
#    4: {2: {'builds_reqd': 104.16666666666669, 'median_delay': 1.0},
#     3: {'builds_reqd': 91.66666666666669, 'median_delay': 1.0},
#     4: {'builds_reqd': 83.92857142857143, 'median_delay': 1.0},
#     5: {'builds_reqd': 85.11904761904762, 'median_delay': 1.0},
#     6: {'builds_reqd': 86.9047619047619, 'median_delay': 1.0},
#     7: {'builds_reqd': 79.76190476190476, 'median_delay': 1.0},
#     8: {'builds_reqd': 88.69047619047619, 'median_delay': 1.0},
#     9: {'builds_reqd': 82.73809523809524, 'median_delay': 1.0},
#     10: {'builds_reqd': 80.35714285714286, 'median_delay': 1.0},
#     11: {'builds_reqd': 76.19047619047619, 'median_delay': 1.0},
#     12: {'builds_reqd': 75.5952380952381, 'median_delay': 1.0},
#     13: {'builds_reqd': 73.80952380952381, 'median_delay': 0.5},
#     14: {'builds_reqd': 72.61904761904762, 'median_delay': 0.5},
#     15: {'builds_reqd': 69.04761904761905, 'median_delay': 0.0},
#     16: {'builds_reqd': 68.45238095238095, 'median_delay': 0.0},
#     17: {'builds_reqd': 68.45238095238095, 'median_delay': 0.0},
#     18: {'builds_reqd': 68.45238095238095, 'median_delay': 0.0},
#     19: {'builds_reqd': 82.14285714285714, 'median_delay': 1.0},
#     20: {'builds_reqd': 80.35714285714286, 'median_delay': 1.0}},
#    8: {2: {'builds_reqd': 120.23809523809524, 'median_delay': 3.5},
#     3: {'builds_reqd': 111.3095238095238, 'median_delay': 3.0},
#     4: {'builds_reqd': 110.71428571428572, 'median_delay': 3.0},
#     5: {'builds_reqd': 113.0952380952381, 'median_delay': 3.0},
#     6: {'builds_reqd': 111.9047619047619, 'median_delay': 3.0},
#     7: {'builds_reqd': 109.52380952380952, 'median_delay': 3.0},
#     8: {'builds_reqd': 108.92857142857144, 'median_delay': 3.0},
#     9: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     10: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     11: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     12: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     13: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     14: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     15: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     16: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     17: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     18: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     19: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0},
#     20: {'builds_reqd': 108.33333333333331, 'median_delay': 3.0}},
#    16: {2: {'builds_reqd': 126.1904761904762, 'median_delay': 8.0},
#     3: {'builds_reqd': 122.02380952380952, 'median_delay': 8.0},
#     4: {'builds_reqd': 116.66666666666669, 'median_delay': 7.5},
#     5: {'builds_reqd': 123.21428571428572, 'median_delay': 7.0},
#     6: {'builds_reqd': 122.61904761904762, 'median_delay': 7.0},
#     7: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     8: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     9: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     10: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     11: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     12: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     13: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     14: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     15: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     16: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     17: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     18: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     19: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0},
#     20: {'builds_reqd': 120.83333333333331, 'median_delay': 7.0}}}},
#  'fog.csv': {'BATCHSTOP4': {4: {2: {'builds_reqd': 62.96296296296296,
#      'median_delay': 1},
#     3: {'builds_reqd': 60.3988603988604, 'median_delay': 1},
#     4: {'builds_reqd': 52.99145299145299, 'median_delay': 1},
#     5: {'builds_reqd': 43.58974358974359, 'median_delay': 0},
#     6: {'builds_reqd': 45.01424501424501, 'median_delay': 0},
#     7: {'builds_reqd': 45.58404558404558, 'median_delay': 0},
#     8: {'builds_reqd': 47.00854700854701, 'median_delay': 0},
#     9: {'builds_reqd': 38.46153846153846, 'median_delay': 0},
#     10: {'builds_reqd': 46.72364672364672, 'median_delay': 0},
#     11: {'builds_reqd': 41.02564102564103, 'median_delay': 0},
#     12: {'builds_reqd': 36.46723646723647, 'median_delay': 0},
#     13: {'builds_reqd': 33.61823361823362, 'median_delay': 0},
#     14: {'builds_reqd': 33.333333333333336, 'median_delay': 0},
#     15: {'builds_reqd': 30.484330484330485, 'median_delay': 0},
#     16: {'builds_reqd': 39.88603988603989, 'median_delay': 0},
#     17: {'builds_reqd': 28.49002849002849, 'median_delay': 0},
#     18: {'builds_reqd': 33.903133903133906, 'median_delay': 0},
#     19: {'builds_reqd': 28.205128205128204, 'median_delay': 0},
#     20: {'builds_reqd': 31.05413105413105, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 67.80626780626781, 'median_delay': 3},
#     3: {'builds_reqd': 68.66096866096866, 'median_delay': 3},
#     4: {'builds_reqd': 67.23646723646723, 'median_delay': 3},
#     5: {'builds_reqd': 65.24216524216524, 'median_delay': 3},
#     6: {'builds_reqd': 60.11396011396011, 'median_delay': 2},
#     7: {'builds_reqd': 61.53846153846154, 'median_delay': 3},
#     8: {'builds_reqd': 62.96296296296296, 'median_delay': 2},
#     9: {'builds_reqd': 56.6951566951567, 'median_delay': 2},
#     10: {'builds_reqd': 54.13105413105413, 'median_delay': 2},
#     11: {'builds_reqd': 55.27065527065527, 'median_delay': 2},
#     12: {'builds_reqd': 56.12535612535613, 'median_delay': 2},
#     13: {'builds_reqd': 49.857549857549856, 'median_delay': 1},
#     14: {'builds_reqd': 50.997150997151, 'median_delay': 1},
#     15: {'builds_reqd': 49.57264957264957, 'median_delay': 1},
#     16: {'builds_reqd': 50.427350427350426, 'median_delay': 1},
#     17: {'builds_reqd': 41.59544159544159, 'median_delay': 0},
#     18: {'builds_reqd': 42.73504273504273, 'median_delay': 0},
#     19: {'builds_reqd': 46.43874643874644, 'median_delay': 0},
#     20: {'builds_reqd': 46.72364672364672, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 75.21367521367522, 'median_delay': 8},
#     3: {'builds_reqd': 76.06837606837607, 'median_delay': 7},
#     4: {'builds_reqd': 78.91737891737891, 'median_delay': 7},
#     5: {'builds_reqd': 77.77777777777777, 'median_delay': 7},
#     6: {'builds_reqd': 76.06837606837607, 'median_delay': 7},
#     7: {'builds_reqd': 76.35327635327636, 'median_delay': 7},
#     8: {'builds_reqd': 74.35897435897436, 'median_delay': 7},
#     9: {'builds_reqd': 67.80626780626781, 'median_delay': 7},
#     10: {'builds_reqd': 68.94586894586895, 'median_delay': 6},
#     11: {'builds_reqd': 68.94586894586895, 'median_delay': 7},
#     12: {'builds_reqd': 71.22507122507122, 'median_delay': 7},
#     13: {'builds_reqd': 67.80626780626781, 'median_delay': 6},
#     14: {'builds_reqd': 70.65527065527066, 'median_delay': 6},
#     15: {'builds_reqd': 61.53846153846154, 'median_delay': 6},
#     16: {'builds_reqd': 62.67806267806268, 'median_delay': 6},
#     17: {'builds_reqd': 59.82905982905983, 'median_delay': 6},
#     18: {'builds_reqd': 60.96866096866097, 'median_delay': 6},
#     19: {'builds_reqd': 60.96866096866097, 'median_delay': 6},
#     20: {'builds_reqd': 60.96866096866097, 'median_delay': 6}}},
#   'BATCH4': {4: {2: {'builds_reqd': 62.96296296296296, 'median_delay': 1},
#     3: {'builds_reqd': 60.3988603988604, 'median_delay': 1},
#     4: {'builds_reqd': 52.99145299145299, 'median_delay': 1},
#     5: {'builds_reqd': 43.58974358974359, 'median_delay': 0},
#     6: {'builds_reqd': 45.01424501424501, 'median_delay': 0},
#     7: {'builds_reqd': 45.58404558404558, 'median_delay': 0},
#     8: {'builds_reqd': 47.00854700854701, 'median_delay': 0},
#     9: {'builds_reqd': 38.46153846153846, 'median_delay': 0},
#     10: {'builds_reqd': 46.72364672364672, 'median_delay': 0},
#     11: {'builds_reqd': 41.02564102564103, 'median_delay': 0},
#     12: {'builds_reqd': 36.46723646723647, 'median_delay': 0},
#     13: {'builds_reqd': 33.61823361823362, 'median_delay': 0},
#     14: {'builds_reqd': 33.333333333333336, 'median_delay': 0},
#     15: {'builds_reqd': 30.484330484330485, 'median_delay': 0},
#     16: {'builds_reqd': 39.88603988603989, 'median_delay': 0},
#     17: {'builds_reqd': 28.49002849002849, 'median_delay': 0},
#     18: {'builds_reqd': 33.903133903133906, 'median_delay': 0},
#     19: {'builds_reqd': 28.205128205128204, 'median_delay': 0},
#     20: {'builds_reqd': 31.05413105413105, 'median_delay': 0}}},
#   'BATCHBISECT': {1: {2: {'builds_reqd': 53.56125356125356, 'median_delay': 0},
#     3: {'builds_reqd': 37.03703703703704, 'median_delay': 0},
#     4: {'builds_reqd': 29.05982905982906, 'median_delay': 0},
#     5: {'builds_reqd': 22.22222222222222, 'median_delay': 0},
#     6: {'builds_reqd': 20.22792022792023, 'median_delay': 0},
#     7: {'builds_reqd': 17.663817663817664, 'median_delay': 0},
#     8: {'builds_reqd': 16.23931623931624, 'median_delay': 0},
#     9: {'builds_reqd': 13.675213675213676, 'median_delay': 0},
#     10: {'builds_reqd': 12.535612535612536, 'median_delay': 0},
#     11: {'builds_reqd': 11.11111111111111, 'median_delay': 0},
#     12: {'builds_reqd': 11.11111111111111, 'median_delay': 0},
#     13: {'builds_reqd': 10.826210826210826, 'median_delay': 0},
#     14: {'builds_reqd': 9.971509971509972, 'median_delay': 0},
#     15: {'builds_reqd': 8.547008547008547, 'median_delay': 0},
#     16: {'builds_reqd': 9.116809116809115, 'median_delay': 0},
#     17: {'builds_reqd': 8.547008547008547, 'median_delay': 0},
#     18: {'builds_reqd': 7.977207977207978, 'median_delay': 0},
#     19: {'builds_reqd': 7.977207977207978, 'median_delay': 0},
#     20: {'builds_reqd': 7.122507122507122, 'median_delay': 0}},
#    2: {2: {'builds_reqd': 56.41025641025641, 'median_delay': 0},
#     3: {'builds_reqd': 49.287749287749286, 'median_delay': 0},
#     4: {'builds_reqd': 37.32193732193732, 'median_delay': 0},
#     5: {'builds_reqd': 33.61823361823362, 'median_delay': 0},
#     6: {'builds_reqd': 31.33903133903134, 'median_delay': 0},
#     7: {'builds_reqd': 29.344729344729345, 'median_delay': 0},
#     8: {'builds_reqd': 23.36182336182336, 'median_delay': 0},
#     9: {'builds_reqd': 23.93162393162393, 'median_delay': 0},
#     10: {'builds_reqd': 21.36752136752137, 'median_delay': 0},
#     11: {'builds_reqd': 20.512820512820515, 'median_delay': 0},
#     12: {'builds_reqd': 19.943019943019944, 'median_delay': 0},
#     13: {'builds_reqd': 21.937321937321936, 'median_delay': 0},
#     14: {'builds_reqd': 16.524216524216524, 'median_delay': 0},
#     15: {'builds_reqd': 18.51851851851852, 'median_delay': 0},
#     16: {'builds_reqd': 20.22792022792023, 'median_delay': 0},
#     17: {'builds_reqd': 15.954415954415955, 'median_delay': 0},
#     18: {'builds_reqd': 13.39031339031339, 'median_delay': 0},
#     19: {'builds_reqd': 15.0997150997151, 'median_delay': 0},
#     20: {'builds_reqd': 19.65811965811966, 'median_delay': 0}},
#    4: {2: {'builds_reqd': 67.52136752136752, 'median_delay': 1},
#     3: {'builds_reqd': 64.95726495726495, 'median_delay': 1},
#     4: {'builds_reqd': 56.98005698005698, 'median_delay': 1},
#     5: {'builds_reqd': 48.14814814814815, 'median_delay': 0},
#     6: {'builds_reqd': 49.57264957264957, 'median_delay': 0},
#     7: {'builds_reqd': 51.282051282051285, 'median_delay': 0},
#     8: {'builds_reqd': 51.566951566951566, 'median_delay': 0},
#     9: {'builds_reqd': 43.58974358974359, 'median_delay': 0},
#     10: {'builds_reqd': 52.421652421652425, 'median_delay': 0},
#     11: {'builds_reqd': 45.58404558404558, 'median_delay': 0},
#     12: {'builds_reqd': 40.45584045584046, 'median_delay': 0},
#     13: {'builds_reqd': 38.74643874643875, 'median_delay': 0},
#     14: {'builds_reqd': 37.89173789173789, 'median_delay': 0},
#     15: {'builds_reqd': 33.903133903133906, 'median_delay': 0},
#     16: {'builds_reqd': 44.44444444444444, 'median_delay': 0},
#     17: {'builds_reqd': 31.90883190883191, 'median_delay': 0},
#     18: {'builds_reqd': 38.46153846153846, 'median_delay': 0},
#     19: {'builds_reqd': 32.763532763532766, 'median_delay': 0},
#     20: {'builds_reqd': 35.61253561253561, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 72.93447293447294, 'median_delay': 3},
#     3: {'builds_reqd': 72.64957264957265, 'median_delay': 3},
#     4: {'builds_reqd': 71.22507122507122, 'median_delay': 3},
#     5: {'builds_reqd': 69.8005698005698, 'median_delay': 3},
#     6: {'builds_reqd': 65.24216524216524, 'median_delay': 2},
#     7: {'builds_reqd': 66.66666666666667, 'median_delay': 3},
#     8: {'builds_reqd': 66.38176638176638, 'median_delay': 2},
#     9: {'builds_reqd': 61.82336182336182, 'median_delay': 2},
#     10: {'builds_reqd': 58.68945868945869, 'median_delay': 2},
#     11: {'builds_reqd': 60.3988603988604, 'median_delay': 2},
#     12: {'builds_reqd': 59.54415954415954, 'median_delay': 2},
#     13: {'builds_reqd': 54.41595441595442, 'median_delay': 1},
#     14: {'builds_reqd': 54.98575498575499, 'median_delay': 1},
#     15: {'builds_reqd': 54.13105413105413, 'median_delay': 1},
#     16: {'builds_reqd': 53.84615384615385, 'median_delay': 1},
#     17: {'builds_reqd': 45.58404558404558, 'median_delay': 0},
#     18: {'builds_reqd': 45.58404558404558, 'median_delay': 0},
#     19: {'builds_reqd': 50.997150997151, 'median_delay': 0},
#     20: {'builds_reqd': 49.00284900284901, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 79.77207977207978, 'median_delay': 8},
#     3: {'builds_reqd': 80.62678062678063, 'median_delay': 7},
#     4: {'builds_reqd': 82.90598290598291, 'median_delay': 7},
#     5: {'builds_reqd': 82.90598290598291, 'median_delay': 7},
#     6: {'builds_reqd': 79.48717948717949, 'median_delay': 7},
#     7: {'builds_reqd': 79.77207977207978, 'median_delay': 7},
#     8: {'builds_reqd': 79.48717948717949, 'median_delay': 7},
#     9: {'builds_reqd': 73.5042735042735, 'median_delay': 7},
#     10: {'builds_reqd': 74.07407407407408, 'median_delay': 6},
#     11: {'builds_reqd': 74.64387464387464, 'median_delay': 7},
#     12: {'builds_reqd': 75.78347578347578, 'median_delay': 7},
#     13: {'builds_reqd': 71.22507122507122, 'median_delay': 6},
#     14: {'builds_reqd': 73.5042735042735, 'median_delay': 6},
#     15: {'builds_reqd': 66.66666666666667, 'median_delay': 6},
#     16: {'builds_reqd': 66.66666666666667, 'median_delay': 6},
#     17: {'builds_reqd': 64.38746438746439, 'median_delay': 6},
#     18: {'builds_reqd': 64.38746438746439, 'median_delay': 6},
#     19: {'builds_reqd': 64.95726495726495, 'median_delay': 6},
#     20: {'builds_reqd': 64.95726495726495, 'median_delay': 6}}}},
#  'graylog2-server.csv': {'BATCHSTOP4': {4: {2: {'builds_reqd': 26.184538653366584,
#      'median_delay': 1},
#     3: {'builds_reqd': 22.443890274314214, 'median_delay': 1},
#     4: {'builds_reqd': 18.703241895261847, 'median_delay': 0},
#     5: {'builds_reqd': 16.209476309226932, 'median_delay': 0},
#     6: {'builds_reqd': 14.463840399002494, 'median_delay': 0},
#     7: {'builds_reqd': 13.46633416458853, 'median_delay': 0},
#     8: {'builds_reqd': 12.468827930174564, 'median_delay': 0},
#     9: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     10: {'builds_reqd': 8.977556109725686, 'median_delay': 0},
#     11: {'builds_reqd': 10.723192019950124, 'median_delay': 0},
#     12: {'builds_reqd': 9.226932668329177, 'median_delay': 0},
#     13: {'builds_reqd': 7.980049875311721, 'median_delay': 0},
#     14: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     15: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     16: {'builds_reqd': 6.733167082294265, 'median_delay': 0},
#     17: {'builds_reqd': 6.234413965087282, 'median_delay': 0},
#     18: {'builds_reqd': 5.985037406483791, 'median_delay': 0},
#     19: {'builds_reqd': 4.488778054862843, 'median_delay': 0},
#     20: {'builds_reqd': 4.239401496259352, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 22.194513715710723, 'median_delay': 3},
#     3: {'builds_reqd': 16.209476309226932, 'median_delay': 3},
#     4: {'builds_reqd': 18.204488778054863, 'median_delay': 2},
#     5: {'builds_reqd': 14.463840399002494, 'median_delay': 2},
#     6: {'builds_reqd': 13.965087281795512, 'median_delay': 1},
#     7: {'builds_reqd': 13.965087281795512, 'median_delay': 1},
#     8: {'builds_reqd': 11.72069825436409, 'median_delay': 0},
#     9: {'builds_reqd': 9.476309226932669, 'median_delay': 0},
#     10: {'builds_reqd': 13.965087281795512, 'median_delay': 0},
#     11: {'builds_reqd': 10.473815461346634, 'median_delay': 0},
#     12: {'builds_reqd': 10.224438902743142, 'median_delay': 0},
#     13: {'builds_reqd': 6.483790523690773, 'median_delay': 0},
#     14: {'builds_reqd': 11.221945137157109, 'median_delay': 0},
#     15: {'builds_reqd': 9.476309226932669, 'median_delay': 0},
#     16: {'builds_reqd': 5.985037406483791, 'median_delay': 0},
#     17: {'builds_reqd': 7.481296758104738, 'median_delay': 0},
#     18: {'builds_reqd': 8.977556109725686, 'median_delay': 0},
#     19: {'builds_reqd': 7.231920199501247, 'median_delay': 0},
#     20: {'builds_reqd': 8.977556109725686, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 23.44139650872818, 'median_delay': 7},
#     3: {'builds_reqd': 19.70074812967581, 'median_delay': 7},
#     4: {'builds_reqd': 19.45137157107232, 'median_delay': 6},
#     5: {'builds_reqd': 15.960099750623442, 'median_delay': 6},
#     6: {'builds_reqd': 12.967581047381548, 'median_delay': 5},
#     7: {'builds_reqd': 17.206982543640898, 'median_delay': 5},
#     8: {'builds_reqd': 17.955112219451372, 'median_delay': 5},
#     9: {'builds_reqd': 12.468827930174564, 'median_delay': 4},
#     10: {'builds_reqd': 17.705735660847882, 'median_delay': 4},
#     11: {'builds_reqd': 15.71072319201995, 'median_delay': 4},
#     12: {'builds_reqd': 16.957605985037407, 'median_delay': 4},
#     13: {'builds_reqd': 18.952618453865338, 'median_delay': 4},
#     14: {'builds_reqd': 21.44638403990025, 'median_delay': 4},
#     15: {'builds_reqd': 13.965087281795512, 'median_delay': 3},
#     16: {'builds_reqd': 14.214463840399002, 'median_delay': 2},
#     17: {'builds_reqd': 9.476309226932669, 'median_delay': 1},
#     18: {'builds_reqd': 10.473815461346634, 'median_delay': 0},
#     19: {'builds_reqd': 9.476309226932669, 'median_delay': 0},
#     20: {'builds_reqd': 11.72069825436409, 'median_delay': 0}}},
#   'BATCH4': {4: {2: {'builds_reqd': 26.184538653366584, 'median_delay': 1},
#     3: {'builds_reqd': 22.443890274314214, 'median_delay': 1},
#     4: {'builds_reqd': 18.703241895261847, 'median_delay': 0},
#     5: {'builds_reqd': 16.209476309226932, 'median_delay': 0},
#     6: {'builds_reqd': 14.463840399002494, 'median_delay': 0},
#     7: {'builds_reqd': 13.46633416458853, 'median_delay': 0},
#     8: {'builds_reqd': 12.468827930174564, 'median_delay': 0},
#     9: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     10: {'builds_reqd': 8.977556109725686, 'median_delay': 0},
#     11: {'builds_reqd': 10.723192019950124, 'median_delay': 0},
#     12: {'builds_reqd': 9.226932668329177, 'median_delay': 0},
#     13: {'builds_reqd': 7.980049875311721, 'median_delay': 0},
#     14: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     15: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     16: {'builds_reqd': 6.733167082294265, 'median_delay': 0},
#     17: {'builds_reqd': 6.234413965087282, 'median_delay': 0},
#     18: {'builds_reqd': 5.985037406483791, 'median_delay': 0},
#     19: {'builds_reqd': 4.488778054862843, 'median_delay': 0},
#     20: {'builds_reqd': 4.239401496259352, 'median_delay': 0}}},
#   'BATCHBISECT': {1: {2: {'builds_reqd': 50.37406483790524, 'median_delay': 0},
#     3: {'builds_reqd': 34.1645885286783, 'median_delay': 0},
#     4: {'builds_reqd': 25.43640897755611, 'median_delay': 0},
#     5: {'builds_reqd': 20.1995012468828, 'median_delay': 0},
#     6: {'builds_reqd': 16.708229426433917, 'median_delay': 0},
#     7: {'builds_reqd': 14.463840399002494, 'median_delay': 0},
#     8: {'builds_reqd': 12.967581047381548, 'median_delay': 0},
#     9: {'builds_reqd': 11.970074812967582, 'median_delay': 0},
#     10: {'builds_reqd': 10.224438902743142, 'median_delay': 0},
#     11: {'builds_reqd': 9.226932668329177, 'median_delay': 0},
#     12: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     13: {'builds_reqd': 7.980049875311721, 'median_delay': 0},
#     14: {'builds_reqd': 7.231920199501247, 'median_delay': 0},
#     15: {'builds_reqd': 6.733167082294265, 'median_delay': 0},
#     16: {'builds_reqd': 6.982543640897756, 'median_delay': 0},
#     17: {'builds_reqd': 6.483790523690773, 'median_delay': 0},
#     18: {'builds_reqd': 5.7356608478803, 'median_delay': 0},
#     19: {'builds_reqd': 5.486284289276808, 'median_delay': 0},
#     20: {'builds_reqd': 5.236907730673317, 'median_delay': 0}},
#    2: {2: {'builds_reqd': 36.408977556109726, 'median_delay': 0},
#     3: {'builds_reqd': 26.93266832917706, 'median_delay': 0},
#     4: {'builds_reqd': 22.443890274314214, 'median_delay': 0},
#     5: {'builds_reqd': 16.708229426433917, 'median_delay': 0},
#     6: {'builds_reqd': 15.71072319201995, 'median_delay': 0},
#     7: {'builds_reqd': 13.216957605985035, 'median_delay': 0},
#     8: {'builds_reqd': 13.46633416458853, 'median_delay': 0},
#     9: {'builds_reqd': 10.723192019950124, 'median_delay': 0},
#     10: {'builds_reqd': 9.226932668329177, 'median_delay': 0},
#     11: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     12: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     13: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     14: {'builds_reqd': 6.733167082294265, 'median_delay': 0},
#     15: {'builds_reqd': 7.231920199501247, 'median_delay': 0},
#     16: {'builds_reqd': 6.733167082294265, 'median_delay': 0},
#     17: {'builds_reqd': 5.7356608478803, 'median_delay': 0},
#     18: {'builds_reqd': 6.234413965087282, 'median_delay': 0},
#     19: {'builds_reqd': 5.7356608478803, 'median_delay': 0},
#     20: {'builds_reqd': 5.486284289276808, 'median_delay': 0}},
#    4: {2: {'builds_reqd': 26.184538653366584, 'median_delay': 1},
#     3: {'builds_reqd': 22.443890274314214, 'median_delay': 1},
#     4: {'builds_reqd': 18.703241895261847, 'median_delay': 0},
#     5: {'builds_reqd': 16.209476309226932, 'median_delay': 0},
#     6: {'builds_reqd': 14.463840399002494, 'median_delay': 0},
#     7: {'builds_reqd': 13.46633416458853, 'median_delay': 0},
#     8: {'builds_reqd': 12.468827930174564, 'median_delay': 0},
#     9: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     10: {'builds_reqd': 8.977556109725686, 'median_delay': 0},
#     11: {'builds_reqd': 10.723192019950124, 'median_delay': 0},
#     12: {'builds_reqd': 9.226932668329177, 'median_delay': 0},
#     13: {'builds_reqd': 7.980049875311721, 'median_delay': 0},
#     14: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     15: {'builds_reqd': 8.478802992518704, 'median_delay': 0},
#     16: {'builds_reqd': 6.733167082294265, 'median_delay': 0},
#     17: {'builds_reqd': 6.234413965087282, 'median_delay': 0},
#     18: {'builds_reqd': 5.985037406483791, 'median_delay': 0},
#     19: {'builds_reqd': 4.488778054862843, 'median_delay': 0},
#     20: {'builds_reqd': 4.239401496259352, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 22.194513715710723, 'median_delay': 3},
#     3: {'builds_reqd': 16.209476309226932, 'median_delay': 3},
#     4: {'builds_reqd': 18.204488778054863, 'median_delay': 2},
#     5: {'builds_reqd': 14.463840399002494, 'median_delay': 2},
#     6: {'builds_reqd': 13.965087281795512, 'median_delay': 1},
#     7: {'builds_reqd': 13.965087281795512, 'median_delay': 1},
#     8: {'builds_reqd': 11.72069825436409, 'median_delay': 0},
#     9: {'builds_reqd': 9.476309226932669, 'median_delay': 0},
#     10: {'builds_reqd': 13.965087281795512, 'median_delay': 0},
#     11: {'builds_reqd': 10.473815461346634, 'median_delay': 0},
#     12: {'builds_reqd': 10.224438902743142, 'median_delay': 0},
#     13: {'builds_reqd': 6.483790523690773, 'median_delay': 0},
#     14: {'builds_reqd': 11.221945137157109, 'median_delay': 0},
#     15: {'builds_reqd': 9.476309226932669, 'median_delay': 0},
#     16: {'builds_reqd': 5.985037406483791, 'median_delay': 0},
#     17: {'builds_reqd': 7.481296758104738, 'median_delay': 0},
#     18: {'builds_reqd': 8.977556109725686, 'median_delay': 0},
#     19: {'builds_reqd': 7.231920199501247, 'median_delay': 0},
#     20: {'builds_reqd': 8.977556109725686, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 23.44139650872818, 'median_delay': 7},
#     3: {'builds_reqd': 19.70074812967581, 'median_delay': 7},
#     4: {'builds_reqd': 19.45137157107232, 'median_delay': 6},
#     5: {'builds_reqd': 15.960099750623442, 'median_delay': 6},
#     6: {'builds_reqd': 12.967581047381548, 'median_delay': 5},
#     7: {'builds_reqd': 17.206982543640898, 'median_delay': 5},
#     8: {'builds_reqd': 17.955112219451372, 'median_delay': 5},
#     9: {'builds_reqd': 12.468827930174564, 'median_delay': 4},
#     10: {'builds_reqd': 17.705735660847882, 'median_delay': 4},
#     11: {'builds_reqd': 15.71072319201995, 'median_delay': 4},
#     12: {'builds_reqd': 16.957605985037407, 'median_delay': 4},
#     13: {'builds_reqd': 18.952618453865338, 'median_delay': 4},
#     14: {'builds_reqd': 21.44638403990025, 'median_delay': 4},
#     15: {'builds_reqd': 13.965087281795512, 'median_delay': 3},
#     16: {'builds_reqd': 14.214463840399002, 'median_delay': 2},
#     17: {'builds_reqd': 9.476309226932669, 'median_delay': 1},
#     18: {'builds_reqd': 10.473815461346634, 'median_delay': 0},
#     19: {'builds_reqd': 9.476309226932669, 'median_delay': 0},
#     20: {'builds_reqd': 11.72069825436409, 'median_delay': 0}}}},
#  'cloudify.csv': {'BATCHSTOP4': {4: {2: {'builds_reqd': 30.327868852459016,
#      'median_delay': 1.0},
#     3: {'builds_reqd': 29.098360655737704, 'median_delay': 1.0},
#     4: {'builds_reqd': 27.049180327868854, 'median_delay': 0.0},
#     5: {'builds_reqd': 20.28688524590164, 'median_delay': 0.0},
#     6: {'builds_reqd': 21.72131147540984, 'median_delay': 0.0},
#     7: {'builds_reqd': 16.598360655737704, 'median_delay': 0.0},
#     8: {'builds_reqd': 16.598360655737704, 'median_delay': 0.0},
#     9: {'builds_reqd': 14.959016393442624, 'median_delay': 0.0},
#     10: {'builds_reqd': 16.39344262295082, 'median_delay': 0.0},
#     11: {'builds_reqd': 15.778688524590164, 'median_delay': 0.0},
#     12: {'builds_reqd': 9.836065573770492, 'median_delay': 0.0},
#     13: {'builds_reqd': 9.631147540983608, 'median_delay': 0.0},
#     14: {'builds_reqd': 9.631147540983608, 'median_delay': 0.0},
#     15: {'builds_reqd': 7.581967213114754, 'median_delay': 0.0},
#     16: {'builds_reqd': 13.114754098360656, 'median_delay': 0.0},
#     17: {'builds_reqd': 6.967213114754099, 'median_delay': 0.0},
#     18: {'builds_reqd': 11.68032786885246, 'median_delay': 0.0},
#     19: {'builds_reqd': 10.450819672131148, 'median_delay': 0.0},
#     20: {'builds_reqd': 9.42622950819672, 'median_delay': 0.0}},
#    8: {2: {'builds_reqd': 30.327868852459016, 'median_delay': 3.0},
#     3: {'builds_reqd': 26.024590163934427, 'median_delay': 3.0},
#     4: {'builds_reqd': 23.36065573770492, 'median_delay': 2.0},
#     5: {'builds_reqd': 22.131147540983605, 'median_delay': 2.0},
#     6: {'builds_reqd': 25.0, 'median_delay': 2.0},
#     7: {'builds_reqd': 25.0, 'median_delay': 1.0},
#     8: {'builds_reqd': 21.516393442622952, 'median_delay': 1.0},
#     9: {'builds_reqd': 20.28688524590164, 'median_delay': 1.0},
#     10: {'builds_reqd': 24.385245901639344, 'median_delay': 1.0},
#     11: {'builds_reqd': 18.0327868852459, 'median_delay': 0.0},
#     12: {'builds_reqd': 14.754098360655735, 'median_delay': 0.0},
#     13: {'builds_reqd': 14.549180327868852, 'median_delay': 0.0},
#     14: {'builds_reqd': 17.21311475409836, 'median_delay': 0.0},
#     15: {'builds_reqd': 18.237704918032787, 'median_delay': 0.0},
#     16: {'builds_reqd': 20.28688524590164, 'median_delay': 0.0},
#     17: {'builds_reqd': 14.549180327868852, 'median_delay': 0.0},
#     18: {'builds_reqd': 14.754098360655735, 'median_delay': 0.0},
#     19: {'builds_reqd': 14.344262295081966, 'median_delay': 0.0},
#     20: {'builds_reqd': 15.368852459016392, 'median_delay': 0.0}},
#    16: {2: {'builds_reqd': 31.762295081967213, 'median_delay': 7.0},
#     3: {'builds_reqd': 32.17213114754098, 'median_delay': 7.0},
#     4: {'builds_reqd': 29.098360655737704, 'median_delay': 7.0},
#     5: {'builds_reqd': 28.07377049180328, 'median_delay': 6.0},
#     6: {'builds_reqd': 29.71311475409836, 'median_delay': 6.0},
#     7: {'builds_reqd': 31.14754098360656, 'median_delay': 6.0},
#     8: {'builds_reqd': 26.4344262295082, 'median_delay': 6.0},
#     9: {'builds_reqd': 26.639344262295083, 'median_delay': 5.0},
#     10: {'builds_reqd': 27.459016393442624, 'median_delay': 5.0},
#     11: {'builds_reqd': 25.614754098360656, 'median_delay': 5.0},
#     12: {'builds_reqd': 19.672131147540984, 'median_delay': 3.0},
#     13: {'builds_reqd': 19.057377049180328, 'median_delay': 4.0},
#     14: {'builds_reqd': 21.92622950819672, 'median_delay': 4.0},
#     15: {'builds_reqd': 25.0, 'median_delay': 4.0},
#     16: {'builds_reqd': 19.672131147540984, 'median_delay': 3.0},
#     17: {'builds_reqd': 14.344262295081966, 'median_delay': 2.0},
#     18: {'builds_reqd': 14.344262295081966, 'median_delay': 2.0},
#     19: {'builds_reqd': 15.98360655737705, 'median_delay': 2.0},
#     20: {'builds_reqd': 17.62295081967213, 'median_delay': 2.0}}},
#   'BATCH4': {4: {2: {'builds_reqd': 30.327868852459016, 'median_delay': 1.0},
#     3: {'builds_reqd': 29.098360655737704, 'median_delay': 1.0},
#     4: {'builds_reqd': 27.049180327868854, 'median_delay': 0.0},
#     5: {'builds_reqd': 20.28688524590164, 'median_delay': 0.0},
#     6: {'builds_reqd': 21.72131147540984, 'median_delay': 0.0},
#     7: {'builds_reqd': 16.598360655737704, 'median_delay': 0.0},
#     8: {'builds_reqd': 16.598360655737704, 'median_delay': 0.0},
#     9: {'builds_reqd': 14.959016393442624, 'median_delay': 0.0},
#     10: {'builds_reqd': 16.39344262295082, 'median_delay': 0.0},
#     11: {'builds_reqd': 15.778688524590164, 'median_delay': 0.0},
#     12: {'builds_reqd': 9.836065573770492, 'median_delay': 0.0},
#     13: {'builds_reqd': 9.631147540983608, 'median_delay': 0.0},
#     14: {'builds_reqd': 9.631147540983608, 'median_delay': 0.0},
#     15: {'builds_reqd': 7.581967213114754, 'median_delay': 0.0},
#     16: {'builds_reqd': 13.114754098360656, 'median_delay': 0.0},
#     17: {'builds_reqd': 6.967213114754099, 'median_delay': 0.0},
#     18: {'builds_reqd': 11.68032786885246, 'median_delay': 0.0},
#     19: {'builds_reqd': 10.450819672131148, 'median_delay': 0.0},
#     20: {'builds_reqd': 9.42622950819672, 'median_delay': 0.0}}},
#   'BATCHBISECT': {1: {2: {'builds_reqd': 51.02459016393443,
#      'median_delay': 0.0},
#     3: {'builds_reqd': 34.01639344262295, 'median_delay': 0.0},
#     4: {'builds_reqd': 25.81967213114754, 'median_delay': 0.0},
#     5: {'builds_reqd': 20.28688524590164, 'median_delay': 0.0},
#     6: {'builds_reqd': 17.418032786885245, 'median_delay': 0.0},
#     7: {'builds_reqd': 15.163934426229508, 'median_delay': 0.0},
#     8: {'builds_reqd': 13.31967213114754, 'median_delay': 0.0},
#     9: {'builds_reqd': 11.885245901639344, 'median_delay': 0.0},
#     10: {'builds_reqd': 10.245901639344265, 'median_delay': 0.0},
#     11: {'builds_reqd': 9.42622950819672, 'median_delay': 0.0},
#     12: {'builds_reqd': 8.60655737704918, 'median_delay': 0.0},
#     13: {'builds_reqd': 7.991803278688525, 'median_delay': 0.0},
#     14: {'builds_reqd': 7.172131147540983, 'median_delay': 0.0},
#     15: {'builds_reqd': 6.762295081967213, 'median_delay': 0.0},
#     16: {'builds_reqd': 6.967213114754099, 'median_delay': 0.0},
#     17: {'builds_reqd': 6.352459016393443, 'median_delay': 0.0},
#     18: {'builds_reqd': 5.942622950819672, 'median_delay': 0.0},
#     19: {'builds_reqd': 5.327868852459017, 'median_delay': 0.0},
#     20: {'builds_reqd': 5.122950819672131, 'median_delay': 0.0}},
#    2: {2: {'builds_reqd': 38.9344262295082, 'median_delay': 0.0},
#     3: {'builds_reqd': 29.098360655737704, 'median_delay': 0.0},
#     4: {'builds_reqd': 22.74590163934426, 'median_delay': 0.0},
#     5: {'builds_reqd': 20.49180327868853, 'median_delay': 0.0},
#     6: {'builds_reqd': 18.64754098360656, 'median_delay': 0.0},
#     7: {'builds_reqd': 16.598360655737704, 'median_delay': 0.0},
#     8: {'builds_reqd': 13.934426229508198, 'median_delay': 0.0},
#     9: {'builds_reqd': 11.885245901639344, 'median_delay': 0.0},
#     10: {'builds_reqd': 10.245901639344265, 'median_delay': 0.0},
#     11: {'builds_reqd': 11.68032786885246, 'median_delay': 0.0},
#     12: {'builds_reqd': 10.040983606557376, 'median_delay': 0.0},
#     13: {'builds_reqd': 11.270491803278688, 'median_delay': 0.0},
#     14: {'builds_reqd': 9.01639344262295, 'median_delay': 0.0},
#     15: {'builds_reqd': 9.221311475409836, 'median_delay': 0.0},
#     16: {'builds_reqd': 7.581967213114754, 'median_delay': 0.0},
#     17: {'builds_reqd': 6.762295081967213, 'median_delay': 0.0},
#     18: {'builds_reqd': 7.581967213114754, 'median_delay': 0.0},
#     19: {'builds_reqd': 6.762295081967213, 'median_delay': 0.0},
#     20: {'builds_reqd': 7.172131147540983, 'median_delay': 0.0}},
#    4: {2: {'builds_reqd': 30.737704918032787, 'median_delay': 1.0},
#     3: {'builds_reqd': 29.508196721311474, 'median_delay': 1.0},
#     4: {'builds_reqd': 27.459016393442624, 'median_delay': 0.0},
#     5: {'builds_reqd': 21.516393442622952, 'median_delay': 0.0},
#     6: {'builds_reqd': 22.131147540983605, 'median_delay': 0.0},
#     7: {'builds_reqd': 17.008196721311474, 'median_delay': 0.0},
#     8: {'builds_reqd': 17.008196721311474, 'median_delay': 0.0},
#     9: {'builds_reqd': 15.778688524590164, 'median_delay': 0.0},
#     10: {'builds_reqd': 17.21311475409836, 'median_delay': 0.0},
#     11: {'builds_reqd': 16.188524590163933, 'median_delay': 0.0},
#     12: {'builds_reqd': 10.245901639344265, 'median_delay': 0.0},
#     13: {'builds_reqd': 10.450819672131148, 'median_delay': 0.0},
#     14: {'builds_reqd': 10.040983606557376, 'median_delay': 0.0},
#     15: {'builds_reqd': 7.991803278688525, 'median_delay': 0.0},
#     16: {'builds_reqd': 13.524590163934429, 'median_delay': 0.0},
#     17: {'builds_reqd': 7.377049180327869, 'median_delay': 0.0},
#     18: {'builds_reqd': 12.09016393442623, 'median_delay': 0.0},
#     19: {'builds_reqd': 10.86065573770492, 'median_delay': 0.0},
#     20: {'builds_reqd': 9.836065573770492, 'median_delay': 0.0}},
#    8: {2: {'builds_reqd': 31.14754098360656, 'median_delay': 3.0},
#     3: {'builds_reqd': 26.4344262295082, 'median_delay': 3.0},
#     4: {'builds_reqd': 24.59016393442623, 'median_delay': 2.0},
#     5: {'builds_reqd': 22.950819672131143, 'median_delay': 2.0},
#     6: {'builds_reqd': 25.40983606557377, 'median_delay': 2.0},
#     7: {'builds_reqd': 25.0, 'median_delay': 1.0},
#     8: {'builds_reqd': 21.516393442622952, 'median_delay': 1.0},
#     9: {'builds_reqd': 21.10655737704918, 'median_delay': 1.0},
#     10: {'builds_reqd': 25.204918032786885, 'median_delay': 1.0},
#     11: {'builds_reqd': 18.852459016393443, 'median_delay': 0.0},
#     12: {'builds_reqd': 15.57377049180328, 'median_delay': 0.0},
#     13: {'builds_reqd': 15.368852459016392, 'median_delay': 0.0},
#     14: {'builds_reqd': 17.21311475409836, 'median_delay': 0.0},
#     15: {'builds_reqd': 19.057377049180328, 'median_delay': 0.0},
#     16: {'builds_reqd': 21.10655737704918, 'median_delay': 0.0},
#     17: {'builds_reqd': 15.368852459016392, 'median_delay': 0.0},
#     18: {'builds_reqd': 15.57377049180328, 'median_delay': 0.0},
#     19: {'builds_reqd': 15.163934426229508, 'median_delay': 0.0},
#     20: {'builds_reqd': 16.188524590163933, 'median_delay': 0.0}},
#    16: {2: {'builds_reqd': 31.762295081967213, 'median_delay': 7.0},
#     3: {'builds_reqd': 32.17213114754098, 'median_delay': 7.0},
#     4: {'builds_reqd': 29.918032786885245, 'median_delay': 7.0},
#     5: {'builds_reqd': 28.89344262295082, 'median_delay': 6.0},
#     6: {'builds_reqd': 30.12295081967213, 'median_delay': 6.0},
#     7: {'builds_reqd': 31.14754098360656, 'median_delay': 6.0},
#     8: {'builds_reqd': 27.66393442622951, 'median_delay': 6.0},
#     9: {'builds_reqd': 27.868852459016395, 'median_delay': 5.0},
#     10: {'builds_reqd': 28.27868852459016, 'median_delay': 5.0},
#     11: {'builds_reqd': 26.4344262295082, 'median_delay': 5.0},
#     12: {'builds_reqd': 19.672131147540984, 'median_delay': 3.0},
#     13: {'builds_reqd': 20.28688524590164, 'median_delay': 4.0},
#     14: {'builds_reqd': 22.74590163934426, 'median_delay': 4.0},
#     15: {'builds_reqd': 25.81967213114754, 'median_delay': 4.0},
#     16: {'builds_reqd': 20.49180327868853, 'median_delay': 3.0},
#     17: {'builds_reqd': 15.163934426229508, 'median_delay': 2.0},
#     18: {'builds_reqd': 15.163934426229508, 'median_delay': 2.0},
#     19: {'builds_reqd': 17.21311475409836, 'median_delay': 2.0},
#     20: {'builds_reqd': 18.442622950819672, 'median_delay': 2.0}}}},
#  'sonarqube.csv': {'BATCHSTOP4': {4: {2: {'builds_reqd': 41.0,
#      'median_delay': 1.0},
#     3: {'builds_reqd': 38.333333333333336, 'median_delay': 1.0},
#     4: {'builds_reqd': 37.333333333333336, 'median_delay': 0.5},
#     5: {'builds_reqd': 27.666666666666668, 'median_delay': 0.0},
#     6: {'builds_reqd': 33.333333333333336, 'median_delay': 0.0},
#     7: {'builds_reqd': 27.33333333333333, 'median_delay': 0.0},
#     8: {'builds_reqd': 25.33333333333333, 'median_delay': 0.0},
#     9: {'builds_reqd': 18.0, 'median_delay': 0.0},
#     10: {'builds_reqd': 27.33333333333333, 'median_delay': 0.0},
#     11: {'builds_reqd': 18.33333333333333, 'median_delay': 0.0},
#     12: {'builds_reqd': 20.666666666666668, 'median_delay': 0.0},
#     13: {'builds_reqd': 17.666666666666668, 'median_delay': 0.0},
#     14: {'builds_reqd': 11.333333333333334, 'median_delay': 0.0},
#     15: {'builds_reqd': 21.0, 'median_delay': 0.0},
#     16: {'builds_reqd': 15.666666666666666, 'median_delay': 0.0},
#     17: {'builds_reqd': 13.333333333333334, 'median_delay': 0.0},
#     18: {'builds_reqd': 9.666666666666666, 'median_delay': 0.0},
#     19: {'builds_reqd': 13.666666666666666, 'median_delay': 0.0},
#     20: {'builds_reqd': 11.333333333333334, 'median_delay': 0.0}},
#    8: {2: {'builds_reqd': 51.0, 'median_delay': 3.0},
#     3: {'builds_reqd': 45.66666666666666, 'median_delay': 3.0},
#     4: {'builds_reqd': 41.66666666666666, 'median_delay': 3.0},
#     5: {'builds_reqd': 48.333333333333336, 'median_delay': 3.0},
#     6: {'builds_reqd': 50.0, 'median_delay': 3.0},
#     7: {'builds_reqd': 45.66666666666666, 'median_delay': 2.0},
#     8: {'builds_reqd': 40.66666666666666, 'median_delay': 2.0},
#     9: {'builds_reqd': 37.0, 'median_delay': 1.5},
#     10: {'builds_reqd': 38.333333333333336, 'median_delay': 1.0},
#     11: {'builds_reqd': 39.0, 'median_delay': 1.0},
#     12: {'builds_reqd': 33.0, 'median_delay': 1.0},
#     13: {'builds_reqd': 39.66666666666666, 'median_delay': 1.0},
#     14: {'builds_reqd': 35.666666666666664, 'median_delay': 1.0},
#     15: {'builds_reqd': 35.666666666666664, 'median_delay': 0.0},
#     16: {'builds_reqd': 32.0, 'median_delay': 0.0},
#     17: {'builds_reqd': 34.666666666666664, 'median_delay': 1.0},
#     18: {'builds_reqd': 29.0, 'median_delay': 0.0},
#     19: {'builds_reqd': 31.33333333333333, 'median_delay': 0.0},
#     20: {'builds_reqd': 31.33333333333333, 'median_delay': 0.0}},
#    16: {2: {'builds_reqd': 55.66666666666666, 'median_delay': 7.0},
#     3: {'builds_reqd': 53.333333333333336, 'median_delay': 7.0},
#     4: {'builds_reqd': 53.0, 'median_delay': 7.0},
#     5: {'builds_reqd': 54.0, 'median_delay': 7.0},
#     6: {'builds_reqd': 50.333333333333336, 'median_delay': 7.0},
#     7: {'builds_reqd': 52.333333333333336, 'median_delay': 7.0},
#     8: {'builds_reqd': 51.0, 'median_delay': 6.0},
#     9: {'builds_reqd': 51.66666666666666, 'median_delay': 6.0},
#     10: {'builds_reqd': 50.0, 'median_delay': 6.0},
#     11: {'builds_reqd': 54.333333333333336, 'median_delay': 6.0},
#     12: {'builds_reqd': 43.333333333333336, 'median_delay': 5.5},
#     13: {'builds_reqd': 52.333333333333336, 'median_delay': 6.0},
#     14: {'builds_reqd': 52.0, 'median_delay': 6.0},
#     15: {'builds_reqd': 50.66666666666666, 'median_delay': 6.0},
#     16: {'builds_reqd': 49.0, 'median_delay': 6.0},
#     17: {'builds_reqd': 52.0, 'median_delay': 6.0},
#     18: {'builds_reqd': 47.0, 'median_delay': 5.5},
#     19: {'builds_reqd': 44.333333333333336, 'median_delay': 5.0},
#     20: {'builds_reqd': 43.66666666666666, 'median_delay': 5.0}}},
#   'BATCH4': {4: {2: {'builds_reqd': 41.0, 'median_delay': 1.0},
#     3: {'builds_reqd': 38.333333333333336, 'median_delay': 1.0},
#     4: {'builds_reqd': 37.333333333333336, 'median_delay': 0.5},
#     5: {'builds_reqd': 27.666666666666668, 'median_delay': 0.0},
#     6: {'builds_reqd': 33.333333333333336, 'median_delay': 0.0},
#     7: {'builds_reqd': 27.33333333333333, 'median_delay': 0.0},
#     8: {'builds_reqd': 25.33333333333333, 'median_delay': 0.0},
#     9: {'builds_reqd': 18.0, 'median_delay': 0.0},
# ...
#     14: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     15: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     16: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     17: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     18: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     19: {'builds_reqd': 0.0, 'median_delay': 0},
#     20: {'builds_reqd': 0.0, 'median_delay': 0}},
#    2: {2: {'builds_reqd': 42.10526315789474, 'median_delay': 0},
#     3: {'builds_reqd': 21.05263157894737, 'median_delay': 0},
#     4: {'builds_reqd': 31.57894736842105, 'median_delay': 0},
#     5: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     6: {'builds_reqd': 26.31578947368421, 'median_delay': 0},
#     7: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     8: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     9: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     10: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     11: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     12: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     13: {'builds_reqd': 21.05263157894737, 'median_delay': 0},
#     14: {'builds_reqd': 21.05263157894737, 'median_delay': 0},
#     15: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     16: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     17: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     18: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     19: {'builds_reqd': 0.0, 'median_delay': 0},
#     20: {'builds_reqd': 0.0, 'median_delay': 0}},
#    4: {2: {'builds_reqd': 52.63157894736842, 'median_delay': 1},
#     3: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     4: {'builds_reqd': 36.8421052631579, 'median_delay': 0},
#     5: {'builds_reqd': 42.10526315789474, 'median_delay': 0},
#     6: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     7: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     8: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     9: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     10: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     11: {'builds_reqd': 31.57894736842105, 'median_delay': 0},
#     12: {'builds_reqd': 42.10526315789474, 'median_delay': 0},
#     13: {'builds_reqd': 36.8421052631579, 'median_delay': 0},
#     14: {'builds_reqd': 31.57894736842105, 'median_delay': 0},
#     15: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     16: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     17: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     18: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     19: {'builds_reqd': 0.0, 'median_delay': 0},
#     20: {'builds_reqd': 0.0, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 42.10526315789474, 'median_delay': 3},
#     3: {'builds_reqd': 36.8421052631579, 'median_delay': 3},
#     4: {'builds_reqd': 26.31578947368421, 'median_delay': 2},
#     5: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     6: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     7: {'builds_reqd': 57.89473684210526, 'median_delay': 2},
#     8: {'builds_reqd': 52.63157894736842, 'median_delay': 1},
#     9: {'builds_reqd': 47.36842105263158, 'median_delay': 0},
#     10: {'builds_reqd': 42.10526315789474, 'median_delay': 0},
#     11: {'builds_reqd': 36.8421052631579, 'median_delay': 0},
#     12: {'builds_reqd': 36.8421052631579, 'median_delay': 0},
#     13: {'builds_reqd': 31.57894736842105, 'median_delay': 0},
#     14: {'builds_reqd': 26.31578947368421, 'median_delay': 0},
#     15: {'builds_reqd': 21.05263157894737, 'median_delay': 0},
#     16: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     17: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     18: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     19: {'builds_reqd': 0.0, 'median_delay': 0},
#     20: {'builds_reqd': 0.0, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 52.63157894736842, 'median_delay': 7},
#     3: {'builds_reqd': 47.36842105263158, 'median_delay': 6},
#     4: {'builds_reqd': 78.94736842105263, 'median_delay': 6},
#     5: {'builds_reqd': 73.6842105263158, 'median_delay': 6},
#     6: {'builds_reqd': 68.42105263157895, 'median_delay': 6},
#     7: {'builds_reqd': 63.1578947368421, 'median_delay': 6},
#     8: {'builds_reqd': 57.89473684210526, 'median_delay': 6},
#     9: {'builds_reqd': 52.63157894736842, 'median_delay': 6},
#     10: {'builds_reqd': 47.36842105263158, 'median_delay': 0},
#     11: {'builds_reqd': 42.10526315789474, 'median_delay': 0},
#     12: {'builds_reqd': 36.8421052631579, 'median_delay': 0},
#     13: {'builds_reqd': 31.57894736842105, 'median_delay': 0},
#     14: {'builds_reqd': 26.31578947368421, 'median_delay': 0},
#     15: {'builds_reqd': 21.05263157894737, 'median_delay': 0},
#     16: {'builds_reqd': 15.789473684210526, 'median_delay': 0},
#     17: {'builds_reqd': 10.526315789473683, 'median_delay': 0},
#     18: {'builds_reqd': 5.2631578947368425, 'median_delay': 0},
#     19: {'builds_reqd': 0.0, 'median_delay': 0},
#     20: {'builds_reqd': 0.0, 'median_delay': 0}}}},
#  'rails.csv': {'BATCHSTOP4': {4: {2: {'builds_reqd': 54.23155044008124,
#      'median_delay': 1},
#     3: {'builds_reqd': 48.20582261340555, 'median_delay': 1},
#     4: {'builds_reqd': 44.68517264725796, 'median_delay': 1},
#     5: {'builds_reqd': 40.48747461069736, 'median_delay': 0},
#     6: {'builds_reqd': 36.76371022342586, 'median_delay': 0},
#     7: {'builds_reqd': 37.779282329045365, 'median_delay': 0},
#     8: {'builds_reqd': 32.566012186865265, 'median_delay': 0},
#     9: {'builds_reqd': 28.029790115098173, 'median_delay': 0},
#     10: {'builds_reqd': 29.85781990521327, 'median_delay': 0},
#     11: {'builds_reqd': 27.55585646580907, 'median_delay': 0},
#     12: {'builds_reqd': 27.14962762356128, 'median_delay': 0},
#     13: {'builds_reqd': 24.44143534190928, 'median_delay': 0},
#     14: {'builds_reqd': 28.50372376438727, 'median_delay': 0},
#     15: {'builds_reqd': 27.14962762356128, 'median_delay': 0},
#     16: {'builds_reqd': 22.68111035883548, 'median_delay': 0},
#     17: {'builds_reqd': 23.290453622207178, 'median_delay': 0},
#     18: {'builds_reqd': 21.80094786729858, 'median_delay': 0},
#     19: {'builds_reqd': 21.05619498984428, 'median_delay': 0},
#     20: {'builds_reqd': 17.603249830737983, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 60.05416384563304, 'median_delay': 3},
#     3: {'builds_reqd': 57.68449559918754, 'median_delay': 3},
#     4: {'builds_reqd': 57.27826675693974, 'median_delay': 3},
#     5: {'builds_reqd': 49.55991875423155, 'median_delay': 3},
#     6: {'builds_reqd': 52.20040622884225, 'median_delay': 3},
#     7: {'builds_reqd': 51.726472579553146, 'median_delay': 2},
#     8: {'builds_reqd': 48.00270819228165, 'median_delay': 2},
#     9: {'builds_reqd': 44.95599187542315, 'median_delay': 2},
#     10: {'builds_reqd': 43.26337169939065, 'median_delay': 2},
#     11: {'builds_reqd': 43.39878131347326, 'median_delay': 2},
#     12: {'builds_reqd': 43.534190927555855, 'median_delay': 1},
#     13: {'builds_reqd': 41.36763710223426, 'median_delay': 1},
#     14: {'builds_reqd': 39.40419769803656, 'median_delay': 1},
#     15: {'builds_reqd': 43.33107650643196, 'median_delay': 1},
#     16: {'builds_reqd': 41.57075152335816, 'median_delay': 1},
#     17: {'builds_reqd': 37.779282329045365, 'median_delay': 1},
#     18: {'builds_reqd': 37.576167907921466, 'median_delay': 1},
#     19: {'builds_reqd': 39.13337846987136, 'median_delay': 1},
#     20: {'builds_reqd': 33.446174678402166, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 66.07989167230873, 'median_delay': 7},
#     3: {'builds_reqd': 68.24644549763033, 'median_delay': 7},
#     4: {'builds_reqd': 63.100880162491535, 'median_delay': 7},
#     5: {'builds_reqd': 62.694651320243736, 'median_delay': 7},
#     6: {'builds_reqd': 62.22071767095464, 'median_delay': 7},
#     7: {'builds_reqd': 64.79350033852404, 'median_delay': 7},
#     8: {'builds_reqd': 62.15301286391334, 'median_delay': 7},
#     9: {'builds_reqd': 62.017603249830735, 'median_delay': 7},
#     10: {'builds_reqd': 61.27285037237644, 'median_delay': 7},
#     11: {'builds_reqd': 58.97088693297224, 'median_delay': 7},
#     12: {'builds_reqd': 58.97088693297224, 'median_delay': 7},
#     13: {'builds_reqd': 58.63236289776574, 'median_delay': 6},
#     14: {'builds_reqd': 58.22613405551794, 'median_delay': 6},
#     15: {'builds_reqd': 57.21056194989844, 'median_delay': 6},
#     16: {'builds_reqd': 57.68449559918754, 'median_delay': 6},
#     17: {'builds_reqd': 58.70006770480704, 'median_delay': 6},
#     18: {'builds_reqd': 60.93432633716994, 'median_delay': 6},
#     19: {'builds_reqd': 59.44482058226134, 'median_delay': 6},
#     20: {'builds_reqd': 58.15842924847664, 'median_delay': 6}}},
#   'BATCH4': {4: {2: {'builds_reqd': 54.23155044008124, 'median_delay': 1},
#     3: {'builds_reqd': 48.20582261340555, 'median_delay': 1},
#     4: {'builds_reqd': 44.68517264725796, 'median_delay': 1},
#     5: {'builds_reqd': 40.48747461069736, 'median_delay': 0},
#     6: {'builds_reqd': 36.76371022342586, 'median_delay': 0},
#     7: {'builds_reqd': 37.779282329045365, 'median_delay': 0},
#     8: {'builds_reqd': 32.566012186865265, 'median_delay': 0},
#     9: {'builds_reqd': 28.029790115098173, 'median_delay': 0},
#     10: {'builds_reqd': 29.85781990521327, 'median_delay': 0},
#     11: {'builds_reqd': 27.55585646580907, 'median_delay': 0},
#     12: {'builds_reqd': 27.14962762356128, 'median_delay': 0},
#     13: {'builds_reqd': 24.44143534190928, 'median_delay': 0},
#     14: {'builds_reqd': 28.50372376438727, 'median_delay': 0},
#     15: {'builds_reqd': 27.14962762356128, 'median_delay': 0},
#     16: {'builds_reqd': 22.68111035883548, 'median_delay': 0},
#     17: {'builds_reqd': 23.290453622207178, 'median_delay': 0},
#     18: {'builds_reqd': 21.80094786729858, 'median_delay': 0},
#     19: {'builds_reqd': 21.05619498984428, 'median_delay': 0},
#     20: {'builds_reqd': 17.603249830737983, 'median_delay': 0}}},
#   'BATCHBISECT': {1: {2: {'builds_reqd': 52.60663507109005, 'median_delay': 0},
#     3: {'builds_reqd': 36.08666215301287, 'median_delay': 0},
#     4: {'builds_reqd': 27.69126607989168, 'median_delay': 0},
#     5: {'builds_reqd': 22.95192958700068, 'median_delay': 0},
#     6: {'builds_reqd': 19.22816519972918, 'median_delay': 0},
#     7: {'builds_reqd': 16.993906567366285, 'median_delay': 0},
#     8: {'builds_reqd': 15.165876777251183, 'median_delay': 0},
#     9: {'builds_reqd': 12.999322951929589, 'median_delay': 0},
#     10: {'builds_reqd': 12.186865267433989, 'median_delay': 0},
#     11: {'builds_reqd': 11.712931618144887, 'median_delay': 0},
#     12: {'builds_reqd': 10.561949898442789, 'median_delay': 0},
#     13: {'builds_reqd': 9.81719702098849, 'median_delay': 0},
#     14: {'builds_reqd': 9.14014895057549, 'median_delay': 0},
#     15: {'builds_reqd': 8.463100880162491, 'median_delay': 0},
#     16: {'builds_reqd': 7.989167230873392, 'median_delay': 0},
#     17: {'builds_reqd': 7.921462423832092, 'median_delay': 0},
#     18: {'builds_reqd': 7.379823967501693, 'median_delay': 0},
#     19: {'builds_reqd': 7.312119160460393, 'median_delay': 0},
#     20: {'builds_reqd': 7.041299932295193, 'median_delay': 0}},
#    2: {2: {'builds_reqd': 50.10155721056195, 'median_delay': 0},
#     3: {'builds_reqd': 40.21665538253216, 'median_delay': 0},
#     4: {'builds_reqd': 32.29519295870007, 'median_delay': 0},
#     5: {'builds_reqd': 25.863236289776573, 'median_delay': 0},
#     6: {'builds_reqd': 24.37373053486797, 'median_delay': 0},
#     7: {'builds_reqd': 21.80094786729858, 'median_delay': 0},
#     8: {'builds_reqd': 18.95734597156398, 'median_delay': 0},
#     9: {'builds_reqd': 18.348002708192283, 'median_delay': 0},
#     10: {'builds_reqd': 17.197020988490184, 'median_delay': 0},
#     11: {'builds_reqd': 15.910629654705485, 'median_delay': 0},
#     12: {'builds_reqd': 15.707515233581583, 'median_delay': 0},
#     13: {'builds_reqd': 13.337846987136087, 'median_delay': 0},
#     14: {'builds_reqd': 13.134732566012186, 'median_delay': 0},
#     15: {'builds_reqd': 13.676371022342586, 'median_delay': 0},
#     16: {'builds_reqd': 12.186865267433989, 'median_delay': 0},
#     17: {'builds_reqd': 11.712931618144887, 'median_delay': 0},
#     18: {'builds_reqd': 11.44211238997969, 'median_delay': 0},
#     19: {'builds_reqd': 9.68178740690589, 'median_delay': 0},
#     20: {'builds_reqd': 11.306702775897088, 'median_delay': 0}},
#    4: {2: {'builds_reqd': 55.856465809072446, 'median_delay': 1},
#     3: {'builds_reqd': 49.96614759647935, 'median_delay': 1},
#     4: {'builds_reqd': 46.31008801624915, 'median_delay': 1},
#     5: {'builds_reqd': 42.24779959377116, 'median_delay': 0},
#     6: {'builds_reqd': 38.25321597833446, 'median_delay': 0},
#     7: {'builds_reqd': 39.13337846987136, 'median_delay': 0},
#     8: {'builds_reqd': 34.055517941773864, 'median_delay': 0},
#     9: {'builds_reqd': 29.38388625592417, 'median_delay': 0},
#     10: {'builds_reqd': 31.211916046039267, 'median_delay': 0},
#     11: {'builds_reqd': 28.50372376438727, 'median_delay': 0},
#     12: {'builds_reqd': 28.23290453622208, 'median_delay': 0},
#     13: {'builds_reqd': 25.66012186865268, 'median_delay': 0},
#     14: {'builds_reqd': 29.58700067704807, 'median_delay': 0},
#     15: {'builds_reqd': 28.23290453622208, 'median_delay': 0},
#     16: {'builds_reqd': 23.764387271496275, 'median_delay': 0},
#     17: {'builds_reqd': 24.238320920785377, 'median_delay': 0},
#     18: {'builds_reqd': 22.88422477995938, 'median_delay': 0},
#     19: {'builds_reqd': 22.00406228842248, 'median_delay': 0},
#     20: {'builds_reqd': 18.41570751523358, 'median_delay': 0}},
#    8: {2: {'builds_reqd': 62.35612728503724, 'median_delay': 3},
#     3: {'builds_reqd': 60.12186865267434, 'median_delay': 3},
#     4: {'builds_reqd': 59.44482058226134, 'median_delay': 3},
#     5: {'builds_reqd': 51.99729180771835, 'median_delay': 3},
#     6: {'builds_reqd': 54.36696005416385, 'median_delay': 3},
#     7: {'builds_reqd': 53.75761679079215, 'median_delay': 2},
#     8: {'builds_reqd': 50.03385240352065, 'median_delay': 2},
#     9: {'builds_reqd': 46.85172647257955, 'median_delay': 2},
#     10: {'builds_reqd': 45.02369668246445, 'median_delay': 2},
#     11: {'builds_reqd': 45.15910629654705, 'median_delay': 2},
#     12: {'builds_reqd': 45.15910629654705, 'median_delay': 1},
#     13: {'builds_reqd': 42.72173324306026, 'median_delay': 1},
#     14: {'builds_reqd': 40.75829383886256, 'median_delay': 1},
#     15: {'builds_reqd': 45.09140148950576, 'median_delay': 1},
#     16: {'builds_reqd': 43.19566689234936, 'median_delay': 1},
#     17: {'builds_reqd': 39.40419769803656, 'median_delay': 1},
#     18: {'builds_reqd': 39.20108327691266, 'median_delay': 1},
#     19: {'builds_reqd': 40.75829383886256, 'median_delay': 1},
#     20: {'builds_reqd': 34.258632362897764, 'median_delay': 0}},
#    16: {2: {'builds_reqd': 68.38185511171294, 'median_delay': 7},
#     3: {'builds_reqd': 70.00677048070413, 'median_delay': 7},
#     4: {'builds_reqd': 65.13202437373053, 'median_delay': 7},
#     5: {'builds_reqd': 64.72579553148273, 'median_delay': 7},
#     6: {'builds_reqd': 64.38727149627624, 'median_delay': 7},
#     7: {'builds_reqd': 66.55382532159783, 'median_delay': 7},
#     8: {'builds_reqd': 64.31956668923493, 'median_delay': 7},
#     9: {'builds_reqd': 64.04874746106974, 'median_delay': 7},
#     10: {'builds_reqd': 63.57481381178064, 'median_delay': 7},
#     11: {'builds_reqd': 61.40825998645904, 'median_delay': 7},
#     12: {'builds_reqd': 60.86662153012864, 'median_delay': 7},
#     13: {'builds_reqd': 60.79891672308734, 'median_delay': 6},
#     14: {'builds_reqd': 59.98645903859174, 'median_delay': 6},
#     15: {'builds_reqd': 59.24170616113744, 'median_delay': 6},
#     16: {'builds_reqd': 59.71563981042654, 'median_delay': 6},
#     17: {'builds_reqd': 60.73121191604604, 'median_delay': 6},
#     18: {'builds_reqd': 62.83006093432634, 'median_delay': 6},
#     19: {'builds_reqd': 61.88219363574814, 'median_delay': 6},
#     20: {'builds_reqd': 60.46039268788084, 'median_delay': 6}}}}}

# %%
lines = []
for p in ssr_delay_lib:
    for alg in ssr_delay_lib[p]:
        for b in ssr_delay_lib[p][alg]:
            for c in ssr_delay_lib[p][alg][b]:
                d = ssr_delay_lib[p][alg][b][c]
                lines.append([p, 'ssr', alg, b, c, d['builds_reqd'], d['median_delay']])

# %%
df = pd.DataFrame(lines, columns=['project', 'method', 'algorithm', 'batch_size', 'confidence', 'builds_reqd', 'total_delays'])

# %%
df.to_csv('ssr_confidence_all_projects_median.csv')
