# %%
import pandas as pd
import numpy as np
from numpy import argmax
from numpy import sqrt
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.utils import resample
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from matplotlib import pyplot
from statistics import median
import pickle
import csv
import warnings
import datetime
import multiprocess
warnings.filterwarnings("ignore")

# %%
project_list = ['geoserver', 'gradle', 'cloud_controller_ng', 'opal', 'jruby', 'cloudify', 'chef', 'orbeon-forms', 'vagrant']

# %%
def output_values(Y_data):
    Y_t = []
    for e in Y_data:
        if e == 'passed':
            Y_t.append(1)
        else:
            Y_t.append(0) 
    return Y_t

# %%
def get_pass_streak(y_project):
    p = y_project[0]
    pass_streak = [y_project[0]]
    for i in range(1, len(y_project)):
        pass_streak.append(p)
        if y_project[i] == 1:
            p += 1
        else:
            p = 0
    return pass_streak

# %%
def get_first_failures(df):
    
    results = df['tr_status'].tolist()
    length = len(results)
    verdict = ['keep']
    prev = results[0]
    
    for i in range(1, length):
        if results[i] == 0:
            if prev == 0:
                verdict.append('discard')
                #print(i+1)
            else:
                verdict.append('keep')
        else:
            verdict.append('keep')
        prev = results[i]
    
    df['verdict'] = verdict
    df = df[ df['verdict'] == 'keep' ]
    df.drop('verdict', inplace=True, axis=1)
    return df

# %%
def get_complete_data(p_name):
    
    #open the metrics file
    filename = 'metrics_data/' + p_name + '_metrics.csv'
    project = pd.read_csv(filename)
    
    #clean the data & remove correlated columns
    project = project [ project['developer_experience'] >= 0]
    project.drop('num_commits', inplace=True, axis=1)
    project.drop('reviewer_experience', inplace=True, axis=1)
    project.drop('num_of_reviewers', inplace=True, axis=1)
    
    build_ids = project['tr_build_id'].tolist()
    #get results data
    res_file = '../data/' + p_name + '.csv'
    res_project = pd.read_csv(res_file, usecols = ['tr_build_id', 'gh_build_started_at', 'tr_status'])
    res_project['gh_build_started_at'] =  pd.to_datetime(res_project['gh_build_started_at'], format='%Y-%m-%d %H:%M:%S')
    y_project = res_project[res_project['tr_build_id'].isin(build_ids)]['tr_status'].tolist()
    y_project = output_values(y_project)
    
    #append date of build
    project_dates = res_project[res_project['tr_build_id'].isin(build_ids)]['gh_build_started_at'].tolist()
    project['gh_build_started_at'] = project_dates
    
    #add results column to the dataframe
    project['tr_status'] = y_project
    
    return project

# %%
def get_start_end_date(project):
    dates = project['gh_build_started_at'].tolist()
    
    start_date = dates[0] - datetime.timedelta(days = 1)
    end_date = dates[-1] - datetime.timedelta(days = 1)
    
    return start_date, end_date

# %%
def get_required_data(p_name, build_ids):
    
    res_file = '../data/' + p_name + '.csv'
    res_project = pd.read_csv(res_file, usecols = ['tr_build_id', 'tr_duration'])
    durations = res_project[res_project['tr_build_id'].isin(build_ids)]['tr_duration'].tolist()
    return durations

# %%
def compute_performance(p_name, test_builds, test_result, pred_result, verbosity):
    
    
    
    durations = get_required_data(p_name, test_builds)
    actual_duration = sum(durations)
    actual_failures = test_result.count(0)
    
    total_builds = len(test_builds)
    num_of_builds = 0
    total_duration = 0
    cbf = 0
    saved_builds = 0
    
    batch = []
    batch_duration = []
    actual_results = []
    max_batch_size = 4
    
    for i in range(len(pred_result)):
        if pred_result[i] == 0:
            
            if test_result[i] == 0:
                cbf += 1
                
            if len(batch) < max_batch_size:
                batch.append(pred_result[i])
                batch_duration.append(durations[i])
                actual_results.append(test_result[i])
            
            if len(batch) == max_batch_size:
                num_of_builds += 1
                total_duration += max(batch_duration)
                
                if 0 in actual_results:
                    num_of_builds += 4
                    total_duration += sum(batch_duration)
        else:
            saved_builds += 1
            
    if len(batch) > 0:
        num_of_builds += 1
        total_duration += max(batch_duration)
        
        if 0 in actual_results:
            num_of_builds += len(batch)
            total_duration += sum(batch_duration)
                    
    #Delay computation
    flag = 0
    count = 0
    delay = []
    for i in range(len(pred_result)):
        if flag == 1:
            if pred_result[i] == 1:
                count += 1
            
            if pred_result[i] == 0:
                delay.append(count)
                count = 0
                flag = 0
                
        if test_result[i] != 1:
            if pred_result[i] == 1:
                flag = 1
    delay.append(count)

    
    try:
        
        time_saved = 100*total_duration/actual_duration
        builds_saved = 100*saved_builds/total_builds
        reqd_builds = 100*num_of_builds/total_builds
        failed = 100*cbf/actual_failures
        median_delays = median(delay)
        total_delays = sum(delay)
        
        if verbosity:
    
            print("===========================================")
            print('The performance of the model is as follows:')
            print('\t Time Reqd : {}'.format(total_duration))
            print('\t % Time Reqd : {}%'.format(time_saved))
            print('\t Num. Builds saved : {}%'.format(saved_builds))
            print('\t % Builds saved : {}%'.format(builds_saved))
            print('\t Num. Builds required : {}'.format(num_of_builds))
            print('\t % Builds required : {}%'.format(reqd_builds))
            print('\t Num. Failed Builds Identified : {}'.format(cbf))
            print('\t % Failed Builds Identified : {}%'.format(failed))
            print('\t Median Delay Induced : {} builds'.format(median_delays))
            print('\t Total Delay Induced: {} builds'.format(total_delays))
            print('\t Total number of builds: {}'.format(total_builds))
            print('\t Total number of failed builds: {}'.format(actual_failures))
            print('\t Total Duration: {}'.format(actual_duration))
            print("===========================================")
        
    except:
        
        print('exception')
        return (0, 0, 0, 0, 0, 0)
    
    return (time_saved, builds_saved, reqd_builds, failed, median_delays, total_delays)

# %%
def hybrid_performance(p_name, test_builds, test_result, ci):
    total_builds = len(test_result)
    actual_builds_made = ci.count(0)//4
    
    
    durations = get_required_data(p_name, test_builds)
    build_time = []
    
    i = 0
    while i < len(test_result):
        if ci[i] == 0:
            batch = ci[i:i+4]
            build_time.append(max(durations[i:i+4]))
            i += 4
        else:
            i+=1
    
    time_reqd = 100*sum(build_time)/sum(durations)
    builds_reqd = 100*actual_builds_made/total_builds
    
    if len(ci) == len(test_result):
        if len(ci) == len(durations):
            print('Going right....')
            
    delay = []
    delay_indexes = []
    built_indexes = []
    for i in range(len(test_result)):
        if ci[i] == 0:
            built_indexes.append(i)
        if test_result[i] == 0:
            if ci[i] != 0:
                delay_indexes.append(i)
                
    num_of_failure_unidentified = len(delay_indexes)
    identified_failures = test_result.count(0) - num_of_failure_unidentified
    failures_found = 100*identified_failures/test_result.count(0)
    
#     print(delay_indexes)
#     print(built_indexes)
    from_value = 0
    
    for k in range(len(built_indexes)):
        for j in range(len(delay_indexes)):
            if delay_indexes[j] > from_value and delay_indexes[j] < built_indexes[k]:
                delay.append(built_indexes[k] - delay_indexes[j])
        from_value = built_indexes[k]
    
    if len(delay_indexes) != 0:
        final_index = len(test_result)
        for j in range(len(delay_indexes)):
            delay.append(final_index - delay_indexes[j])
    
#     print("===========================================")
#     print('Total Number of builds for {} = {}'.format(p_name, total_builds))
#     print('Total % of builds required for {} = {}'.format(p_name, builds_reqd))
#     print('Total % of time required for {} = {}'.format(p_name, time_reqd))
#     print('Total delays made for {} = {}'.format(p_name, sum(delay)))
#     print('Total % of failures identified for {} = {}'.format(p_name, failures_found))
#     print('Total % of failures unidentified for {} = {}'.format(p_name, 100*num_of_failure_unidentified/test_result.count(0)))
#     print("===========================================")
    
    return (time_reqd, builds_reqd, sum(delay), failures_found, 100*num_of_failure_unidentified/test_result.count(0))

# %%
def bootstrapping(p_name):
    
    print('Processing {}'.format(p_name))
    
    performances = {'time_reqd':[], 'builds_reqd':[], 'total_delay':[], 'failures_found':[], 'failures_not_found':[]}
    
    #This will return the entire dataset with X and Y values
    project = get_complete_data(p_name)
#     print(project)
#     print(list(project['tr_status']))
    start_date, end_date = get_start_end_date(project)
    
    #grid search hyperparameters
    n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
    max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
    
    #setting up grid search
    param_grid = {'n_estimators': n_estimators, 'max_depth': max_depth}
    forest = RandomForestClassifier()
    grid_search = GridSearchCV(estimator = forest, param_grid = param_grid, cv = 3, n_jobs = -1, verbose = 0)
    
    phase = 1

    while start_date < end_date:
        
        #setting the training and testing period in terms of num of days
        train_period = 300
        test_period = 30
        
        '''
        Getting a good number of training and testing data
        Setting min length of training set to be 100
        Setting min length of testing set to be 10
        
        if training set length < min or testing set length < min,
        increase the corresponding training and testing period
        '''
        
        while True:
            train_end = start_date + datetime.timedelta(days = train_period + 1)
            test_start = start_date + datetime.timedelta(days = train_period)
            test_end = test_start + datetime.timedelta(days = test_period)

            #getting data of train & test phase wise
            train_data = project[ (project['gh_build_started_at'] > start_date) & (project['gh_build_started_at'] < train_end)]
            test_data = project[ (project['gh_build_started_at'] > test_start) & (project['gh_build_started_at'] < test_end)]

            #getting 'y' data
            train_result = train_data['tr_status'].tolist()
            test_result = test_data['tr_status'].tolist()
            
            if len(train_result) > 100 and len(test_result) > 10 :
                break
            
            if test_end > end_date:
                if len(test_result) == 0:
                    train_end = end_date - datetime.timedelta(days = test_period)
                    test_start = train_end + datetime.timedelta(days = 1)
                    test_end = end_date
                    
                    train_data = project[ (project['gh_build_started_at'] > start_date) & (project['gh_build_started_at'] < train_end)]
                    test_data = project[ (project['gh_build_started_at'] > test_start) & (project['gh_build_started_at'] < test_end)]
                    
                    train_result = train_data['tr_status'].tolist()
                    test_result = test_data['tr_status'].tolist()
                break
                
            if len(train_result) <= 100:
                train_period += 20
            
            if len(test_result) <= 10:
                test_period += 20
                
        #Now we have gotten atleast minimum number of training and testing data    
        print('The training period = {} to {}'.format(start_date, train_end))
        print('The testing period = {} to {}'.format(test_start, test_end))
        
#         print('Training size = {}'.format(len(train_result)))
#         print('Testing size = {}'.format(len(test_result)))
        
        #dropping build start time column
        train_data.drop('gh_build_started_at', inplace=True, axis=1)
        test_data.drop('gh_build_started_at', inplace=True, axis=1)
        
        #add pass_streak to training data:
        train_data['num_of_passes'] = get_pass_streak(train_result)
        
        best_n_estimators = []
        best_max_depth = []
        
        best_f1 = 0
        best_f1_sample = 0
        best_f1_sample_result = 0
        best_f1_estimator = 0
        best_thresholds = []

        
        #bootstrap 10 times
        for i in range(50):
            print('Bootstrapping {} for {}'.format(i, p_name))
            
            file_name = 'dump_data/rq2_' + p_name + '_' + str(phase) + '_model_' + str(i+1) + '_model.pkl'
            
            #Ensuring we get a non-zero training or testing sample
            while True:
                print('Here for {} {}'.format(i, p_name))
                sample_train = resample(train_data, replace=True, n_samples=len(train_data))
                sample_train_result = sample_train['tr_status']

                build_ids = sample_train['tr_build_id'].tolist()
                sample_test = train_data [~train_data['tr_build_id'].isin(build_ids)] 
                sample_test_result = sample_test['tr_status']
                
                if len(sample_test_result) != 0:
                    break
            
            #dropping result column and build ids column
            sample_train.drop('tr_status', inplace=True, axis=1)
            sample_train.drop('tr_build_id', inplace=True, axis=1)
            sample_test.drop('tr_status', inplace=True, axis=1)
            sample_test.drop('tr_build_id', inplace=True, axis=1)
            
            #training the sample
            print('Training {} for {}'.format(i, p_name))
            grid_search.fit(sample_train, sample_train_result)
            sample_pred_vals = grid_search.predict_proba(sample_test)
            
            pred_vals = sample_pred_vals[:, 1]
            fpr, tpr, t = roc_curve(sample_test_result, pred_vals)
            gmeans = sqrt(tpr * (1-fpr))
            ix = argmax(gmeans)
            bt = t[ix]
            best_thresholds.append(bt)
            
            final_pred_result = []
            #threshold setting
            for j in range(len(pred_vals)):
                if pred_vals[j] > bt:
                    final_pred_result.append(1)
                else:
                    final_pred_result.append(0)
            
            try:
                accuracy = accuracy_score(sample_test_result, final_pred_result)
                precision = precision_score(sample_test_result, final_pred_result)
                recall = recall_score(sample_test_result, final_pred_result)
                confusion = confusion_matrix(sample_test_result, final_pred_result)
                auc_score = roc_auc_score(sample_test_result, final_pred_result)
                f1 = f1_score(sample_test_result, final_pred_result)
            except:
                print('')
    
            if f1 > best_f1:
                best_f1 = f1
                best_f1_sample = sample_train
                best_f1_sample_result = sample_train_result
                best_f1_estimator = grid_search.best_estimator_

#             print(precision, recall, accuracy, f1, auc_score)
            best_n_estimators.append(grid_search.best_params_['n_estimators'])
            best_max_depth.append(grid_search.best_params_['max_depth'])
        
        #completed with bootstrapping 
        threshold = median(best_thresholds)
#         print(threshold)
        n_estimator = median(best_n_estimators)
        max_depth = median(best_max_depth)
        
        #retrain to get the best model
        forest = RandomForestClassifier(n_estimators=int(n_estimator), max_depth=int(max_depth))
        forest.fit(best_f1_sample, best_f1_sample_result)
        
        test_builds = test_data['tr_build_id'].tolist()
        test_data.drop('tr_build_id', inplace=True, axis=1)
        test_data.drop('tr_status', inplace=True, axis=1)
        
        batch = []
        batch_durations = []
        actual_batch_results = []
        max_batch_size = 4
        final_pred_result = []
        pass_streak = 0
        i = 0
        total = len(test_data)
        
        num_of_builds = 0
        
        #The variable 'ci' will hold the actual execution process of the current phase
        #If ci[i] == 0, it means that build was made
        #If ci[i] == 1, it means that build was saved
        ci = []
        
        while i < total :
            data = test_data.iloc[i]
            data['num_of_passes'] = pass_streak
            predict = forest.predict_proba([data])
#             print(predict)
            #predicted that build has passed
            if predict[0][1] > predict[0][0]:
                final_pred_result.append(1)
                ci.append(1)
                pass_streak += 1
                i+=1
            else:
                #We found first failure
                
                #Until an entire batch passes, we are going to continue group builds ie., subsequent failures are grouped
                while True:
                    if (total - i) > 4:
                        ci.extend([0,0,0,0])
                    else:
                        ci.extend([0 for e in range(total-i)])
                    
                    num_of_builds += 1
                    actual_batch_results = test_result[i:i+4]
                    
                    #if any build has failed in the batch, then whole batch will fail
                    if 0 in actual_batch_results:
                        i = i+4
                    else:
                        break
                #Now that we have found a passing build, we can update pass_streak to 1
                pass_streak = 1
                i += 4
                
                
#         print('Individual testing for {}....'.format(p_name))
#         try:
#             accuracy = accuracy_score(test_result, final_pred_result)
#             precision = precision_score(test_result, final_pred_result)
#             recall = recall_score(test_result, final_pred_result)
#             confusion = confusion_matrix(test_result, final_pred_result)
#             auc_score = roc_auc_score(test_result, final_pred_result)
#             f1 = f1_score(test_result, final_pred_result)

# #             print(precision, recall, accuracy, f1, auc_score)
# #             print(confusion)
            
#         except:
#             print('')
#         print(ci)
#         print(test_result)
#         print(len(ci))

        batch_performance = hybrid_performance(p_name, test_builds, test_result, ci)
        performances['time_reqd'].append(batch_performance[0])
        performances['builds_reqd'].append(batch_performance[1])
        performances['total_delay'].append(batch_performance[2])
        performances['failures_found'].append(batch_performance[3])
        performances['failures_not_found'].append(batch_performance[4])
        
        start_date = test_end
        phase += 1
    
    
    print("Average Time Reqd in {} = {}".format(p_name, sum(performances['time_reqd'])/len(performances['time_reqd'])))
    print("Average Builds Reqd in {} = {}".format(p_name, sum(performances['builds_reqd'])/len(performances['builds_reqd'])))
    print("Average Total Delay in {} = {}".format(p_name, sum(performances['total_delay'])/len(performances['total_delay'])))
    print("Average Failed Identified in {} = {}".format(p_name, sum(performances['failures_found'])/len(performances['failures_found'])))
    print("Average Failed Unidentified in {} = {}".format(p_name, sum(performances['failures_not_found'])/len(performances['failures_not_found'])))

    print('\n\n\n\n\n')

# %%
for p_name in project_list:
    bootstrapping(p_name)
# Out:
# Processing geoserver
# The training period = 2013-09-27 16:19:56 to 2014-07-25 16:19:56
# The testing period = 2014-07-24 16:19:56 to 2014-08-23 16:19:56
# Bootstrapping 0 for geoserver
# Here for 0 geoserver
# Training 0 for geoserver
# Bootstrapping 1 for geoserver
# Here for 1 geoserver
# Training 1 for geoserver
# Bootstrapping 2 for geoserver
# Here for 2 geoserver
# Training 2 for geoserver
# Bootstrapping 3 for geoserver
# Here for 3 geoserver
# Training 3 for geoserver
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/connection.py", line 262, in poll
#     return self._poll(timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/connection.py", line 429, in _poll
#     r = wait([self], timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/connection.py", line 936, in wait
#     ready = selector.select(timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
# ...
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_38544/3624040150.py in <module>
#       1 for p_name in project_list:
# ----> 2     bootstrapping(p_name)
#
# /var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_38544/1378984893.py in bootstrapping(p_name)
#     123             #training the sample
#     124             print('Training {} for {}'.format(i, p_name))
# --> 125             grid_search.fit(sample_train, sample_train_result)
#     126             sample_pred_vals = grid_search.predict_proba(sample_test)
#     127
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
jobs = []
for p_name in project_list:
    
    q = multiprocess.Process(target=bootstrapping, args=(p_name,))
    jobs.append(q)
    q.start()

for j in jobs:
    j.join()

# %%
p_name
# Out:
# 'geoserver'

# %%
from multiprocess import Pool

with Pool(9) as pool:
    pool.map(bootstrapping, project_list)
# Out:
# Processing geoserverProcessing gradle
# Processing cloud_controller_ng
# Processing opal
#
# Processing jrubyProcessing cloudifyProcessing chef
# Processing orbeon-forms
#
# Processing vagrant
#
# The training period = 2013-06-12 22:19:49 to 2014-04-09 22:19:49The training period = 2012-09-10 11:25:11 to 2013-07-08 11:25:11The training period = 2013-01-16 20:55:32 to 2013-11-13 20:55:32The training period = 2013-09-27 16:19:56 to 2014-07-25 16:19:56
# The training period = 2014-03-04 01:06:23 to 2014-08-16 22:49:09
#
# The testing period = 2013-07-07 11:25:11 to 2013-08-06 11:25:11The testing period = 2014-04-08 22:19:49 to 2014-05-08 22:19:49
#
# The testing period = 2014-07-24 16:19:56 to 2014-08-23 16:19:56
# The testing period = 2013-11-12 20:55:32 to 2013-12-12 20:55:32
# The training period = 2012-05-31 04:07:59 to 2013-03-28 04:07:59The testing period = 2014-08-17 22:49:09 to 2014-09-15 22:49:09
#
#
#
# Bootstrapping 0 for chefBootstrapping 0 for geoserverBootstrapping 0 for opalThe testing period = 2013-03-27 04:07:59 to 2013-04-26 04:07:59
#
# Bootstrapping 0 for gradleBootstrapping 0 for cloud_controller_ng
# Here for 0 chef
# Here for 0 opalHere for 0 geoserver
#
#
#
# Here for 0 cloud_controller_ng
# Here for 0 gradleBootstrapping 0 for cloudifyThe training period = 2012-02-24 18:32:40 to 2013-03-11 18:32:40
#
#
# Training 0 for chefTraining 0 for geoserverTraining 0 for opalThe training period = 2012-03-12 18:19:48 to 2013-01-07 18:19:48Here for 0 cloudify
#
#
#
# Training 0 for gradleTraining 0 for cloud_controller_ng
#
# Training 0 for cloudify
# The testing period = 2013-01-06 18:19:48 to 2013-02-05 18:19:48
#
# The testing period = 2013-03-10 18:32:40 to 2013-04-29 18:32:40
# Bootstrapping 0 for orbeon-forms
# Here for 0 orbeon-formsBootstrapping 0 for vagrant
#
# Here for 0 vagrantTraining 0 for orbeon-forms
#
# Training 0 for vagrant
#
# The training period = 2012-03-14 02:07:19 to 2013-01-09 02:07:19
# The testing period = 2013-01-08 02:07:19 to 2013-05-18 02:07:19
# Bootstrapping 0 for jruby
# Here for 0 jruby
# Training 0 for jruby
# Bootstrapping 1 for vagrant
# Here for 1 vagrant
# Training 1 for vagrant
# Bootstrapping 1 for chef
# Here for 1 chef
# Training 1 for chef
# Bootstrapping 1 for orbeon-forms
# Here for 1 orbeon-forms
# Training 1 for orbeon-forms
# Bootstrapping 1 for opal
# Here for 1 opal
# Training 1 for opal
# Bootstrapping 1 for geoserver
# Here for 1 geoserver
# Training 1 for geoserver
# Bootstrapping 1 for gradle
# Here for 1 gradle
# Training 1 for gradle
# Bootstrapping 1 for jruby
# Here for 1 jruby
# Training 1 for jruby
# Bootstrapping 1 for cloud_controller_ng
# Here for 1 cloud_controller_ng
# Training 1 for cloud_controller_ng
# Bootstrapping 2 for vagrant
# Here for 2 vagrant
# Training 2 for vagrant
# Bootstrapping 1 for cloudify
# Here for 1 cloudify
# Training 1 for cloudify
# Bootstrapping 2 for chef
# Here for 2 chef
# Training 2 for chef
# Bootstrapping 2 for orbeon-forms
# Here for 2 orbeon-forms
# Training 2 for orbeon-forms
# Bootstrapping 2 for geoserver
# Here for 2 geoserver
# Training 2 for geoserver
# Bootstrapping 2 for opal
# Here for 2 opal
# Training 2 for opal
# Bootstrapping 2 for gradle
# Here for 2 gradle
# Training 2 for gradle
# Bootstrapping 2 for jruby
# Here for 2 jruby
# Training 2 for jruby
# Bootstrapping 2 for cloud_controller_ng
# Here for 2 cloud_controller_ng
# Training 2 for cloud_controller_ng
# Bootstrapping 3 for vagrant
# Here for 3 vagrant
# Training 3 for vagrant
# Bootstrapping 3 for chef
#
# Here for 3 chef
# Training 3 for chefBootstrapping 3 for orbeon-forms
# Here for 3 orbeon-forms
# Training 3 for orbeon-forms
# Bootstrapping 3 for geoserver
# Here for 3 geoserver
# Training 3 for geoserver
# Bootstrapping 3 for opal
# Here for 3 opal
# Training 3 for opal
# Bootstrapping 3 for gradle
# Here for 3 gradle
# Training 3 for gradle
# Bootstrapping 4 for vagrant
# Here for 4 vagrant
# Training 4 for vagrant
# Bootstrapping 3 for jruby
# Here for 3 jruby
# Training 3 for jruby
# Bootstrapping 2 for cloudify
# Here for 2 cloudify
# Training 2 for cloudify
# Bootstrapping 4 for chef
# Here for 4 chef
# Training 4 for chef
# Bootstrapping 3 for cloud_controller_ng
# Here for 3 cloud_controller_ng
# Training 3 for cloud_controller_ng
# Bootstrapping 4 for orbeon-forms
# Here for 4 orbeon-forms
# Training 4 for orbeon-forms
# Bootstrapping 5 for vagrant
# Here for 5 vagrant
# Training 5 for vagrant
# Bootstrapping 4 for geoserver
# Here for 4 geoserver
# Training 4 for geoserver
# Bootstrapping 4 for opalHere for 4 opal
#
# Training 4 for opal
# Bootstrapping 4 for gradle
# Here for 4 gradle
# Training 4 for gradle
# Bootstrapping 5 for chef
# Here for 5 chef
# Training 5 for chef
# Bootstrapping 4 for jruby
# Here for 4 jruby
# Training 4 for jruby
# Bootstrapping 4 for cloud_controller_ng
# Here for 4 cloud_controller_ng
# Training 4 for cloud_controller_ng
# Bootstrapping 6 for vagrant
# Here for 6 vagrant
# Training 6 for vagrant
# Bootstrapping 5 for orbeon-forms
# Here for 5 orbeon-forms
# Training 5 for orbeon-forms
# Bootstrapping 5 for geoserver
# Here for 5 geoserver
# Training 5 for geoserver
# Bootstrapping 5 for opal
# Here for 5 opal
# Training 5 for opal
# Bootstrapping 3 for cloudify
# Here for 3 cloudify
# Training 3 for cloudify
# Bootstrapping 6 for chef
# Here for 6 chef
# Training 6 for chef
# Bootstrapping 5 for gradleHere for 5 gradle
#
# Training 5 for gradle
# Bootstrapping 5 for jruby
# Here for 5 jruby
# Training 5 for jruby
# Bootstrapping 7 for vagrant
# Here for 7 vagrant
# Training 7 for vagrant
# Bootstrapping 5 for cloud_controller_ng
# Here for 5 cloud_controller_ng
# Training 5 for cloud_controller_ng
# Bootstrapping 6 for orbeon-forms
# Here for 6 orbeon-forms
# Training 6 for orbeon-forms
# Bootstrapping 7 for chef
# Here for 7 chef
# Training 7 for chef
# Bootstrapping 6 for geoserver
# Here for 6 geoserver
# Training 6 for geoserver
# Bootstrapping 6 for opal
# Here for 6 opal
# Training 6 for opal
# Bootstrapping 6 for gradle
# Here for 6 gradle
# Training 6 for gradle
#
# Bootstrapping 8 for vagrant
# Here for 8 vagrant
# Training 8 for vagrant
# Bootstrapping 6 for jruby
# Here for 6 jruby
# Training 6 for jruby
# Bootstrapping 7 for orbeon-forms
# Here for 7 orbeon-forms
# Training 7 for orbeon-forms
# Bootstrapping 4 for cloudify
# Here for 4 cloudify
# Training 4 for cloudify
# Bootstrapping 8 for chef
# Here for 8 chef
# Training 8 for chef
# Bootstrapping 6 for cloud_controller_ng
# Here for 6 cloud_controller_ng
# Training 6 for cloud_controller_ng
# Bootstrapping 7 for geoserver
# Here for 7 geoserver
# Training 7 for geoserver
# Bootstrapping 7 for opal
# Here for 7 opal
# Training 7 for opal
# Bootstrapping 9 for vagrant
# Here for 9 vagrant
# Training 9 for vagrant
# Bootstrapping 7 for gradle
# Here for 7 gradle
# Training 7 for gradle
# Bootstrapping 8 for orbeon-forms
# Here for 8 orbeon-forms
# Training 8 for orbeon-forms
# Bootstrapping 7 for jruby
# Here for 7 jruby
# Training 7 for jruby
# Bootstrapping 9 for chef
# Here for 9 chef
# Training 9 for chef
# Bootstrapping 10 for vagrant
# Here for 10 vagrant
# Training 10 for vagrant
# Bootstrapping 8 for geoserver
# Here for 8 geoserver
# Training 8 for geoserver
# Bootstrapping 7 for cloud_controller_ng
# Here for 7 cloud_controller_ng
# Training 7 for cloud_controller_ng
# Bootstrapping 8 for opal
# Here for 8 opal
# Training 8 for opal
# Bootstrapping 8 for gradle
# Here for 8 gradle
# Training 8 for gradle
# Bootstrapping 5 for cloudify
# Here for 5 cloudify
# Training 5 for cloudify
# Bootstrapping 10 for chef
# Here for 10 chef
# Training 10 for chef
# Bootstrapping 9 for orbeon-forms
# Here for 9 orbeon-forms
# Training 9 for orbeon-forms
# Bootstrapping 11 for vagrant
# Here for 11 vagrant
# Training 11 for vagrant
# Bootstrapping 8 for jruby
# Here for 8 jruby
# Training 8 for jruby
# Bootstrapping 9 for geoserver
# Here for 9 geoserver
# Training 9 for geoserver
# Bootstrapping 9 for opal
# Here for 9 opal
# Training 9 for opal
# Bootstrapping 8 for cloud_controller_ng
# Here for 8 cloud_controller_ng
# Training 8 for cloud_controller_ng
# Bootstrapping 11 for chef
# Here for 11 chef
# Training 11 for chef
# Bootstrapping 9 for gradle
# Here for 9 gradle
# Training 9 for gradle
#
# Bootstrapping 12 for vagrant
# Here for 12 vagrant
# Training 12 for vagrant
# Bootstrapping 10 for orbeon-forms
# Here for 10 orbeon-forms
# Training 10 for orbeon-forms
# Bootstrapping 9 for jruby
# Here for 9 jruby
# Training 9 for jruby
# Bootstrapping 10 for geoserver
# Here for 10 geoserver
# Training 10 for geoserver
# Bootstrapping 6 for cloudify
# Here for 6 cloudify
# Training 6 for cloudify
# Bootstrapping 10 for opal
# Here for 10 opal
# Training 10 for opal
# Bootstrapping 12 for chef
# Here for 12 chef
# Training 12 for chef
# Bootstrapping 13 for vagrant
# Here for 13 vagrant
# Training 13 for vagrant
# Bootstrapping 9 for cloud_controller_ng
# Here for 9 cloud_controller_ng
# Training 9 for cloud_controller_ng
# Bootstrapping 10 for gradle
# Here for 10 gradle
# Training 10 for gradle
# Bootstrapping 11 for orbeon-forms
# Here for 11 orbeon-forms
# Training 11 for orbeon-forms
# Bootstrapping 10 for jruby
# Here for 10 jruby
# Training 10 for jruby
# Bootstrapping 11 for geoserver
# Here for 11 geoserver
# Training 11 for geoserver
# Bootstrapping 13 for chef
# Here for 13 chef
# Training 13 for chef
# Bootstrapping 11 for opal
# Here for 11 opal
# Training 11 for opal
# Bootstrapping 14 for vagrant
# Here for 14 vagrant
# Training 14 for vagrant
# Bootstrapping 10 for cloud_controller_ng
# Here for 10 cloud_controller_ng
# Training 10 for cloud_controller_ng
# Bootstrapping 11 for gradle
# Here for 11 gradle
# Training 11 for gradle
# Bootstrapping 12 for orbeon-forms
# Here for 12 orbeon-forms
# Training 12 for orbeon-forms
# Bootstrapping 7 for cloudify
# Here for 7 cloudify
# Training 7 for cloudify
# Bootstrapping 15 for vagrant
# Here for 15 vagrant
# Training 15 for vagrant
# Bootstrapping 14 for chef
# Here for 14 chef
# Training 14 for chef
# Bootstrapping 12 for geoserver
# Here for 12 geoserver
# Training 12 for geoserver
# Bootstrapping 11 for jruby
# Here for 11 jruby
# Training 11 for jruby
# Bootstrapping 12 for opal
# Here for 12 opal
# Training 12 for opal
# Bootstrapping 13 for orbeon-forms
# Here for 13 orbeon-forms
# Training 13 for orbeon-forms
# Bootstrapping 12 for gradle
# Here for 12 gradle
# Training 12 for gradle
# Bootstrapping 11 for cloud_controller_ng
# Here for 11 cloud_controller_ng
# Training 11 for cloud_controller_ng
# Bootstrapping 16 for vagrant
# Here for 16 vagrant
# Training 16 for vagrant
# Bootstrapping 15 for chef
# Here for 15 chef
# Training 15 for chef
# Bootstrapping 13 for geoserver
# Here for 13 geoserver
# Training 13 for geoserver
# Bootstrapping 13 for opal
# Here for 13 opal
# Training 13 for opal
# Bootstrapping 12 for jruby
# Here for 12 jruby
# Training 12 for jruby
# Bootstrapping 14 for orbeon-forms
# Here for 14 orbeon-forms
# Training 14 for orbeon-forms
# Bootstrapping 17 for vagrant
# Here for 17 vagrant
# Training 17 for vagrant
# Bootstrapping 13 for gradle
# Here for 13 gradle
# Training 13 for gradle
# Bootstrapping 8 for cloudify
# Here for 8 cloudify
# Training 8 for cloudify
# Bootstrapping 12 for cloud_controller_ng
# Here for 12 cloud_controller_ng
# Training 12 for cloud_controller_ng
# Bootstrapping 16 for chef
# Here for 16 chef
# Training 16 for chef
# Bootstrapping 14 for geoserver
# Here for 14 geoserver
# Training 14 for geoserver
# Bootstrapping 14 for opal
# Here for 14 opal
# Training 14 for opal
# Bootstrapping 13 for jruby
# Here for 13 jruby
# Training 13 for jruby
# Bootstrapping 18 for vagrant
# Here for 18 vagrant
# Training 18 for vagrant
# Bootstrapping 15 for orbeon-forms
# Here for 15 orbeon-forms
# Training 15 for orbeon-forms
# Bootstrapping 17 for chef
# Here for 17 chef
# Training 17 for chef
# Bootstrapping 14 for gradle
# Here for 14 gradle
# Training 14 for gradle
# Bootstrapping 13 for cloud_controller_ng
# Here for 13 cloud_controller_ng
# Training 13 for cloud_controller_ng
# Bootstrapping 15 for geoserver
# Here for 15 geoserver
# Training 15 for geoserver
# Bootstrapping 19 for vagrant
# Here for 19 vagrant
# Training 19 for vagrant
# Bootstrapping 15 for opal
# Here for 15 opal
# Training 15 for opal
# Bootstrapping 14 for jruby
# Here for 14 jruby
# Training 14 for jruby
# Bootstrapping 9 for cloudify
# Here for 9 cloudify
# Training 9 for cloudify
# Bootstrapping 16 for orbeon-forms
# Here for 16 orbeon-forms
# Training 16 for orbeon-forms
# Bootstrapping 18 for chef
# Here for 18 chef
# Training 18 for chef
# Bootstrapping 15 for gradle
# Here for 15 gradle
# Training 15 for gradle
# Bootstrapping 14 for cloud_controller_ng
# Here for 14 cloud_controller_ng
# Training 14 for cloud_controller_ng
# Bootstrapping 20 for vagrant
# Here for 20 vagrant
# Training 20 for vagrant
# Bootstrapping 16 for geoserver
# Here for 16 geoserver
# Training 16 for geoserver
# Bootstrapping 16 for opal
# Here for 16 opal
# Training 16 for opal
# Bootstrapping 19 for chef
# Here for 19 chef
# Training 19 for chef
# Bootstrapping 17 for orbeon-forms
# Here for 17 orbeon-forms
# Training 17 for orbeon-forms
# Bootstrapping 15 for jruby
# Here for 15 jruby
# Training 15 for jruby
#
# Bootstrapping 21 for vagrant
# Here for 21 vagrant
# Training 21 for vagrant
# Bootstrapping 16 for gradle
# Here for 16 gradle
# Training 16 for gradle
# Bootstrapping 15 for cloud_controller_ng
# Here for 15 cloud_controller_ng
# Training 15 for cloud_controller_ng
# Bootstrapping 10 for cloudify
# Here for 10 cloudify
# Training 10 for cloudify
# Bootstrapping 17 for geoserver
# Here for 17 geoserver
# Training 17 for geoserver
# Bootstrapping 17 for opal
# Here for 17 opal
# Training 17 for opal
# Bootstrapping 20 for chef
# Here for 20 chef
# Training 20 for chef
# Bootstrapping 18 for orbeon-forms
# Here for 18 orbeon-forms
# Training 18 for orbeon-forms
# Bootstrapping 16 for jruby
# Here for 16 jruby
# Training 16 for jruby
# Bootstrapping 17 for gradle
# Here for 17 gradle
# Training 17 for gradle
# Bootstrapping 21 for chef
# Here for 21 chef
# Training 21 for chef
# Bootstrapping 18 for opal
# Here for 18 opal
# Training 18 for opal
# Bootstrapping 18 for geoserver
# Here for 18 geoserver
# Training 18 for geoserver
# Bootstrapping 16 for cloud_controller_ng
# Here for 16 cloud_controller_ng
# Training 16 for cloud_controller_ng
# Bootstrapping 19 for orbeon-forms
# Here for 19 orbeon-forms
# Training 19 for orbeon-forms
# Bootstrapping 17 for jruby
# Here for 17 jruby
# Training 17 for jruby
# Bootstrapping 11 for cloudify
# Here for 11 cloudify
# Training 11 for cloudify
# Bootstrapping 22 for chef
# Here for 22 chef
# Training 22 for chef
# Bootstrapping 18 for gradle
# Here for 18 gradle
# Training 18 for gradle
# Bootstrapping 19 for opal
# Here for 19 opal
# Training 19 for opal
# Bootstrapping 19 for geoserver
# Here for 19 geoserver
# Training 19 for geoserver
# Bootstrapping 20 for orbeon-forms
# Here for 20 orbeon-forms
# Training 20 for orbeon-forms
# Bootstrapping 17 for cloud_controller_ng
# Here for 17 cloud_controller_ng
# Training 17 for cloud_controller_ng
# Bootstrapping 23 for chef
# Here for 23 chef
# Training 23 for chef
# Bootstrapping 18 for jruby
# Here for 18 jruby
# Training 18 for jruby
# Bootstrapping 19 for gradle
# Here for 19 gradle
# Training 19 for gradle
# Bootstrapping 20 for opal
# Here for 20 opal
# Training 20 for opal
# Bootstrapping 20 for geoserver
# Here for 20 geoserver
# Training 20 for geoserver
# Bootstrapping 21 for orbeon-forms
# Here for 21 orbeon-forms
# Training 21 for orbeon-forms
# Bootstrapping 18 for cloud_controller_ng
# Here for 18 cloud_controller_ng
# Training 18 for cloud_controller_ng
# Bootstrapping 12 for cloudify
# Here for 12 cloudify
# Training 12 for cloudify
# Bootstrapping 24 for chef
# Here for 24 chef
# Training 24 for chef
# Bootstrapping 19 for jruby
# Here for 19 jruby
# Training 19 for jruby
# Bootstrapping 20 for gradle
# Here for 20 gradle
# Training 20 for gradle
# Bootstrapping 21 for opal
# Here for 21 opal
# Training 21 for opal
# Bootstrapping 21 for geoserver
# Here for 21 geoserver
# Training 21 for geoserver
# Bootstrapping 22 for orbeon-forms
# Here for 22 orbeon-forms
# Training 22 for orbeon-forms
# Bootstrapping 25 for chef
# Here for 25 chef
# Training 25 for chef
# Bootstrapping 19 for cloud_controller_ng
# Here for 19 cloud_controller_ng
# Training 19 for cloud_controller_ng
# Bootstrapping 20 for jruby
# Here for 20 jruby
# Training 20 for jruby
# Bootstrapping 21 for gradle
# Here for 21 gradle
# Training 21 for gradle
# Bootstrapping 22 for opal
# Here for 22 opal
# Training 22 for opal
# Bootstrapping 13 for cloudify
# Here for 13 cloudify
# Training 13 for cloudify
# Bootstrapping 23 for orbeon-forms
# Here for 23 orbeon-forms
# Training 23 for orbeon-forms
# Bootstrapping 22 for geoserver
# Here for 22 geoserver
# Training 22 for geoserver
# Bootstrapping 26 for chef
# Here for 26 chef
# Training 26 for chef
# Bootstrapping 20 for cloud_controller_ng
# Here for 20 cloud_controller_ng
# Training 20 for cloud_controller_ng
# Bootstrapping 23 for opal
# Here for 23 opal
# Training 23 for opal
# Bootstrapping 22 for gradle
# Here for 22 gradle
# Training 22 for gradle
# Bootstrapping 27 for chef
# Here for 27 chef
# Training 27 for chef
# Bootstrapping 21 for jruby
# Here for 21 jruby
# Training 21 for jruby
# Bootstrapping 24 for orbeon-forms
# Here for 24 orbeon-forms
# Training 24 for orbeon-forms
# Bootstrapping 23 for geoserver
# Here for 23 geoserver
# Training 23 for geoserver
# Bootstrapping 21 for cloud_controller_ng
# Here for 21 cloud_controller_ng
# Training 21 for cloud_controller_ng
# Bootstrapping 14 for cloudify
# Here for 14 cloudify
# Training 14 for cloudify
# Bootstrapping 28 for chef
# Here for 28 chef
# Training 28 for chef
# Bootstrapping 25 for orbeon-forms
# Here for 25 orbeon-forms
# Training 25 for orbeon-forms
# Bootstrapping 24 for opal
# Here for 24 opal
# Training 24 for opal
# Bootstrapping 23 for gradle
# Here for 23 gradle
# Training 23 for gradle
# Bootstrapping 24 for geoserver
# Here for 24 geoserver
# Training 24 for geoserver
# Bootstrapping 22 for jruby
# Here for 22 jruby
# Training 22 for jruby
# Bootstrapping 29 for chef
# Here for 29 chef
# Training 29 for chef
# Bootstrapping 22 for cloud_controller_ng
# Here for 22 cloud_controller_ng
# Training 22 for cloud_controller_ng
# Bootstrapping 26 for orbeon-forms
# Here for 26 orbeon-forms
# Training 26 for orbeon-forms
# Bootstrapping 25 for opal
# Here for 25 opal
# Training 25 for opal
# Bootstrapping 24 for gradle
# Here for 24 gradle
# Training 24 for gradle
# Bootstrapping 25 for geoserver
# Here for 25 geoserver
# Training 25 for geoserver
# Bootstrapping 23 for jruby
# Here for 23 jruby
# Training 23 for jruby
# Bootstrapping 15 for cloudify
# Here for 15 cloudify
# Training 15 for cloudify
# Bootstrapping 30 for chef
# Here for 30 chef
# Training 30 for chef
# Bootstrapping 27 for orbeon-forms
# Here for 27 orbeon-forms
# Training 27 for orbeon-forms
# Bootstrapping 23 for cloud_controller_ng
# Here for 23 cloud_controller_ng
# Training 23 for cloud_controller_ng
# Bootstrapping 26 for opal
# Here for 26 opal
# Training 26 for opal
# Bootstrapping 25 for gradle
# Here for 25 gradle
# Training 25 for gradle
# Bootstrapping 26 for geoserver
# Here for 26 geoserver
# Training 26 for geoserver
# Bootstrapping 24 for jruby
# Here for 24 jruby
# Training 24 for jruby
# Bootstrapping 31 for chef
# Here for 31 chef
# Training 31 for chef
# Bootstrapping 28 for orbeon-forms
# Here for 28 orbeon-forms
# Training 28 for orbeon-forms
# Bootstrapping 27 for opal
# Here for 27 opal
# Training 27 for opal
# Bootstrapping 24 for cloud_controller_ng
# Here for 24 cloud_controller_ng
# Training 24 for cloud_controller_ng
# Bootstrapping 26 for gradle
# Here for 26 gradle
# Training 26 for gradle
# Bootstrapping 16 for cloudify
# Here for 16 cloudify
# Training 16 for cloudify
# Bootstrapping 27 for geoserver
# Here for 27 geoserver
# Training 27 for geoserver
# Bootstrapping 32 for chef
# Here for 32 chef
# Training 32 for chef
# Bootstrapping 25 for jruby
# Here for 25 jruby
# Training 25 for jruby
# Bootstrapping 29 for orbeon-forms
# Here for 29 orbeon-forms
# Training 29 for orbeon-forms
# Bootstrapping 28 for opal
# Here for 28 opal
# Training 28 for opal
# Bootstrapping 27 for gradle
# Here for 27 gradle
# Training 27 for gradle
# Bootstrapping 33 for chef
# Here for 33 chef
# Training 33 for chef
# Bootstrapping 25 for cloud_controller_ng
# Here for 25 cloud_controller_ng
# Training 25 for cloud_controller_ng
# Bootstrapping 28 for geoserver
# Here for 28 geoserver
# Training 28 for geoserver
# Bootstrapping 26 for jruby
# Here for 26 jruby
# Training 26 for jruby
# Bootstrapping 30 for orbeon-forms
# Here for 30 orbeon-forms
# Training 30 for orbeon-forms
# Bootstrapping 17 for cloudify
# Here for 17 cloudify
# Training 17 for cloudify
# Bootstrapping 34 for chef
# Here for 34 chef
# Training 34 for chef
# Bootstrapping 29 for opal
# Here for 29 opal
# Training 29 for opal
# Bootstrapping 28 for gradle
# Here for 28 gradle
# Training 28 for gradle
# Bootstrapping 26 for cloud_controller_ng
# Here for 26 cloud_controller_ng
# Training 26 for cloud_controller_ng
# Bootstrapping 29 for geoserver
# Here for 29 geoserver
# Training 29 for geoserver
# Bootstrapping 27 for jruby
# Here for 27 jruby
# Training 27 for jruby
# Bootstrapping 31 for orbeon-forms
# Here for 31 orbeon-forms
# Training 31 for orbeon-forms
# Bootstrapping 35 for chef
# Here for 35 chef
# Training 35 for chef
# Bootstrapping 30 for opal
# Here for 30 opal
# Training 30 for opal
# Bootstrapping 29 for gradle
# Here for 29 gradle
# Training 29 for gradle
# Bootstrapping 30 for geoserver
# Here for 30 geoserver
# Training 30 for geoserver
# Bootstrapping 27 for cloud_controller_ng
# Here for 27 cloud_controller_ng
# Training 27 for cloud_controller_ng
# Bootstrapping 18 for cloudify
# Here for 18 cloudify
# Training 18 for cloudify
# Bootstrapping 32 for orbeon-forms
# Here for 32 orbeon-forms
# Training 32 for orbeon-forms
# Bootstrapping 28 for jruby
# Here for 28 jruby
# Training 28 for jruby
# Bootstrapping 36 for chef
# Here for 36 chef
# Training 36 for chef
# Bootstrapping 31 for opal
# Here for 31 opal
# Training 31 for opal
# Bootstrapping 31 for geoserver
# Here for 31 geoserver
# Training 31 for geoserver
# Bootstrapping 30 for gradle
# Here for 30 gradle
# Training 30 for gradle
# Bootstrapping 28 for cloud_controller_ng
# Here for 28 cloud_controller_ng
# Training 28 for cloud_controller_ng
# Bootstrapping 37 for chef
# Here for 37 chef
# Training 37 for chef
# Bootstrapping 33 for orbeon-forms
# Here for 33 orbeon-forms
# Training 33 for orbeon-forms
# Bootstrapping 29 for jruby
# Here for 29 jruby
# Training 29 for jruby
# Bootstrapping 32 for opal
# Here for 32 opal
# Training 32 for opal
# Bootstrapping 19 for cloudify
# Here for 19 cloudify
# Training 19 for cloudify
# Bootstrapping 32 for geoserver
# Here for 32 geoserver
# Training 32 for geoserver
# Bootstrapping 31 for gradle
# Here for 31 gradle
# Training 31 for gradle
# Bootstrapping 38 for chef
# Here for 38 chef
# Training 38 for chef
# Bootstrapping 34 for orbeon-forms
# Here for 34 orbeon-forms
# Training 34 for orbeon-forms
# Bootstrapping 29 for cloud_controller_ng
# Here for 29 cloud_controller_ng
# Training 29 for cloud_controller_ng
# Bootstrapping 30 for jruby
# Here for 30 jruby
# Training 30 for jruby
# Bootstrapping 33 for opal
# Here for 33 opal
# Training 33 for opal
# Bootstrapping 39 for chef
# Here for 39 chef
# Training 39 for chef
# Bootstrapping 33 for geoserver
# Here for 33 geoserver
# Training 33 for geoserver
# Bootstrapping 32 for gradle
# Here for 32 gradle
# Training 32 for gradle
# Bootstrapping 35 for orbeon-forms
# Here for 35 orbeon-forms
# Training 35 for orbeon-forms
# Bootstrapping 30 for cloud_controller_ng
# Here for 30 cloud_controller_ng
# Training 30 for cloud_controller_ng
# Bootstrapping 20 for cloudify
# Here for 20 cloudify
# Training 20 for cloudify
# Bootstrapping 31 for jruby
# Here for 31 jruby
# Training 31 for jruby
# Bootstrapping 34 for opal
# Here for 34 opal
# Training 34 for opal
# Bootstrapping 40 for chef
# Here for 40 chef
# Training 40 for chef
# Bootstrapping 34 for geoserver
# Here for 34 geoserver
# Training 34 for geoserver
# Bootstrapping 33 for gradle
# Here for 33 gradle
# Training 33 for gradle
# Bootstrapping 36 for orbeon-forms
# Here for 36 orbeon-forms
# Training 36 for orbeon-forms
# Bootstrapping 31 for cloud_controller_ng
# Here for 31 cloud_controller_ng
# Training 31 for cloud_controller_ng
# Bootstrapping 41 for chef
# Here for 41 chef
# Training 41 for chef
# Bootstrapping 32 for jruby
# Here for 32 jruby
# Training 32 for jruby
# Bootstrapping 35 for opal
# Here for 35 opal
# Training 35 for opal
# Bootstrapping 35 for geoserver
# Here for 35 geoserver
# Training 35 for geoserver
# Bootstrapping 37 for orbeon-forms
# Here for 37 orbeon-forms
# Training 37 for orbeon-forms
# Bootstrapping 21 for cloudify
# Here for 21 cloudify
# Training 21 for cloudify
# Bootstrapping 34 for gradle
# Here for 34 gradle
# Training 34 for gradle
# Bootstrapping 42 for chef
# Here for 42 chef
# Training 42 for chef
# Bootstrapping 32 for cloud_controller_ng
# Here for 32 cloud_controller_ng
# Training 32 for cloud_controller_ng
# Bootstrapping 36 for opal
# Here for 36 opal
# Training 36 for opal
# Bootstrapping 33 for jruby
# Here for 33 jruby
# Training 33 for jruby
# Bootstrapping 36 for geoserver
# Here for 36 geoserver
# Training 36 for geoserver
# Bootstrapping 38 for orbeon-forms
# Here for 38 orbeon-forms
# Training 38 for orbeon-forms
# Bootstrapping 35 for gradle
# Here for 35 gradle
# Training 35 for gradle
# Bootstrapping 43 for chef
# Here for 43 chef
# Training 43 for chef
# Bootstrapping 37 for opal
# Here for 37 opal
# Training 37 for opal
# Bootstrapping 33 for cloud_controller_ng
# Here for 33 cloud_controller_ng
# Training 33 for cloud_controller_ng
# Bootstrapping 22 for cloudify
# Here for 22 cloudify
# Training 22 for cloudify
# Bootstrapping 34 for jruby
# Here for 34 jruby
# Training 34 for jruby
# Bootstrapping 37 for geoserver
# Here for 37 geoserver
# Training 37 for geoserver
# Bootstrapping 39 for orbeon-forms
# Here for 39 orbeon-forms
# Training 39 for orbeon-forms
# Bootstrapping 44 for chef
# Here for 44 chef
# Training 44 for chef
# Bootstrapping 36 for gradle
# Here for 36 gradle
# Training 36 for gradle
# Bootstrapping 38 for opal
# Here for 38 opal
# Training 38 for opal
# Bootstrapping 38 for geoserver
# Here for 38 geoserver
# Training 38 for geoserver
# Bootstrapping 34 for cloud_controller_ng
# Here for 34 cloud_controller_ng
# Training 34 for cloud_controller_ng
# Bootstrapping 35 for jruby
# Here for 35 jruby
# Training 35 for jruby
# Bootstrapping 45 for chef
# Here for 45 chef
# Training 45 for chef
# Bootstrapping 40 for orbeon-forms
# Here for 40 orbeon-forms
# Training 40 for orbeon-forms
# Bootstrapping 37 for gradle
# Here for 37 gradle
# Training 37 for gradle
# Bootstrapping 23 for cloudify
# Here for 23 cloudify
# Training 23 for cloudify
# Bootstrapping 39 for opalHere for 39 opal
#
# Training 39 for opal
# Bootstrapping 39 for geoserver
# Here for 39 geoserver
# Training 39 for geoserver
# Bootstrapping 46 for chef
# Here for 46 chef
# Training 46 for chef
# Bootstrapping 35 for cloud_controller_ng
# Here for 35 cloud_controller_ng
# Training 35 for cloud_controller_ng
# Bootstrapping 36 for jruby
# Here for 36 jruby
# Training 36 for jruby
# Bootstrapping 41 for orbeon-forms
# Here for 41 orbeon-forms
# Training 41 for orbeon-forms
# Bootstrapping 38 for gradle
# Here for 38 gradle
# Training 38 for gradle
# Bootstrapping 47 for chef
# Here for 47 chef
# Training 47 for chef
# Bootstrapping 40 for opal
# Here for 40 opal
# Training 40 for opal
# Bootstrapping 40 for geoserver
# Here for 40 geoserver
# Training 40 for geoserver
# Bootstrapping 42 for orbeon-forms
# Here for 42 orbeon-forms
# Training 42 for orbeon-forms
# Bootstrapping 37 for jruby
# Here for 37 jruby
# Training 37 for jruby
# Bootstrapping 36 for cloud_controller_ng
# Here for 36 cloud_controller_ng
# Training 36 for cloud_controller_ng
# Bootstrapping 24 for cloudify
# Here for 24 cloudify
# Training 24 for cloudify
# Bootstrapping 39 for gradle
# Here for 39 gradle
# Training 39 for gradle
# Bootstrapping 48 for chefHere for 48 chef
#
# Training 48 for chef
# Bootstrapping 41 for opal
# Here for 41 opal
# Training 41 for opal
# Bootstrapping 41 for geoserver
# Here for 41 geoserver
# Training 41 for geoserver
# Bootstrapping 43 for orbeon-forms
# Here for 43 orbeon-forms
# Training 43 for orbeon-forms
# Bootstrapping 38 for jruby
# Here for 38 jruby
# Training 38 for jruby
# Bootstrapping 37 for cloud_controller_ng
# Here for 37 cloud_controller_ng
# Training 37 for cloud_controller_ng
# Bootstrapping 49 for chef
# Here for 49 chef
# Training 49 for chef
# Bootstrapping 40 for gradle
# Here for 40 gradle
# Training 40 for gradle
# Bootstrapping 42 for opal
# Here for 42 opal
# Training 42 for opal
# Bootstrapping 44 for orbeon-forms
# Here for 44 orbeon-forms
# Training 44 for orbeon-forms
# Bootstrapping 25 for cloudify
# Here for 25 cloudify
# Training 25 for cloudify
# Bootstrapping 42 for geoserver
# Here for 42 geoserver
# Training 42 for geoserver
# Bootstrapping 39 for jruby
# Here for 39 jruby
# Training 39 for jruby
# Going right....
# The training period = 2014-05-08 22:19:49 to 2015-03-05 22:19:49
# The testing period = 2015-03-04 22:19:49 to 2015-04-03 22:19:49
# Bootstrapping 0 for chef
# Here for 0 chef
# Training 0 for chef
# Bootstrapping 38 for cloud_controller_ng
# Here for 38 cloud_controller_ng
# Training 38 for cloud_controller_ng
# Bootstrapping 41 for gradle
#
# Here for 41 gradleTraining 41 for gradle
# Bootstrapping 43 for opal
# Here for 43 opal
# Training 43 for opal
# Bootstrapping 45 for orbeon-forms
# Here for 45 orbeon-forms
# Training 45 for orbeon-forms
# Bootstrapping 43 for geoserver
# Here for 43 geoserver
# Training 43 for geoserver
# Bootstrapping 40 for jruby
# Here for 40 jruby
# Training 40 for jruby
# Bootstrapping 1 for chef
# Here for 1 chef
# Training 1 for chef
# Bootstrapping 39 for cloud_controller_ng
# Here for 39 cloud_controller_ng
# Training 39 for cloud_controller_ng
# Bootstrapping 26 for cloudify
# Here for 26 cloudify
# Training 26 for cloudify
# Bootstrapping 42 for gradle
# Here for 42 gradle
# Training 42 for gradle
# Bootstrapping 44 for opal
# Here for 44 opal
# Training 44 for opal
# Bootstrapping 46 for orbeon-forms
# Here for 46 orbeon-forms
# Training 46 for orbeon-forms
# Bootstrapping 44 for geoserver
# Here for 44 geoserver
# Training 44 for geoserver
# Bootstrapping 41 for jruby
# Here for 41 jruby
# Training 41 for jruby
# Bootstrapping 2 for chef
# Here for 2 chef
# Training 2 for chef
# Bootstrapping 40 for cloud_controller_ng
# Here for 40 cloud_controller_ng
# Training 40 for cloud_controller_ng
# Bootstrapping 43 for gradle
# Here for 43 gradle
# Training 43 for gradle
# Bootstrapping 45 for opal
# Here for 45 opal
# Training 45 for opal
# Bootstrapping 47 for orbeon-forms
# Here for 47 orbeon-forms
# Training 47 for orbeon-forms
# Bootstrapping 45 for geoserver
# Here for 45 geoserver
# Training 45 for geoserver
# Bootstrapping 27 for cloudify
# Here for 27 cloudify
# Training 27 for cloudify
# Bootstrapping 3 for chef
# Here for 3 chef
# Training 3 for chef
# Bootstrapping 42 for jruby
# Here for 42 jruby
# Training 42 for jruby
# Bootstrapping 41 for cloud_controller_ngHere for 41 cloud_controller_ng
#
# Training 41 for cloud_controller_ng
# Bootstrapping 48 for orbeon-forms
# Here for 48 orbeon-forms
# Training 48 for orbeon-forms
# Bootstrapping 44 for gradle
# Here for 44 gradle
# Training 44 for gradle
# Bootstrapping 46 for opal
# Here for 46 opal
# Training 46 for opal
# Bootstrapping 46 for geoserver
# Here for 46 geoserver
# Training 46 for geoserver
# Bootstrapping 4 for chef
# Here for 4 chef
# Training 4 for chef
# Bootstrapping 43 for jruby
# Here for 43 jruby
# Training 43 for jruby
# Bootstrapping 49 for orbeon-forms
# Here for 49 orbeon-forms
# Training 49 for orbeon-forms
# Bootstrapping 47 for opal
# Here for 47 opal
# Training 47 for opal
# Bootstrapping 42 for cloud_controller_ng
# Here for 42 cloud_controller_ng
# Training 42 for cloud_controller_ng
# Bootstrapping 45 for gradle
# Here for 45 gradle
# Training 45 for gradle
# Bootstrapping 47 for geoserver
# Here for 47 geoserver
# Training 47 for geoserver
# Bootstrapping 28 for cloudify
# Here for 28 cloudify
# Training 28 for cloudify
# Bootstrapping 5 for chef
# Here for 5 chef
# Training 5 for chef
# Going right....
# The training period = 2013-02-05 18:19:48 to 2013-12-03 18:19:48
# The testing period = 2013-12-02 18:19:48 to 2014-01-01 18:19:48
# Bootstrapping 0 for orbeon-forms
# Here for 0 orbeon-forms
# Training 0 for orbeon-forms
# Bootstrapping 44 for jruby
# Here for 44 jruby
# Training 44 for jruby
# Bootstrapping 48 for opal
# Here for 48 opal
# Training 48 for opal
# Bootstrapping 46 for gradle
# Here for 46 gradle
# Training 46 for gradle
# Bootstrapping 43 for cloud_controller_ng
# Here for 43 cloud_controller_ng
# Training 43 for cloud_controller_ng
# Bootstrapping 48 for geoserver
# Here for 48 geoserver
# Training 48 for geoserver
# Bootstrapping 1 for orbeon-forms
# Here for 1 orbeon-forms
# Training 1 for orbeon-forms
# Bootstrapping 29 for cloudify
# Here for 29 cloudify
# Training 29 for cloudify
# Bootstrapping 6 for chef
# Here for 6 chef
# Training 6 for chef
# Bootstrapping 49 for opal
# Here for 49 opal
# Training 49 for opal
# Bootstrapping 47 for gradle
# Here for 47 gradle
# Training 47 for gradle
# Bootstrapping 45 for jruby
# Here for 45 jruby
# Training 45 for jruby
# Bootstrapping 49 for geoserver
# Here for 49 geoserver
# Training 49 for geoserver
# Bootstrapping 44 for cloud_controller_ng
# Here for 44 cloud_controller_ng
# Training 44 for cloud_controller_ng
# Bootstrapping 2 for orbeon-forms
# Here for 2 orbeon-forms
# Training 2 for orbeon-forms
# Bootstrapping 7 for chef
# Here for 7 chef
# Training 7 for chef
# Going right....
# The training period = 2014-08-23 16:19:56 to 2015-06-20 16:19:56
# The testing period = 2015-06-19 16:19:56 to 2015-07-19 16:19:56
# Bootstrapping 0 for geoserver
# Here for 0 geoserver
# Training 0 for geoserver
# Bootstrapping 48 for gradle
# Here for 48 gradle
# Training 48 for gradle
# Going right....
# The training period = 2013-08-06 11:25:11 to 2014-06-03 11:25:11
# The testing period = 2014-06-02 11:25:11 to 2014-07-02 11:25:11
# Bootstrapping 0 for opal
# Here for 0 opal
# Training 0 for opal
# Bootstrapping 46 for jruby
# Here for 46 jruby
# Training 46 for jruby
# Bootstrapping 45 for cloud_controller_ng
# Here for 45 cloud_controller_ng
# Training 45 for cloud_controller_ng
# Bootstrapping 3 for orbeon-forms
# Here for 3 orbeon-forms
# Training 3 for orbeon-forms
# Bootstrapping 30 for cloudify
# Here for 30 cloudify
# Training 30 for cloudify
# Bootstrapping 8 for chef
# Here for 8 chef
# Training 8 for chef
# Bootstrapping 1 for geoserver
# Here for 1 geoserver
# Training 1 for geoserver
# Bootstrapping 49 for gradle
# Here for 49 gradle
# Training 49 for gradle
# Bootstrapping 1 for opal
# Here for 1 opal
# Training 1 for opal
# Bootstrapping 47 for jruby
# Here for 47 jruby
# Training 47 for jruby
# Bootstrapping 4 for orbeon-forms
# Here for 4 orbeon-forms
# Training 4 for orbeon-forms
# Bootstrapping 46 for cloud_controller_ng
# Here for 46 cloud_controller_ng
# Training 46 for cloud_controller_ng
# Bootstrapping 9 for chef
# Here for 9 chef
# Training 9 for chef
# Bootstrapping 5 for orbeon-forms
# Here for 5 orbeon-forms
# Training 5 for orbeon-forms
# Bootstrapping 2 for geoserver
# Here for 2 geoserver
# Training 2 for geoserver
# Bootstrapping 2 for opal
# Here for 2 opal
# Training 2 for opal
# Bootstrapping 31 for cloudify
# Here for 31 cloudify
# Training 31 for cloudify
# Going right....
# Average Time Reqd in gradle = 0.0
# Average Builds Reqd in gradle = 0.0
# Average Total Delay in gradle = 1940.0
# Average Failed Identified in gradle = 0.0
# Average Failed Unidentified in gradle = 100.0
#
#
#
#
#
#
# Bootstrapping 48 for jruby
# Here for 48 jruby
# Training 48 for jruby
# Bootstrapping 47 for cloud_controller_ng
# Here for 47 cloud_controller_ng
# Training 47 for cloud_controller_ng
# Bootstrapping 6 for orbeon-forms
# Here for 6 orbeon-forms
# Training 6 for orbeon-forms
# Bootstrapping 10 for chef
# Here for 10 chef
# Training 10 for chef
# Bootstrapping 3 for geoserver
# Here for 3 geoserver
# Training 3 for geoserver
# Bootstrapping 3 for opal
# Here for 3 opal
# Training 3 for opal
# Bootstrapping 49 for jruby
# Here for 49 jruby
# Training 49 for jruby
# Bootstrapping 48 for cloud_controller_ng
# Here for 48 cloud_controller_ng
# Training 48 for cloud_controller_ng
# Bootstrapping 7 for orbeon-forms
# Here for 7 orbeon-forms
# Training 7 for orbeon-forms
# Bootstrapping 11 for chef
# Here for 11 chef
# Training 11 for chef
# Bootstrapping 32 for cloudify
# Here for 32 cloudify
# Training 32 for cloudify
# Bootstrapping 4 for geoserver
# Here for 4 geoserver
# Training 4 for geoserver
# Bootstrapping 4 for opal
# Here for 4 opal
# Training 4 for opal
# Going right....
# The training period = 2013-05-18 02:07:19 to 2014-03-15 02:07:19
# The testing period = 2014-03-14 02:07:19 to 2014-04-13 02:07:19
# Bootstrapping 0 for jruby
# Here for 0 jruby
# Training 0 for jruby
# Bootstrapping 8 for orbeon-forms
# Here for 8 orbeon-forms
# Training 8 for orbeon-forms
# Bootstrapping 49 for cloud_controller_ng
# Here for 49 cloud_controller_ng
# Training 49 for cloud_controller_ng
# Bootstrapping 12 for chef
# Here for 12 chef
# Training 12 for chef
# Bootstrapping 5 for geoserver
# Here for 5 geoserver
# Training 5 for geoserver
# Bootstrapping 5 for opal
# Here for 5 opal
# Training 5 for opal
# Bootstrapping 9 for orbeon-forms
# Here for 9 orbeon-forms
# Training 9 for orbeon-forms
# Bootstrapping 33 for cloudify
# Here for 33 cloudify
# Training 33 for cloudify
# Bootstrapping 13 for chef
# Here for 13 chef
# Training 13 for chef
# Bootstrapping 1 for jruby
# Here for 1 jruby
# Training 1 for jruby
# Going right....
# The training period = 2013-12-12 20:55:32 to 2014-10-09 20:55:32
# The testing period = 2014-10-08 20:55:32 to 2014-11-07 20:55:32
# Bootstrapping 0 for cloud_controller_ng
# Here for 0 cloud_controller_ng
# Training 0 for cloud_controller_ng
# Bootstrapping 6 for geoserver
# Here for 6 geoserver
# Training 6 for geoserver
# Bootstrapping 10 for orbeon-forms
# Here for 10 orbeon-forms
# Training 10 for orbeon-forms
# Bootstrapping 6 for opal
# Here for 6 opal
# Training 6 for opal
# Bootstrapping 14 for chef
# Here for 14 chef
# Training 14 for chef
# Bootstrapping 7 for geoserver
# Here for 7 geoserver
# Training 7 for geoserver
# Bootstrapping 1 for cloud_controller_ng
# Here for 1 cloud_controller_ng
# Training 1 for cloud_controller_ng
# Bootstrapping 2 for jruby
# Here for 2 jruby
# Training 2 for jruby
# Bootstrapping 34 for cloudify
# Here for 34 cloudify
# Training 34 for cloudify
# Bootstrapping 11 for orbeon-forms
# Here for 11 orbeon-forms
# Training 11 for orbeon-forms
# Bootstrapping 7 for opal
# Here for 7 opal
# Training 7 for opal
# Bootstrapping 15 for chef
# Here for 15 chef
# Training 15 for chef
# Bootstrapping 12 for orbeon-forms
# Here for 12 orbeon-forms
# Training 12 for orbeon-forms
# Bootstrapping 8 for geoserver
# Here for 8 geoserver
# Training 8 for geoserver
# Bootstrapping 2 for cloud_controller_ng
# Here for 2 cloud_controller_ng
# Training 2 for cloud_controller_ng
# Bootstrapping 3 for jruby
# Here for 3 jruby
# Training 3 for jruby
# Bootstrapping 8 for opal
# Here for 8 opal
# Training 8 for opal
# Bootstrapping 35 for cloudify
# Here for 35 cloudify
# Training 35 for cloudify
# Bootstrapping 16 for chef
# Here for 16 chef
# Training 16 for chef
# Bootstrapping 13 for orbeon-forms
# Here for 13 orbeon-forms
# Training 13 for orbeon-forms
# Bootstrapping 9 for geoserver
# Here for 9 geoserver
# Training 9 for geoserver
# Bootstrapping 9 for opal
# Here for 9 opal
# Training 9 for opal
# Bootstrapping 3 for cloud_controller_ng
# Here for 3 cloud_controller_ng
# Training 3 for cloud_controller_ng
# Bootstrapping 14 for orbeon-forms
# Here for 14 orbeon-forms
# Training 14 for orbeon-forms
# Bootstrapping 4 for jruby
# Here for 4 jruby
# Training 4 for jruby
# Bootstrapping 17 for chef
# Here for 17 chef
# Training 17 for chef
# Bootstrapping 10 for geoserver
# Here for 10 geoserver
# Training 10 for geoserver
# Bootstrapping 36 for cloudify
# Here for 36 cloudify
# Training 36 for cloudify
# Bootstrapping 15 for orbeon-forms
# Here for 15 orbeon-forms
# Training 15 for orbeon-forms
# Bootstrapping 10 for opal
# Here for 10 opal
# Training 10 for opal
# Bootstrapping 4 for cloud_controller_ng
# Here for 4 cloud_controller_ng
# Training 4 for cloud_controller_ng
# Bootstrapping 18 for chef
# Here for 18 chef
# Training 18 for chef
# Bootstrapping 5 for jruby
# Here for 5 jruby
# Training 5 for jruby
# Bootstrapping 11 for geoserver
# Here for 11 geoserver
# Training 11 for geoserver
# Bootstrapping 16 for orbeon-forms
# Here for 16 orbeon-forms
# Training 16 for orbeon-forms
# Bootstrapping 11 for opal
# Here for 11 opal
# Training 11 for opal
# Bootstrapping 5 for cloud_controller_ng
# Here for 5 cloud_controller_ng
# Training 5 for cloud_controller_ng
# Bootstrapping 19 for chef
# Here for 19 chef
# Training 19 for chef
# Bootstrapping 37 for cloudify
# Here for 37 cloudify
# Training 37 for cloudify
# Bootstrapping 12 for geoserver
# Here for 12 geoserver
# Training 12 for geoserver
# Bootstrapping 17 for orbeon-forms
# Here for 17 orbeon-forms
# Training 17 for orbeon-forms
# Bootstrapping 6 for jruby
# Here for 6 jruby
# Training 6 for jruby
# Bootstrapping 12 for opal
# Here for 12 opal
# Training 12 for opal
# Bootstrapping 20 for chef
# Here for 20 chef
# Training 20 for chef
# Bootstrapping 6 for cloud_controller_ng
# Here for 6 cloud_controller_ng
# Training 6 for cloud_controller_ng
# Bootstrapping 18 for orbeon-forms
# Here for 18 orbeon-forms
# Training 18 for orbeon-forms
# Bootstrapping 13 for geoserver
# Here for 13 geoserver
# Training 13 for geoserver
# Bootstrapping 38 for cloudify
# Here for 38 cloudify
# Training 38 for cloudify
# Bootstrapping 7 for jruby
# Here for 7 jruby
# Training 7 for jruby
# Bootstrapping 13 for opal
# Here for 13 opal
# Training 13 for opal
# Bootstrapping 21 for chef
# Here for 21 chef
# Training 21 for chef
# Bootstrapping 19 for orbeon-forms
# Here for 19 orbeon-forms
# Training 19 for orbeon-forms
# Bootstrapping 7 for cloud_controller_ng
# Here for 7 cloud_controller_ng
# Training 7 for cloud_controller_ng
# Bootstrapping 14 for geoserver
# Here for 14 geoserver
# Training 14 for geoserver
# Bootstrapping 14 for opal
# Here for 14 opal
# Training 14 for opal
# Bootstrapping 20 for orbeon-forms
# Here for 20 orbeon-forms
# Training 20 for orbeon-forms
# Bootstrapping 22 for chef
# Here for 22 chef
# Training 22 for chef
# Bootstrapping 39 for cloudify
# Here for 39 cloudify
# Training 39 for cloudify
# Bootstrapping 8 for jruby
# Here for 8 jruby
# Training 8 for jruby
# Bootstrapping 8 for cloud_controller_ng
# Here for 8 cloud_controller_ng
# Training 8 for cloud_controller_ng
# Bootstrapping 15 for geoserver
# Here for 15 geoserver
# Training 15 for geoserver
# Bootstrapping 21 for orbeon-forms
# Here for 21 orbeon-forms
# Training 21 for orbeon-forms
# Bootstrapping 15 for opal
# Here for 15 opal
# Training 15 for opal
# Bootstrapping 23 for chef
# Here for 23 chef
# Training 23 for chef
# Bootstrapping 9 for cloud_controller_ng
# Here for 9 cloud_controller_ng
# Training 9 for cloud_controller_ng
# Bootstrapping 16 for geoserver
# Here for 16 geoserver
# Training 16 for geoserver
# Bootstrapping 22 for orbeon-forms
# Here for 22 orbeon-forms
# Training 22 for orbeon-forms
# Bootstrapping 9 for jruby
# Here for 9 jruby
# Training 9 for jruby
# Bootstrapping 40 for cloudify
# Here for 40 cloudify
# Training 40 for cloudify
# Bootstrapping 16 for opal
# Here for 16 opal
# Training 16 for opal
# Bootstrapping 24 for chef
# Here for 24 chef
# Training 24 for chef
# Bootstrapping 17 for geoserver
# Here for 17 geoserver
# Training 17 for geoserver
# Bootstrapping 23 for orbeon-forms
# Here for 23 orbeon-forms
# Training 23 for orbeon-forms
# Bootstrapping 10 for cloud_controller_ng
# Here for 10 cloud_controller_ng
# Training 10 for cloud_controller_ng
# Bootstrapping 17 for opal
# Here for 17 opal
# Training 17 for opal
# Bootstrapping 10 for jruby
# Here for 10 jruby
# Training 10 for jruby
# Bootstrapping 25 for chef
# Here for 25 chef
# Training 25 for chef
# Bootstrapping 24 for orbeon-forms
# Here for 24 orbeon-forms
# Training 24 for orbeon-forms
# Bootstrapping 18 for geoserver
# Here for 18 geoserver
# Training 18 for geoserver
# Bootstrapping 41 for cloudify
# Here for 41 cloudify
# Training 41 for cloudify
# Bootstrapping 11 for cloud_controller_ng
# Here for 11 cloud_controller_ng
# Training 11 for cloud_controller_ng
# Bootstrapping 18 for opal
# Here for 18 opal
# Training 18 for opal
# Bootstrapping 25 for orbeon-forms
# Here for 25 orbeon-forms
# Training 25 for orbeon-forms
# Bootstrapping 26 for chef
# Here for 26 chef
# Training 26 for chef
# Bootstrapping 19 for geoserver
# Here for 19 geoserver
# Training 19 for geoserver
# Bootstrapping 11 for jruby
# Here for 11 jruby
# Training 11 for jruby
# Bootstrapping 12 for cloud_controller_ng
# Here for 12 cloud_controller_ng
# Training 12 for cloud_controller_ng
# Bootstrapping 19 for opal
# Here for 19 opal
# Training 19 for opal
# Bootstrapping 26 for orbeon-forms
# Here for 26 orbeon-forms
# Training 26 for orbeon-forms
# Bootstrapping 42 for cloudify
# Here for 42 cloudify
# Training 42 for cloudify
# Bootstrapping 27 for chef
# Here for 27 chef
# Training 27 for chef
# Bootstrapping 20 for geoserver
# Here for 20 geoserver
# Training 20 for geoserver
# Bootstrapping 13 for cloud_controller_ng
# Here for 13 cloud_controller_ng
# Training 13 for cloud_controller_ng
# Bootstrapping 27 for orbeon-forms
# Here for 27 orbeon-forms
# Training 27 for orbeon-forms
# Bootstrapping 20 for opal
# Here for 20 opal
# Training 20 for opal
# Bootstrapping 12 for jruby
# Here for 12 jruby
# Training 12 for jruby
# Bootstrapping 28 for chef
# Here for 28 chef
# Training 28 for chef
# Bootstrapping 21 for geoserver
# Here for 21 geoserver
# Training 21 for geoserver
# Bootstrapping 28 for orbeon-forms
# Here for 28 orbeon-forms
# Training 28 for orbeon-forms
# Bootstrapping 14 for cloud_controller_ng
# Here for 14 cloud_controller_ng
# Training 14 for cloud_controller_ng
# Bootstrapping 43 for cloudify
# Here for 43 cloudify
# Training 43 for cloudify
# Bootstrapping 21 for opal
# Here for 21 opal
# Training 21 for opal
# Bootstrapping 29 for chef
# Here for 29 chef
# Training 29 for chef
# Bootstrapping 13 for jruby
# Here for 13 jruby
# Training 13 for jruby
# Bootstrapping 22 for geoserver
# Here for 22 geoserver
# Training 22 for geoserver
# Bootstrapping 29 for orbeon-forms
# Here for 29 orbeon-forms
# Training 29 for orbeon-forms
# Bootstrapping 22 for opal
# Here for 22 opal
# Training 22 for opal
# Bootstrapping 15 for cloud_controller_ng
# Here for 15 cloud_controller_ng
# Training 15 for cloud_controller_ng
# Bootstrapping 30 for orbeon-forms
# Here for 30 orbeon-forms
# Training 30 for orbeon-forms
# Bootstrapping 44 for cloudify
# Here for 44 cloudify
# Training 44 for cloudify
# Bootstrapping 30 for chef
# Here for 30 chef
# Training 30 for chef
# Bootstrapping 23 for geoserver
# Here for 23 geoserver
# Training 23 for geoserver
# Bootstrapping 14 for jruby
# Here for 14 jruby
# Training 14 for jruby
# Bootstrapping 23 for opal
# Here for 23 opal
# Training 23 for opal
# Bootstrapping 16 for cloud_controller_ng
# Here for 16 cloud_controller_ng
# Training 16 for cloud_controller_ng
# Bootstrapping 31 for orbeon-forms
# Here for 31 orbeon-forms
# Training 31 for orbeon-forms
# Bootstrapping 31 for chef
# Here for 31 chef
# Training 31 for chef
# Bootstrapping 24 for geoserver
# Here for 24 geoserver
# Training 24 for geoserver
# Bootstrapping 24 for opal
# Here for 24 opal
# Training 24 for opal
# Bootstrapping 45 for cloudify
# Here for 45 cloudify
# Training 45 for cloudify
# Bootstrapping 17 for cloud_controller_ng
# Here for 17 cloud_controller_ng
# Training 17 for cloud_controller_ng
# Bootstrapping 32 for orbeon-forms
# Here for 32 orbeon-forms
# Training 32 for orbeon-forms
# Bootstrapping 15 for jruby
# Here for 15 jruby
# Training 15 for jruby
# Bootstrapping 32 for chef
# Here for 32 chef
# Training 32 for chef
# Bootstrapping 25 for geoserver
# Here for 25 geoserver
# Training 25 for geoserver
# Bootstrapping 25 for opal
# Here for 25 opal
# Training 25 for opal
# Bootstrapping 33 for orbeon-forms
# Here for 33 orbeon-forms
# Training 33 for orbeon-forms
# Bootstrapping 18 for cloud_controller_ng
# Here for 18 cloud_controller_ng
# Training 18 for cloud_controller_ng
# Bootstrapping 33 for chef
# Here for 33 chef
# Training 33 for chef
# Bootstrapping 16 for jruby
# Here for 16 jruby
# Training 16 for jruby
# Bootstrapping 46 for cloudify
# Here for 46 cloudify
# Training 46 for cloudify
# Bootstrapping 34 for orbeon-forms
# Here for 34 orbeon-forms
# Training 34 for orbeon-forms
# Bootstrapping 26 for geoserver
# Here for 26 geoserver
# Training 26 for geoserver
# Bootstrapping 26 for opal
# Here for 26 opal
# Training 26 for opal
# Bootstrapping 19 for cloud_controller_ng
# Here for 19 cloud_controller_ng
# Training 19 for cloud_controller_ng
# Bootstrapping 34 for chef
# Here for 34 chef
# Training 34 for chef
# Bootstrapping 35 for orbeon-forms
# Here for 35 orbeon-forms
# Training 35 for orbeon-forms
# Bootstrapping 17 for jruby
# Here for 17 jruby
# Training 17 for jruby
# Bootstrapping 27 for geoserver
# Here for 27 geoserver
# Training 27 for geoserver
# Bootstrapping 27 for opal
# Here for 27 opal
# Training 27 for opal
# Process LokyProcess-172:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 446, in _process_worker
#     del call_item
# KeyboardInterrupt
# Process LokyProcess-166:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 483, in _process_worker
#     gc.collect()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_38544/1559431214.py in <module>
#       2
#       3 with Pool(9) as pool:
# ----> 4     pool.map(bootstrapping, project_list)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/site-packages/multiprocess/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# /opt/homebrew/Caskroom/miniforge/base/envs/new_env/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
