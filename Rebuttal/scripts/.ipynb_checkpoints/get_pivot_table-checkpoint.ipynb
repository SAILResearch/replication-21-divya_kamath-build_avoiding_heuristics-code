# %%
import pandas as pd
import sys
import csv
from statistics import median

# %%
results = pd.read_csv("final_results_for_plotting.csv")

# %%
results['project'] = results['project'].str.replace('.csv','')
# Out:
# /var/folders/09/2vzp5xpd2ldd4ggk4xzjt1qr0000gn/T/ipykernel_63033/2064200378.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   results['project'] = results['project'].str.replace('.csv','')

# %%
results
# Out:
#      Unnamed: 0  Unnamed: 0.1               project    algorithm  batch_size  \
# 0             0             0              rubinius       BATCH4           4
# 1             1             1              rubinius  BATCHBISECT           1
# 2             2             2              rubinius  BATCHBISECT           2
# 3             3             3              rubinius  BATCHBISECT           4
# 4             4             4              rubinius  BATCHBISECT           8
# ..          ...           ...                   ...          ...         ...
# 615         141           141                 jruby       BATCH4           4
# 616         150           150       graylog2-server       BATCH4           4
# 617         159           159              cloudify       BATCH4           4
# 618         168           168  metasploit-framework       BATCH4           4
# 619         177           177                loomio       BATCH4           4
#
#      builds_reqd  median_delay  testall_size  sum_delay method  confidence
# 0      30.751498           5.0          2169     2960.0    sbs         NaN
# 1      30.751498           5.0          2169     2960.0    sbs         NaN
# 2      30.751498           5.0          2169     2960.0    sbs         NaN
# 3      30.751498           5.0          2169     2960.0    sbs         NaN
# 4      30.751498           5.0          2169     2960.0    sbs         NaN
# ..           ...           ...           ...        ...    ...         ...
# 615   113.145538           2.0          4473        NaN     tr         8.0
# 616    25.021872           2.0          1143        NaN     tr        18.0
# 617    49.865437           2.0          2601        NaN     tr        20.0
# 618    27.777779           2.0          4104        NaN     tr        19.0
# 619    57.133839           2.0          1584        NaN     tr        17.0
#
# [620 rows x 11 columns]

# %%
results = results.drop('Unnamed: 0', axis='columns')

# %%
method = ['mlci', 'tr', 'gr', '']
algorithms = ['BATCH4', 'BATCHBISECT', 'BATCHSTOP4']
batchsize = [2, 4, 8, 16]
project_list = list(set(results['project'].tolist()))

# %%
for m in method:
    
    filename = m + '_pivot_median_delay.csv'
    file = open(filename, 'w')
    res_headers = ['project', 'B4_builds', 'B4_delay', 'B4_Batch', 'BB_builds', 'BB_delay', 'BB_Batch', 'BS4_builds', 'BS4_delay', 'BS4_Batch']
    res_writer = csv.writer(file)
    res_writer.writerow(res_headers)
    
    
    for p in project_list:
        
        b4_builds = 0
        b4_delay = 0
        b4_batch = 0
        
        bs4_builds = 0
        bs4_delay = 0
        bs4_batch = 0
        
        bb_builds = 0
        bb_delay = 0
        bb_batch = 0
        
        for alg in algorithms:
            data = results[ (results['method'] == m) & (results['algorithm'] == alg) & (results['project'] == p)]
            data = data.drop(data[data.batch_size < 2].index)
            data = data.drop(data[data.batch_size > 16].index)

            best_batch = 0
            lowest_distance = sys.maxsize
            delays = data['median_delay'].tolist()
            builds_reqd = data['builds_reqd'].tolist()
            batch_size = data['batch_size'].tolist()

            for i in range(len(delays)):
                d = (builds_reqd[i]**2 + delays[i]**2)**0.5
                if d < lowest_distance:
                    
                    best_batch = batch_size[i]
                    lowest_distance = d
                    
                    if alg == 'BATCHBISECT':
                        bb_builds = builds_reqd[i]
                        bb_delay = delays[i]
                        bb_batch = best_batch
                    elif alg == 'BATCHSTOP4':
                        bs4_builds = builds_reqd[i]
                        bs4_delay = delays[i]
                        bs4_batch = best_batch
                    else:
                        b4_builds = builds_reqd[i]
                        b4_delay = delays[i]
                        b4_batch = best_batch
            print('{} - {} - {} - {}'.format(p, m, alg, best_batch))
        res_writer.writerow([p, b4_builds, b4_delay, b4_batch, bb_builds, bb_delay, bb_batch, bs4_builds, bs4_delay, bs4_batch])
# Out:
# opal - mlci - BATCH4 - 4
# opal - mlci - BATCHBISECT - 4
# opal - mlci - BATCHSTOP4 - 8
# fog - mlci - BATCH4 - 4
# fog - mlci - BATCHBISECT - 2
# fog - mlci - BATCHSTOP4 - 8
# cloud_controller_ng - mlci - BATCH4 - 4
# cloud_controller_ng - mlci - BATCHBISECT - 2
# cloud_controller_ng - mlci - BATCHSTOP4 - 8
# puppet - mlci - BATCH4 - 4
# puppet - mlci - BATCHBISECT - 8
# puppet - mlci - BATCHSTOP4 - 8
# orbeon-forms - mlci - BATCH4 - 4
# orbeon-forms - mlci - BATCHBISECT - 2
# orbeon-forms - mlci - BATCHSTOP4 - 8
# sufia - mlci - BATCH4 - 4
# sufia - mlci - BATCHBISECT - 4
# sufia - mlci - BATCHSTOP4 - 8
# vagrant - mlci - BATCH4 - 4
# vagrant - mlci - BATCHBISECT - 8
# vagrant - mlci - BATCHSTOP4 - 8
# heroku - mlci - BATCH4 - 4
# heroku - mlci - BATCHBISECT - 2
# heroku - mlci - BATCHSTOP4 - 8
# loomio - mlci - BATCH4 - 4
# loomio - mlci - BATCHBISECT - 2
# loomio - mlci - BATCHSTOP4 - 8
# concerto - mlci - BATCH4 - 4
# concerto - mlci - BATCHBISECT - 8
# concerto - mlci - BATCHSTOP4 - 8
# geoserver - mlci - BATCH4 - 4
# geoserver - mlci - BATCHBISECT - 2
# geoserver - mlci - BATCHSTOP4 - 8
# jruby - mlci - BATCH4 - 4
# jruby - mlci - BATCHBISECT - 2
# jruby - mlci - BATCHSTOP4 - 8
# graylog2-server - mlci - BATCH4 - 4
# graylog2-server - mlci - BATCHBISECT - 16
# graylog2-server - mlci - BATCHSTOP4 - 16
# sonarqube - mlci - BATCH4 - 4
# sonarqube - mlci - BATCHBISECT - 2
# sonarqube - mlci - BATCHSTOP4 - 8
# rubinius - mlci - BATCH4 - 4
# rubinius - mlci - BATCHBISECT - 2
# rubinius - mlci - BATCHSTOP4 - 8
# gradle - mlci - BATCH4 - 4
# gradle - mlci - BATCHBISECT - 4
# gradle - mlci - BATCHSTOP4 - 8
# cloudify - mlci - BATCH4 - 4
# cloudify - mlci - BATCHBISECT - 4
# cloudify - mlci - BATCHSTOP4 - 8
# rails - mlci - BATCH4 - 4
# rails - mlci - BATCHBISECT - 2
# rails - mlci - BATCHSTOP4 - 8
# metasploit-framework - mlci - BATCH4 - 4
# metasploit-framework - mlci - BATCHBISECT - 16
# metasploit-framework - mlci - BATCHSTOP4 - 16
# open-build-service - mlci - BATCH4 - 4
# open-build-service - mlci - BATCHBISECT - 2
# open-build-service - mlci - BATCHSTOP4 - 8
# opal - tr - BATCH4 - 4
# opal - tr - BATCHBISECT - 16
# opal - tr - BATCHSTOP4 - 16
# fog - tr - BATCH4 - 4
# fog - tr - BATCHBISECT - 4
# fog - tr - BATCHSTOP4 - 8
# cloud_controller_ng - tr - BATCH4 - 4
# cloud_controller_ng - tr - BATCHBISECT - 4
# cloud_controller_ng - tr - BATCHSTOP4 - 8
# puppet - tr - BATCH4 - 4
# puppet - tr - BATCHBISECT - 16
# puppet - tr - BATCHSTOP4 - 16
# orbeon-forms - tr - BATCH4 - 4
# orbeon-forms - tr - BATCHBISECT - 2
# orbeon-forms - tr - BATCHSTOP4 - 8
# sufia - tr - BATCH4 - 4
# sufia - tr - BATCHBISECT - 16
# sufia - tr - BATCHSTOP4 - 16
# vagrant - tr - BATCH4 - 4
# vagrant - tr - BATCHBISECT - 16
# vagrant - tr - BATCHSTOP4 - 16
# heroku - tr - BATCH4 - 4
# heroku - tr - BATCHBISECT - 8
# heroku - tr - BATCHSTOP4 - 8
# loomio - tr - BATCH4 - 4
# loomio - tr - BATCHBISECT - 4
# loomio - tr - BATCHSTOP4 - 8
# concerto - tr - BATCH4 - 4
# concerto - tr - BATCHBISECT - 16
# concerto - tr - BATCHSTOP4 - 16
# geoserver - tr - BATCH4 - 4
# geoserver - tr - BATCHBISECT - 2
# geoserver - tr - BATCHSTOP4 - 8
# jruby - tr - BATCH4 - 4
# jruby - tr - BATCHBISECT - 2
# jruby - tr - BATCHSTOP4 - 8
# graylog2-server - tr - BATCH4 - 4
# graylog2-server - tr - BATCHBISECT - 16
# graylog2-server - tr - BATCHSTOP4 - 16
# sonarqube - tr - BATCH4 - 4
# sonarqube - tr - BATCHBISECT - 8
# sonarqube - tr - BATCHSTOP4 - 8
# rubinius - tr - BATCH4 - 4
# rubinius - tr - BATCHBISECT - 2
# rubinius - tr - BATCHSTOP4 - 8
# gradle - tr - BATCH4 - 4
# gradle - tr - BATCHBISECT - 16
# gradle - tr - BATCHSTOP4 - 16
# cloudify - tr - BATCH4 - 4
# cloudify - tr - BATCHBISECT - 16
# cloudify - tr - BATCHSTOP4 - 8
# rails - tr - BATCH4 - 4
# rails - tr - BATCHBISECT - 4
# rails - tr - BATCHSTOP4 - 8
# metasploit-framework - tr - BATCH4 - 4
# metasploit-framework - tr - BATCHBISECT - 16
# metasploit-framework - tr - BATCHSTOP4 - 16
# open-build-service - tr - BATCH4 - 4
# open-build-service - tr - BATCHBISECT - 4
# open-build-service - tr - BATCHSTOP4 - 8
# opal - gr - BATCH4 - 4
# opal - gr - BATCHBISECT - 8
# opal - gr - BATCHSTOP4 - 8
# fog - gr - BATCH4 - 4
# fog - gr - BATCHBISECT - 2
# fog - gr - BATCHSTOP4 - 8
# cloud_controller_ng - gr - BATCH4 - 4
# cloud_controller_ng - gr - BATCHBISECT - 4
# cloud_controller_ng - gr - BATCHSTOP4 - 8
# puppet - gr - BATCH4 - 4
# puppet - gr - BATCHBISECT - 16
# puppet - gr - BATCHSTOP4 - 16
# orbeon-forms - gr - BATCH4 - 4
# orbeon-forms - gr - BATCHBISECT - 2
# orbeon-forms - gr - BATCHSTOP4 - 8
# sufia - gr - BATCH4 - 4
# sufia - gr - BATCHBISECT - 8
# sufia - gr - BATCHSTOP4 - 8
# vagrant - gr - BATCH4 - 4
# vagrant - gr - BATCHBISECT - 16
# vagrant - gr - BATCHSTOP4 - 16
# heroku - gr - BATCH4 - 4
# heroku - gr - BATCHBISECT - 8
# heroku - gr - BATCHSTOP4 - 8
# loomio - gr - BATCH4 - 4
# loomio - gr - BATCHBISECT - 4
# loomio - gr - BATCHSTOP4 - 8
# concerto - gr - BATCH4 - 4
# concerto - gr - BATCHBISECT - 8
# concerto - gr - BATCHSTOP4 - 8
# geoserver - gr - BATCH4 - 4
# geoserver - gr - BATCHBISECT - 2
# geoserver - gr - BATCHSTOP4 - 8
# jruby - gr - BATCH4 - 4
# jruby - gr - BATCHBISECT - 2
# jruby - gr - BATCHSTOP4 - 8
# graylog2-server - gr - BATCH4 - 4
# graylog2-server - gr - BATCHBISECT - 16
# graylog2-server - gr - BATCHSTOP4 - 16
# sonarqube - gr - BATCH4 - 4
# sonarqube - gr - BATCHBISECT - 4
# sonarqube - gr - BATCHSTOP4 - 8
# rubinius - gr - BATCH4 - 4
# rubinius - gr - BATCHBISECT - 2
# rubinius - gr - BATCHSTOP4 - 8
# gradle - gr - BATCH4 - 4
# gradle - gr - BATCHBISECT - 8
# gradle - gr - BATCHSTOP4 - 8
# cloudify - gr - BATCH4 - 4
# cloudify - gr - BATCHBISECT - 16
# cloudify - gr - BATCHSTOP4 - 16
# rails - gr - BATCH4 - 4
# rails - gr - BATCHBISECT - 4
# rails - gr - BATCHSTOP4 - 8
# metasploit-framework - gr - BATCH4 - 4
# metasploit-framework - gr - BATCHBISECT - 16
# metasploit-framework - gr - BATCHSTOP4 - 16
# open-build-service - gr - BATCH4 - 4
# open-build-service - gr - BATCHBISECT - 4
# open-build-service - gr - BATCHSTOP4 - 8
# opal -  - BATCH4 - 0
# opal -  - BATCHBISECT - 0
# opal -  - BATCHSTOP4 - 0
# fog -  - BATCH4 - 0
# fog -  - BATCHBISECT - 0
# fog -  - BATCHSTOP4 - 0
# cloud_controller_ng -  - BATCH4 - 0
# cloud_controller_ng -  - BATCHBISECT - 0
# cloud_controller_ng -  - BATCHSTOP4 - 0
# puppet -  - BATCH4 - 0
# puppet -  - BATCHBISECT - 0
# puppet -  - BATCHSTOP4 - 0
# orbeon-forms -  - BATCH4 - 0
# orbeon-forms -  - BATCHBISECT - 0
# orbeon-forms -  - BATCHSTOP4 - 0
# sufia -  - BATCH4 - 0
# sufia -  - BATCHBISECT - 0
# sufia -  - BATCHSTOP4 - 0
# vagrant -  - BATCH4 - 0
# vagrant -  - BATCHBISECT - 0
# vagrant -  - BATCHSTOP4 - 0
# heroku -  - BATCH4 - 0
# heroku -  - BATCHBISECT - 0
# heroku -  - BATCHSTOP4 - 0
# loomio -  - BATCH4 - 0
# loomio -  - BATCHBISECT - 0
# loomio -  - BATCHSTOP4 - 0
# concerto -  - BATCH4 - 0
# concerto -  - BATCHBISECT - 0
# concerto -  - BATCHSTOP4 - 0
# geoserver -  - BATCH4 - 0
# geoserver -  - BATCHBISECT - 0
# geoserver -  - BATCHSTOP4 - 0
# jruby -  - BATCH4 - 0
# jruby -  - BATCHBISECT - 0
# jruby -  - BATCHSTOP4 - 0
# graylog2-server -  - BATCH4 - 0
# graylog2-server -  - BATCHBISECT - 0
# graylog2-server -  - BATCHSTOP4 - 0
# sonarqube -  - BATCH4 - 0
# sonarqube -  - BATCHBISECT - 0
# sonarqube -  - BATCHSTOP4 - 0
# rubinius -  - BATCH4 - 0
# rubinius -  - BATCHBISECT - 0
# rubinius -  - BATCHSTOP4 - 0
# gradle -  - BATCH4 - 0
# gradle -  - BATCHBISECT - 0
# gradle -  - BATCHSTOP4 - 0
# cloudify -  - BATCH4 - 0
# cloudify -  - BATCHBISECT - 0
# cloudify -  - BATCHSTOP4 - 0
# rails -  - BATCH4 - 0
# rails -  - BATCHBISECT - 0
# rails -  - BATCHSTOP4 - 0
# metasploit-framework -  - BATCH4 - 0
# metasploit-framework -  - BATCHBISECT - 0
# metasploit-framework -  - BATCHSTOP4 - 0
# open-build-service -  - BATCH4 - 0
# open-build-service -  - BATCHBISECT - 0
# open-build-service -  - BATCHSTOP4 - 0

# %%
batch_reps = {0: 'na', 2: '2', 4: '4', 8:'8', 16:'16'}

# %%
print(batch_reps[2])
# Out:
# 2

# %%
ssr = pd.read_csv('tr_pivot_median_delay.csv')

# %%
ssr = ssr.sort_values(by=['project'])
projects = ssr['project'].tolist()
col3 = ssr['B4_builds'].tolist()
col4 = ssr['B4_delay'].tolist()
b4_batch = ssr['B4_Batch'].tolist()
col5 = ssr['BB_builds'].tolist()
col6 = ssr['BB_delay'].tolist()
bb_batch = ssr['BB_Batch'].tolist()
col7 = ssr['BS4_builds'].tolist()
col8 = ssr['BS4_delay'].tolist()
bs4_batch = ssr['BS4_Batch'].tolist()

# %%
for i in range(len(projects)):
    print("{} & {} & {} & {} & {} & {} & {} & {} & {} & {}\\\\".format(projects[i].split('.')[0],  
                                                                round(col3[i], 3), round(col4[i], 3), batch_reps[b4_batch[i]], 
                                                                round(col5[i], 3), round(col6[i], 3), batch_reps[bb_batch[i]], 
                                                                round(col7[i], 3), round(col8[i], 3), batch_reps[bs4_batch[i]] ))
    print("\hline")

print("Median & {} & {} & & {} & {} & & {} & {}".format(round(median(col3), 3), round(median(col4), 3), round(median(col5), 3), round(median(col6), 3), round(median(col7), 3), round(median(col8), 3)))
print("\hline\n\hline")
# Out:
# cloud_controller_ng & 52.855 & 2.0 & 4 & 55.71 & 2.0 & 4 & 53.395 & 4.0 & 8\\
# \hline
# cloudify & 49.865 & 2.0 & 4 & 52.018 & 8.0 & 16 & 46.79 & 4.0 & 8\\
# \hline
# concerto & 33.494 & 2.0 & 4 & 26.651 & 7.0 & 16 & 26.329 & 7.0 & 16\\
# \hline
# fog & 67.063 & 2.0 & 4 & 74.537 & 2.0 & 4 & 69.444 & 4.0 & 8\\
# \hline
# geoserver & 91.858 & 2.0 & 4 & 110.263 & 1.0 & 2 & 98.304 & 4.0 & 8\\
# \hline
# gradle & 26.22 & 2.0 & 4 & 12.201 & 7.0 & 16 & 12.098 & 7.0 & 16\\
# \hline
# graylog2-server & 25.022 & 2.0 & 4 & 12.511 & 8.0 & 16 & 12.336 & 8.0 & 16\\
# \hline
# heroku & 51.289 & 2.0 & 4 & 54.578 & 4.0 & 8 & 51.022 & 4.0 & 8\\
# \hline
# jruby & 113.146 & 2.0 & 4 & 127.118 & 1.0 & 2 & 124.078 & 4.0 & 8\\
# \hline
# loomio & 57.134 & 2.0 & 4 & 59.407 & 2.0 & 4 & 57.513 & 4.0 & 8\\
# \hline
# metasploit-framework & 27.778 & 2.0 & 4 & 13.621 & 7.0 & 16 & 13.475 & 7.0 & 16\\
# \hline
# opal & 33.12 & 2.0 & 4 & 25.641 & 7.5 & 16 & 25.356 & 7.5 & 16\\
# \hline
# open-build-service & 57.499 & 2.0 & 4 & 61.086 & 2.0 & 4 & 58.744 & 4.0 & 8\\
# \hline
# orbeon-forms & 103.846 & 2.0 & 4 & 117.009 & 1.0 & 2 & 113.333 & 4.0 & 8\\
# \hline
# puppet & 27.817 & 2.0 & 4 & 17.888 & 7.0 & 16 & 17.888 & 7.0 & 16\\
# \hline
# rails & 67.453 & 2.0 & 4 & 71.934 & 2.0 & 4 & 71.226 & 4.0 & 8\\
# \hline
# rubinius & 79.76 & 2.0 & 4 & 86.63 & 1.0 & 2 & 86.123 & 4.0 & 8\\
# \hline
# sonarqube & 44.678 & 2.0 & 4 & 43.099 & 4.0 & 8 & 41.579 & 4.0 & 8\\
# \hline
# sufia & 35.621 & 2.0 & 4 & 29.902 & 7.0 & 16 & 29.085 & 7.0 & 16\\
# \hline
# vagrant & 31.687 & 2.0 & 4 & 22.268 & 7.0 & 16 & 22.268 & 7.0 & 16\\
# \hline
# Median & 50.577 & 2.0 & & 53.298 & 4.0 & & 48.906 & 4.0
# \hline
# \hline

# %%
ml = pd.read_csv('mlci_pivot_median_delay.csv')
ml = ml.sort_values(by='project')

# %%
projects = ml['project'].tolist()
col3 = ml['B4_builds'].tolist()
col4 = ml['B4_delay'].tolist()
b4_batch = ml['B4_Batch'].tolist()
col5 = ml['BB_builds'].tolist()
col6 = ml['BB_delay'].tolist()
bb_batch = ml['BB_Batch'].tolist()
col7 = ml['BS4_builds'].tolist()
col8 = ml['BS4_delay'].tolist()
bs4_batch = ml['BS4_Batch'].tolist()

# %%
for i in range(len(projects)):
    print("{} & {} & {} & {} & {} & {} & {} & {} & {} & {}\\\\".format(projects[i].split('.')[0], 
                                                                round(col3[i], 2), int(round(col4[i], 3)), batch_reps[b4_batch[i]], 
                                                                round(col5[i], 2), int(round(col6[i], 3)), batch_reps[bb_batch[i]], 
                                                                round(col7[i], 2), int(round(col8[i], 3)), batch_reps[bs4_batch[i]] ))
    print("\hline")
print("Median & {} & {} & & {} & {} & & {} & {}".format(round(median(col3), 3), round(median(col4), 3), round(median(col5), 3), round(median(col6), 3), round(median(col7), 3), round(median(col8), 3)))
print("\hline\n\hline")
# Out:
# cloud_controller_ng & 62.27 & 2 & 4 & 55.56 & 1 & 2 & 74.61 & 4 & 8\\
# \hline
# cloudify & 21.11 & 2 & 4 & 23.95 & 2 & 4 & 28.49 & 4 & 8\\
# \hline
# concerto & 39.45 & 2 & 4 & 40.42 & 4 & 8 & 38.49 & 4 & 8\\
# \hline
# fog & 69.78 & 2 & 4 & 64.09 & 1 & 2 & 86.31 & 4 & 8\\
# \hline
# geoserver & 87.02 & 2 & 4 & 71.25 & 1 & 2 & 103.39 & 4 & 8\\
# \hline
# gradle & 37.59 & 2 & 4 & 38.63 & 2 & 4 & 37.85 & 4 & 8\\
# \hline
# graylog2-server & 30.71 & 2 & 4 & 23.01 & 8 & 16 & 21.96 & 8 & 16\\
# \hline
# heroku & 36.27 & 2 & 4 & 38.13 & 1 & 2 & 42.31 & 4 & 8\\
# \hline
# jruby & 73.06 & 2 & 4 & 62.62 & 1 & 2 & 103.6 & 4 & 8\\
# \hline
# loomio & 54.1 & 2 & 4 & 57.26 & 1 & 2 & 73.86 & 4 & 8\\
# \hline
# metasploit-framework & 34.04 & 2 & 4 & 28.53 & 8 & 16 & 28.0 & 8 & 16\\
# \hline
# opal & 35.4 & 2 & 4 & 36.68 & 2 & 4 & 36.54 & 4 & 8\\
# \hline
# open-build-service & 51.97 & 2 & 4 & 45.89 & 1 & 2 & 60.49 & 4 & 8\\
# \hline
# orbeon-forms & 63.33 & 2 & 4 & 67.26 & 1 & 2 & 73.93 & 4 & 8\\
# \hline
# puppet & 31.21 & 2 & 4 & 23.48 & 4 & 8 & 23.01 & 4 & 8\\
# \hline
# rails & 44.47 & 2 & 4 & 36.29 & 1 & 2 & 64.09 & 4 & 8\\
# \hline
# rubinius & 74.0 & 2 & 4 & 63.12 & 1 & 2 & 88.15 & 4 & 8\\
# \hline
# sonarqube & 48.36 & 2 & 4 & 51.17 & 1 & 2 & 52.4 & 4 & 8\\
# \hline
# sufia & 47.22 & 2 & 4 & 49.84 & 2 & 4 & 47.88 & 4 & 8\\
# \hline
# vagrant & 26.43 & 2 & 4 & 28.44 & 4 & 8 & 25.51 & 4 & 8\\
# \hline
# Median & 45.846 & 2.0 & & 43.154 & 1.0 & & 50.137 & 4.0
# \hline
# \hline

# %%
gr = pd.read_csv('gr_pivot_median_delay.csv')
gr = gr.sort_values(by='project')

# %%
sbs_values = results[ (results['method'] == 'sbs') & (results['algorithm'] == 'BATCH4')]

# %%
sbs_values = sbs_values.sort_values(by='project')

# %%
gr['SBS_builds'] = sbs_values['builds_reqd']
gr['SBS_delay'] = sbs_values['median_delay']
gr.to_csv('baseline_pivot_median_delay.csv')

# %%
projects = gr['project'].tolist()
col2 = sbs_values['builds_reqd'].tolist()
col3 = sbs_values['median_delay'].tolist()
col4 = gr['B4_builds'].tolist()
col5 = gr['B4_Batch'].tolist()
col6 = gr['BB_builds'].tolist()
col7 = gr['BB_Batch'].tolist()
col8 = gr['BS4_builds'].tolist()
col9 = gr['BS4_Batch'].tolist()

# %%
for i in range(len(projects)):
    print("{} & {} & {} & {} & {} & {} & {} \\\\".format(projects[i], 
                                                                round(col2[i], 2), round(col4[i], 2), 
                                                                round(col6[i], 2), round(col7[i], 2), 
                                                                round(col8[i], 2), round(col9[i], 2) ))
    print("\hline")
print("Median & {} & {} & {} & {} & {} & {}".format(round(median(col2), 3), round(median(col4), 3), round(median(col6), 3), round(median(col7), 3), round(median(col8), 3), round(median(col9), 3)))
print("\hline\n\hline")
# Out:
# cloud_controller_ng & 11.27 & 74.69 & 80.4 & 4 & 80.09 & 8 \\
# \hline
# cloudify & 16.96 & 45.25 & 42.87 & 16 & 38.64 & 16 \\
# \hline
# concerto & 3.86 & 45.97 & 44.12 & 8 & 42.19 & 8 \\
# \hline
# fog & 26.59 & 83.73 & 93.92 & 2 & 89.75 & 8 \\
# \hline
# geoserver & 62.0 & 99.49 & 108.23 & 2 & 108.48 & 8 \\
# \hline
# gradle & 0.88 & 44.55 & 40.97 & 8 & 39.51 & 8 \\
# \hline
# graylog2-server & 1.22 & 35.0 & 23.8 & 16 & 22.75 & 16 \\
# \hline
# heroku & 14.58 & 53.33 & 55.64 & 8 & 51.38 & 8 \\
# \hline
# jruby & 79.32 & 108.41 & 121.37 & 2 & 119.27 & 8 \\
# \hline
# loomio & 17.3 & 73.48 & 82.83 & 4 & 78.03 & 8 \\
# \hline
# metasploit-framework & 1.02 & 37.48 & 28.97 & 16 & 28.44 & 16 \\
# \hline
# opal & 3.49 & 43.52 & 40.88 & 8 & 39.46 & 8 \\
# \hline
# open-build-service & 16.54 & 69.36 & 76.33 & 4 & 72.35 & 8 \\
# \hline
# orbeon-forms & 64.44 & 80.09 & 96.84 & 2 & 82.82 & 8 \\
# \hline
# puppet & 1.73 & 35.3 & 25.14 & 16 & 24.51 & 16 \\
# \hline
# rails & 24.11 & 72.8 & 82.97 & 4 & 76.76 & 8 \\
# \hline
# rubinius & 30.75 & 84.88 & 92.07 & 2 & 90.96 & 8 \\
# \hline
# sonarqube & 8.19 & 56.61 & 60.23 & 4 & 56.73 & 8 \\
# \hline
# sufia & 4.41 & 51.8 & 53.51 & 8 & 49.75 & 8 \\
# \hline
# vagrant & 2.38 & 39.55 & 33.84 & 16 & 30.82 & 16 \\
# \hline
# Median & 12.922 & 54.971 & 57.939 & 6.0 & 54.051 & 8.0
# \hline
# \hline
